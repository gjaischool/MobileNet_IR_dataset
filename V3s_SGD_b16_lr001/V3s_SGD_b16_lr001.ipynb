# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow_addons as tfa
from tensorflow.keras import mixed_precision
# Out:
# 2024-10-29 08:23:01.791888: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 08:23:01.858729: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 08:23:01.858779: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 08:23:01.858843: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 08:23:01.874709: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 08:23:03.232068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jovyan/.local/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # 데이터셋 로더

# %%
# **1. GPU 메모리 성장 설정 (가장 먼저 실행)**
physical_devices = tf.config.list_physical_devices('GPU')
for gpu in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"메모리 성장 설정 완료: {gpu}")
    except RuntimeError as e:
        print(f"메모리 성장 설정 실패: {gpu} - {e}")

# **2. 분산 전략 설정**
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# **3. Mixed Precision 비활성화**
policy = mixed_precision.Policy('float32')
mixed_precision.set_global_policy(policy)

# **4. 데이터셋 로더 함수**
def load_data(csv_file, image_dir):
    df = pd.read_csv(csv_file)
    image_paths = df['image_path'].tolist()
    keypoints = df.iloc[:, 1:].values.astype(np.float32)
    return image_paths, keypoints

# **5. 키포인트 스케일링 함수 정의**
def scale_keypoints(keypoints, original_width=720, original_height=1280, target_size=224):
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    x_scale = target_size / original_width
    y_scale = target_size / original_height
    x_scaled = x_coords * x_scale
    y_scaled = y_coords * y_scale
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    return scaled_keypoints

# **6. 데이터 증강 함수 정의 (현재 사용 안 함)**
def augment(image, keypoints):
    # 랜덤 회전
    angle = tf.random.uniform([], -15, 15, dtype=tf.float32)
    angle_rad = angle * np.pi / 180.0
    image = tfa.image.rotate(image, angles=angle_rad, fill_mode='nearest')
    
    # 키포인트 회전
    center_x = 720.0 / 2 * (224 / 720.0)  # 224x224 이미지 기준 (720 -> 224)
    center_y = 1280.0 / 2 * (224 / 1280.0)  # 1280 -> 224
    rotation_matrix = tf.reshape([
        tf.cos(angle_rad), -tf.sin(angle_rad),
        tf.sin(angle_rad), tf.cos(angle_rad)
    ], [2, 2])
    keypoints = tf.reshape(keypoints, [NUM_KEYPOINTS, 2])
    keypoints = tf.matmul(keypoints - tf.constant([center_x, center_y]), rotation_matrix) + tf.constant([center_x, center_y])
    keypoints = tf.reshape(keypoints, [-1])
    
    return image, keypoints

# **7. 이미지 및 키포인트 전처리 함수 (종횡비 유지 및 패딩 추가)**
def preprocess_image(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    """
    이미지와 키포인트를 전처리하는 함수.

    Parameters:
        image_path (tf.Tensor): 이미지 파일 경로.
        keypoints (tf.Tensor): 키포인트 좌표.
        image_dir (tf.Tensor): 이미지가 저장된 디렉토리 경로.
        target_size (int): 모델 입력 이미지의 크기.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.

    Returns:
        image (tf.Tensor): 전처리된 이미지.
        scaled_keypoints (tf.Tensor): 스케일 조정된 키포인트 좌표.
    """
    # 이미지 경로 결합
    image_full_path = tf.strings.join([image_dir, '/', image_path])
    
    # 이미지 로드 및 디코드
    image = tf.io.read_file(image_full_path)
    image = tf.image.decode_jpeg(image, channels=3)
    
    # 이미지가 정상적으로 로드되었는지 확인하고, float32로 변환 및 [0,1] 범위로 스케일링
    image = tf.cond(tf.equal(tf.size(image), 0),
                   lambda: tf.zeros([target_size, target_size, 3], dtype=tf.float32),
                   lambda: tf.image.convert_image_dtype(image, tf.float32))
    
    # 원본 크기 가져오기
    orig_shape = tf.shape(image)[:2]
    orig_height_img = tf.cast(orig_shape[0], tf.float32)
    orig_width_img = tf.cast(orig_shape[1], tf.float32)
    
    # 종횡비 유지하며 리사이징
    scale = tf.minimum(target_size / orig_width_img, target_size / orig_height_img)
    new_width = tf.cast(tf.round(orig_width_img * scale), tf.int32)
    new_height = tf.cast(tf.round(orig_height_img * scale), tf.int32)
    
    image = tf.image.resize(image, [new_height, new_width])
    
    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_width = target_size - new_width
    pad_height = target_size - new_height
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    
    image = tf.pad(image, [[pad_top, pad_bottom], [pad_left, pad_right], [0, 0]], constant_values=0)
    
    # 키포인트 스케일 조정 및 이동
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    
    # 스케일링
    x_scale = scale
    y_scale = scale
    
    x_scaled = x_coords * x_scale + tf.cast(pad_left, tf.float32)
    y_scaled = y_coords * y_scale + tf.cast(pad_top, tf.float32)
    
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    
    return image, scaled_keypoints

# **8. 데이터셋 전처리 및 증강 함수**
def preprocess_image_aug(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    image, keypoints = preprocess_image(image_path, keypoints, image_dir, target_size, original_width, original_height)
    image, keypoints = augment(image, keypoints)
    return image, keypoints

# **9. 데이터셋 생성 함수 수정**
def create_dataset(image_paths, keypoints, image_dir, batch_size=64, shuffle=True, augment_data=False, target_size=224, original_width=720, original_height=1280):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, keypoints))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(image_paths))
    
    # image_dir을 TensorFlow 상수로 변환
    image_dir_tf = tf.constant(image_dir)
    
    if augment_data:
        # 데이터 증강 적용
        dataset = dataset.map(lambda x, y: preprocess_image_aug(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        # 데이터 증강 미적용
        dataset = dataset.map(lambda x, y: preprocess_image(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset
# Out:
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3
# 2024-10-29 08:23:17.085719: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.087803: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.089775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.138232: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.140191: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.142067: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.143945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.145827: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:17.147668: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.072985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.075104: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.077191: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.079148: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.081044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.083022: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.084908: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.086795: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.088686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.119526: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.121506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.123423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.125310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.127200: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.129080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.131020: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.133375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12553 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:08.0, compute capability: 7.5
# 2024-10-29 08:23:18.133837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.135719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13071 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5
# 2024-10-29 08:23:18.136090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:23:18.138029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 13071 MB memory:  -> device: 2, name: Tesla T4, pci bus id: 0000:00:0a.0, compute capability: 7.5

# %%
# CSV 파일 경로
train_csv = 'keras_dataset/annotations/train_annotations.csv'
val_csv = 'keras_dataset/annotations/val_annotations.csv'

# 이미지 디렉토리
train_image_dir = 'keras_dataset/images/train'
val_image_dir = 'keras_dataset/images/val'

# 로드된 데이터
train_image_paths, train_keypoints = load_data(train_csv, train_image_dir)
val_image_paths, val_keypoints = load_data(val_csv, val_image_dir)

# 전체 배치 크기 설정
BATCH_SIZE_PER_REPLICA = 16  # 각 GPU당 배치 크기 (메모리 문제를 방지하기 위해 줄임)
GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync  # 전체 배치 크기

# 훈련 및 검증 데이터셋 생성
train_dataset = create_dataset(
    train_image_paths, 
    train_keypoints, 
    train_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=True, 
    augment_data=False,  # 현재 데이터 증강 비활성화
    target_size=224, 
    original_width=720, 
    original_height=1280
)

val_dataset = create_dataset(
    val_image_paths, 
    val_keypoints, 
    val_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=False, 
    augment_data=False, 
    target_size=224, 
    original_width=720, 
    original_height=1280
)

# %% [markdown]
# # 키포인트 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터셋 일부 시각화 (디버깅 용도)
def visualize_sample(image, keypoints, title='Sample'):
    image_np = image.numpy()
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np)
    # 키포인트를 224x224 이미지에 맞게 그리기
    x = keypoints[::2].numpy()
    y = keypoints[1::2].numpy()
    plt.scatter(x, y, c='r', s=10)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# 데이터셋에서 샘플 가져오기
for images, keypoints in train_dataset.take(1):
    for i in range(3):  # 첫 3개 샘플 시각화
        visualize_sample(images[i], keypoints[i], title=f"Sample {i+1}")

# %% [markdown]
# # 모델학습

# %%
import keras


# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 백본 모델 로드 (pre-trained MobileNetV3Small)
    base_model = MobileNetV3Small(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # 백본 모델 학습
    base_model.trainable = True
    
    # 글로벌 풀링
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    
    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표
    x = Dense(NUM_KEYPOINTS * 2, activation='linear', dtype='float32')(x)  # mixed precision 시 출력 dtype 설정
    
    # 모델 정의
    model = Model(inputs=base_model.input, outputs=x)
    
    # 모델 컴파일
    optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 224, 224, 3)          0         ['input_3[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_2[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_54 (TFOpLambda  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  )
#
#  re_lu_64 (ReLU)             (None, 112, 112, 16)         0         ['tf.math.add_54[0][0]']
#
#  tf.math.multiply_54 (TFOpL  (None, 112, 112, 16)         0         ['re_lu_64[0][0]']
#  ambda)
#
#  multiply_36 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_54[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_36[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_65 (ReLU)             (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_65[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_55 (TFOpLambda  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  )                                                                  /Conv_1[0][0]']
#
#  re_lu_66 (ReLU)             (None, 1, 1, 16)             0         ['tf.math.add_55[0][0]']
#
#  tf.math.multiply_55 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_66[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_65[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_55[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_67 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_67[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_68 (ReLU)             (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_68[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_69 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_69[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_70 (ReLU)             (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_70[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_56 (TFOpLambda  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_71 (ReLU)             (None, 28, 28, 96)           0         ['tf.math.add_56[0][0]']
#
#  tf.math.multiply_56 (TFOpL  (None, 28, 28, 96)           0         ['re_lu_71[0][0]']
#  ambda)
#
#  multiply_37 (Multiply)      (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_56[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_37[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_57 (TFOpLambda  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_72 (ReLU)             (None, 14, 14, 96)           0         ['tf.math.add_57[0][0]']
#
#  tf.math.multiply_57 (TFOpL  (None, 14, 14, 96)           0         ['re_lu_72[0][0]']
#  ambda)
#
#  multiply_38 (Multiply)      (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_38[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_58 (TFOpLambda  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_73 (ReLU)             (None, 1, 1, 96)             0         ['tf.math.add_58[0][0]']
#
#  tf.math.multiply_58 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_73[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_38[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_58[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_59 (TFOpLambda  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_74 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_59[0][0]']
#
#  tf.math.multiply_59 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_74[0][0]']
#  ambda)
#
#  multiply_39 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_59[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_39[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_60 (TFOpLambda  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_75 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_60[0][0]']
#
#  tf.math.multiply_60 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_75[0][0]']
#  ambda)
#
#  multiply_40 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_60[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_40[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_61 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_76 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_61[0][0]']
#
#  tf.math.multiply_61 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_76[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_40[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_61[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_62 (TFOpLambda  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_77 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_62[0][0]']
#
#  tf.math.multiply_62 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_77[0][0]']
#  ambda)
#
#  multiply_41 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_62[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_41[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_63 (TFOpLambda  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_78 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_63[0][0]']
#
#  tf.math.multiply_63 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_78[0][0]']
#  ambda)
#
#  multiply_42 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_63[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_42[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_64 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_79 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_64[0][0]']
#
#  tf.math.multiply_64 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_79[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_42[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_64[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_65 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_80 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_65[0][0]']
#
#  tf.math.multiply_65 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_80[0][0]']
#  ambda)
#
#  multiply_43 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_65[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_43[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_66 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_81 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_66[0][0]']
#
#  tf.math.multiply_66 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_81[0][0]']
#  ambda)
#
#  multiply_44 (Multiply)      (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_66[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_44[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_67 (TFOpLambda  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_82 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_67[0][0]']
#
#  tf.math.multiply_67 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_82[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_44[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_67[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_68 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_83 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_68[0][0]']
#
#  tf.math.multiply_68 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_83[0][0]']
#  ambda)
#
#  multiply_45 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_68[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_45[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_69 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_84 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_69[0][0]']
#
#  tf.math.multiply_69 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_84[0][0]']
#  ambda)
#
#  multiply_46 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_69[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_46[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_70 (TFOpLambda  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_85 (ReLU)             (None, 1, 1, 144)            0         ['tf.math.add_70[0][0]']
#
#  tf.math.multiply_70 (TFOpL  (None, 1, 1, 144)            0         ['re_lu_85[0][0]']
#  ambda)
#
#  expanded_conv_7/squeeze_ex  (None, 14, 14, 144)          0         ['multiply_46[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_70[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 48)           6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
# ...
#  ambda)
#
#  multiply_49 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_74[0][0]']
#
#  expanded_conv_9/depthwise   (None, 7, 7, 576)            14400     ['multiply_49[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 7, 7, 576)            2304      ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_75 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_90 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_75[0][0]']
#
#  tf.math.multiply_75 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_90[0][0]']
#  ambda)
#
#  multiply_50 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_75[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_50[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_76 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_91 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_76[0][0]']
#
#  tf.math.multiply_76 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_91[0][0]']
#  ambda)
#
#  expanded_conv_9/squeeze_ex  (None, 7, 7, 576)            0         ['multiply_50[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_76[0][0]']
#
#  expanded_conv_9/project (C  (None, 7, 7, 96)             55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, 7, 7, 96)             384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 7, 7, 96)             0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 7, 7, 576)            55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 7, 7, 576)            2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_77 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#  )                                                                  hNorm[0][0]']
#
#  re_lu_92 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_77[0][0]']
#
#  tf.math.multiply_77 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_92[0][0]']
#  ambda)
#
#  multiply_51 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_77[0][0]']
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_51[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_78 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_93 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_78[0][0]']
#
#  tf.math.multiply_78 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_93[0][0]']
#  ambda)
#
#  multiply_52 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_78[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_52[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_79 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_94 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_79[0][0]']
#
#  tf.math.multiply_79 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_94[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_52[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_79[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_80 (TFOpLambda  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  )
#
#  re_lu_95 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_80[0][0]']
#
#  tf.math.multiply_80 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_95[0][0]']
#  ambda)
#
#  multiply_53 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_80[0][0]']
#
#  global_average_pooling2d_2  (None, 576)                  0         ['multiply_53[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 576)                  0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 140)                  80780     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 1019900 (3.89 MB)
# Trainable params: 1007788 (3.84 MB)
# Non-trainable params: 12112 (47.31 KB)
# __________________________________________________________________________________________________

# %%
len(base_model.layers)
# Out:
# 229

# %%
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import time

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001  # 첫 50 에포크 동안 학습률은 0.001
    else:
        return 0.0005  # 에포크 51부터 100까지 학습률은 0.0005

# 에포크 시간 측정을 위한 콜백 클래스 정의
class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
        
# 콜백 설정
checkpoint = ModelCheckpoint('v3s_sgd_b16_lr001.h5', monitor='val_loss', save_best_only=True, verbose=1)
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)
time_callback = TimeHistory()
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, lr_scheduler_callback, time_callback]
)
# Out:
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 140 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 140 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 856/856 [==============================] - ETA: 0s - loss: 344.4804 - mae: 10.6403
# Epoch 1: val_loss improved from inf to 165321.12500, saving model to v3s_sgd_b16_lr001.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 188s 177ms/step - loss: 344.4804 - mae: 10.6403 - val_loss: 165321.1250 - val_mae: 398.8458 - lr: 0.0010
# Epoch 2/100
# 855/856 [============================>.] - ETA: 0s - loss: 60.4560 - mae: 6.0828
# Epoch 2: val_loss improved from 165321.12500 to 6467.78564, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 139s 161ms/step - loss: 60.4538 - mae: 6.0826 - val_loss: 6467.7856 - val_mae: 61.9798 - lr: 0.0010
# Epoch 3/100
# 855/856 [============================>.] - ETA: 0s - loss: 53.2114 - mae: 5.7337
# Epoch 3: val_loss improved from 6467.78564 to 3422.44238, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 134s 156ms/step - loss: 53.2111 - mae: 5.7338 - val_loss: 3422.4424 - val_mae: 52.8794 - lr: 0.0010
# Epoch 4/100
# 855/856 [============================>.] - ETA: 0s - loss: 50.4959 - mae: 5.5832
# Epoch 4: val_loss improved from 3422.44238 to 1954.75232, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 135s 157ms/step - loss: 50.4981 - mae: 5.5832 - val_loss: 1954.7523 - val_mae: 42.2014 - lr: 0.0010
# Epoch 5/100
# 855/856 [============================>.] - ETA: 0s - loss: 48.8699 - mae: 5.4855
# Epoch 5: val_loss did not improve from 1954.75232
# 856/856 [==============================] - 131s 153ms/step - loss: 48.8749 - mae: 5.4859 - val_loss: 2052.7783 - val_mae: 41.4919 - lr: 0.0010
# Epoch 6/100
# 855/856 [============================>.] - ETA: 0s - loss: 48.1466 - mae: 5.4504
# Epoch 6: val_loss improved from 1954.75232 to 1755.77087, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 130s 151ms/step - loss: 48.1479 - mae: 5.4505 - val_loss: 1755.7709 - val_mae: 36.3397 - lr: 0.0010
# Epoch 7/100
# 855/856 [============================>.] - ETA: 0s - loss: 47.1048 - mae: 5.3946
# Epoch 7: val_loss did not improve from 1755.77087
# 856/856 [==============================] - 132s 153ms/step - loss: 47.1025 - mae: 5.3946 - val_loss: 5001.2573 - val_mae: 69.1701 - lr: 0.0010
# Epoch 8/100
# 855/856 [============================>.] - ETA: 0s - loss: 45.9747 - mae: 5.3231
# Epoch 8: val_loss did not improve from 1755.77087
# 856/856 [==============================] - 133s 155ms/step - loss: 45.9808 - mae: 5.3233 - val_loss: 3674.1179 - val_mae: 56.9411 - lr: 0.0010
# Epoch 9/100
# 855/856 [============================>.] - ETA: 0s - loss: 46.3190 - mae: 5.3460
# Epoch 9: val_loss improved from 1755.77087 to 1574.14026, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 134s 156ms/step - loss: 46.3199 - mae: 5.3461 - val_loss: 1574.1403 - val_mae: 33.2151 - lr: 0.0010
# Epoch 10/100
# 855/856 [============================>.] - ETA: 0s - loss: 45.8784 - mae: 5.3128
# Epoch 10: val_loss improved from 1574.14026 to 418.26300, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 131s 153ms/step - loss: 45.8860 - mae: 5.3131 - val_loss: 418.2630 - val_mae: 18.3654 - lr: 0.0010
# Epoch 11/100
# 855/856 [============================>.] - ETA: 0s - loss: 45.6119 - mae: 5.3048
# Epoch 11: val_loss did not improve from 418.26300
# 856/856 [==============================] - 130s 152ms/step - loss: 45.6066 - mae: 5.3045 - val_loss: 9335.8301 - val_mae: 95.0685 - lr: 0.0010
# Epoch 12/100
# 855/856 [============================>.] - ETA: 0s - loss: 44.8473 - mae: 5.2564
# Epoch 12: val_loss did not improve from 418.26300
# 856/856 [==============================] - 128s 149ms/step - loss: 44.8421 - mae: 5.2560 - val_loss: 787.1054 - val_mae: 22.1907 - lr: 0.0010
# Epoch 13/100
# 855/856 [============================>.] - ETA: 0s - loss: 44.7702 - mae: 5.2479
# Epoch 13: val_loss improved from 418.26300 to 26.70070, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 129s 150ms/step - loss: 44.7693 - mae: 5.2478 - val_loss: 26.7007 - val_mae: 3.7250 - lr: 0.0010
# Epoch 14/100
# 855/856 [============================>.] - ETA: 0s - loss: 44.3900 - mae: 5.2325
# Epoch 14: val_loss did not improve from 26.70070
# 856/856 [==============================] - 127s 148ms/step - loss: 44.3982 - mae: 5.2329 - val_loss: 29.7466 - val_mae: 4.1581 - lr: 0.0010
# Epoch 15/100
# 855/856 [============================>.] - ETA: 0s - loss: 43.6913 - mae: 5.1892
# Epoch 15: val_loss did not improve from 26.70070
# 856/856 [==============================] - 129s 150ms/step - loss: 43.6910 - mae: 5.1893 - val_loss: 1418.6605 - val_mae: 33.4345 - lr: 0.0010
# Epoch 16/100
# 855/856 [============================>.] - ETA: 0s - loss: 44.1487 - mae: 5.2161
# Epoch 16: val_loss improved from 26.70070 to 15.76108, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 130s 152ms/step - loss: 44.1560 - mae: 5.2166 - val_loss: 15.7611 - val_mae: 3.0702 - lr: 0.0010
# Epoch 17/100
# 855/856 [============================>.] - ETA: 0s - loss: 43.2925 - mae: 5.1646
# Epoch 17: val_loss did not improve from 15.76108
# 856/856 [==============================] - 127s 148ms/step - loss: 43.2958 - mae: 5.1648 - val_loss: 9553.4199 - val_mae: 95.7758 - lr: 0.0010
# Epoch 18/100
# 856/856 [==============================] - ETA: 0s - loss: 43.5241 - mae: 5.1763
# Epoch 18: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 43.5241 - mae: 5.1763 - val_loss: 37.0252 - val_mae: 4.9381 - lr: 0.0010
# Epoch 19/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.6406 - mae: 5.1169
# Epoch 19: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 42.6481 - mae: 5.1173 - val_loss: 6539.7788 - val_mae: 78.8954 - lr: 0.0010
# Epoch 20/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.8061 - mae: 5.1352
# Epoch 20: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 42.8166 - mae: 5.1356 - val_loss: 68.5427 - val_mae: 6.4357 - lr: 0.0010
# Epoch 21/100
# 855/856 [============================>.] - ETA: 0s - loss: 43.2882 - mae: 5.1605
# Epoch 21: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 152ms/step - loss: 43.2880 - mae: 5.1606 - val_loss: 1083.3523 - val_mae: 26.7131 - lr: 0.0010
# Epoch 22/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.7746 - mae: 5.1345
# Epoch 22: val_loss did not improve from 15.76108
# 856/856 [==============================] - 128s 149ms/step - loss: 42.7763 - mae: 5.1345 - val_loss: 6854.3096 - val_mae: 80.6419 - lr: 0.0010
# Epoch 23/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.8269 - mae: 5.1382
# Epoch 23: val_loss did not improve from 15.76108
# 856/856 [==============================] - 133s 155ms/step - loss: 42.8363 - mae: 5.1385 - val_loss: 53.3651 - val_mae: 5.7895 - lr: 0.0010
# Epoch 24/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.4364 - mae: 5.1136
# Epoch 24: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 42.4447 - mae: 5.1141 - val_loss: 888.5774 - val_mae: 25.7720 - lr: 0.0010
# Epoch 25/100
# 856/856 [==============================] - ETA: 0s - loss: 42.1868 - mae: 5.1001
# Epoch 25: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 42.1868 - mae: 5.1001 - val_loss: 1521.2430 - val_mae: 35.2402 - lr: 0.0010
# Epoch 26/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.5736 - mae: 5.1222
# Epoch 26: val_loss did not improve from 15.76108
# 856/856 [==============================] - 128s 149ms/step - loss: 42.5749 - mae: 5.1223 - val_loss: 31.5077 - val_mae: 4.4715 - lr: 0.0010
# Epoch 27/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.3888 - mae: 5.1022
# Epoch 27: val_loss did not improve from 15.76108
# 856/856 [==============================] - 126s 147ms/step - loss: 42.3836 - mae: 5.1019 - val_loss: 220.3802 - val_mae: 11.7047 - lr: 0.0010
# Epoch 28/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.7061 - mae: 5.0665
# Epoch 28: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 41.7036 - mae: 5.0663 - val_loss: 5869.4805 - val_mae: 73.7780 - lr: 0.0010
# Epoch 29/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.1824 - mae: 5.0907
# Epoch 29: val_loss did not improve from 15.76108
# 856/856 [==============================] - 128s 150ms/step - loss: 42.1806 - mae: 5.0906 - val_loss: 5936.2900 - val_mae: 75.1837 - lr: 0.0010
# Epoch 30/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.0133 - mae: 5.0791
# Epoch 30: val_loss did not improve from 15.76108
# 856/856 [==============================] - 131s 153ms/step - loss: 42.0080 - mae: 5.0788 - val_loss: 236.3267 - val_mae: 12.6003 - lr: 0.0010
# Epoch 31/100
# 856/856 [==============================] - ETA: 0s - loss: 41.9658 - mae: 5.0791
# Epoch 31: val_loss did not improve from 15.76108
# 856/856 [==============================] - 127s 148ms/step - loss: 41.9658 - mae: 5.0791 - val_loss: 843.5659 - val_mae: 24.9198 - lr: 0.0010
# Epoch 32/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.6132 - mae: 5.0555
# Epoch 32: val_loss did not improve from 15.76108
# 856/856 [==============================] - 127s 149ms/step - loss: 41.6166 - mae: 5.0557 - val_loss: 188.4031 - val_mae: 9.7435 - lr: 0.0010
# Epoch 33/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.5428 - mae: 5.0591
# Epoch 33: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 152ms/step - loss: 41.5369 - mae: 5.0586 - val_loss: 1555.0824 - val_mae: 34.1265 - lr: 0.0010
# Epoch 34/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.3165 - mae: 5.0377
# Epoch 34: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 41.3191 - mae: 5.0378 - val_loss: 8948.3154 - val_mae: 92.3286 - lr: 0.0010
# Epoch 35/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.5025 - mae: 5.0498
# Epoch 35: val_loss did not improve from 15.76108
# 856/856 [==============================] - 128s 149ms/step - loss: 41.5052 - mae: 5.0501 - val_loss: 184.5283 - val_mae: 10.8388 - lr: 0.0010
# Epoch 36/100
# 856/856 [==============================] - ETA: 0s - loss: 41.4026 - mae: 5.0505
# Epoch 36: val_loss did not improve from 15.76108
# 856/856 [==============================] - 131s 152ms/step - loss: 41.4026 - mae: 5.0505 - val_loss: 55.5726 - val_mae: 5.8461 - lr: 0.0010
# Epoch 37/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.3179 - mae: 5.0430
# Epoch 37: val_loss did not improve from 15.76108
# 856/856 [==============================] - 127s 147ms/step - loss: 41.3199 - mae: 5.0432 - val_loss: 428.9234 - val_mae: 16.4541 - lr: 0.0010
# Epoch 38/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.5121 - mae: 5.0500
# Epoch 38: val_loss did not improve from 15.76108
# 856/856 [==============================] - 132s 154ms/step - loss: 41.5159 - mae: 5.0503 - val_loss: 16.0787 - val_mae: 3.2466 - lr: 0.0010
# Epoch 39/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.1333 - mae: 5.0231
# Epoch 39: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.1297 - mae: 5.0229 - val_loss: 65.8404 - val_mae: 5.3187 - lr: 0.0010
# Epoch 40/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.2957 - mae: 5.0336
# Epoch 40: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 151ms/step - loss: 41.2969 - mae: 5.0337 - val_loss: 199.8506 - val_mae: 10.9531 - lr: 0.0010
# Epoch 41/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.4265 - mae: 5.0497
# Epoch 41: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.4280 - mae: 5.0497 - val_loss: 8109.9355 - val_mae: 88.0652 - lr: 0.0010
# Epoch 42/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.9003 - mae: 5.0106
# Epoch 42: val_loss did not improve from 15.76108
# 856/856 [==============================] - 130s 152ms/step - loss: 40.8975 - mae: 5.0104 - val_loss: 478.6874 - val_mae: 18.2867 - lr: 0.0010
# Epoch 43/100
# 856/856 [==============================] - ETA: 0s - loss: 41.0191 - mae: 5.0240
# Epoch 43: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.0191 - mae: 5.0240 - val_loss: 433.8250 - val_mae: 18.4626 - lr: 0.0010
# Epoch 44/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.1719 - mae: 5.0307
# Epoch 44: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.1668 - mae: 5.0304 - val_loss: 782.8806 - val_mae: 23.1620 - lr: 0.0010
# Epoch 45/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.1628 - mae: 5.0335
# Epoch 45: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.1620 - mae: 5.0335 - val_loss: 1813.8214 - val_mae: 39.4951 - lr: 0.0010
# Epoch 46/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.8669 - mae: 5.0009
# Epoch 46: val_loss did not improve from 15.76108
# 856/856 [==============================] - 126s 147ms/step - loss: 40.8698 - mae: 5.0010 - val_loss: 3179.3779 - val_mae: 53.6292 - lr: 0.0010
# Epoch 47/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.0072 - mae: 5.0168
# Epoch 47: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 41.0130 - mae: 5.0171 - val_loss: 1517.1586 - val_mae: 36.7577 - lr: 0.0010
# Epoch 48/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.9395 - mae: 5.0127
# Epoch 48: val_loss did not improve from 15.76108
# 856/856 [==============================] - 129s 150ms/step - loss: 40.9403 - mae: 5.0128 - val_loss: 442.8800 - val_mae: 18.6306 - lr: 0.0010
# Epoch 49/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.0776 - mae: 5.0262
# Epoch 49: val_loss improved from 15.76108 to 13.27963, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 126s 147ms/step - loss: 41.0812 - mae: 5.0265 - val_loss: 13.2796 - val_mae: 2.8695 - lr: 0.0010
# Epoch 50/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.6068 - mae: 5.0009
# Epoch 50: val_loss did not improve from 13.27963
# 856/856 [==============================] - 129s 150ms/step - loss: 40.6071 - mae: 5.0009 - val_loss: 129.3387 - val_mae: 9.0575 - lr: 0.0010
# Epoch 51/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.4838 - mae: 4.9867
# Epoch 51: val_loss did not improve from 13.27963
# 856/856 [==============================] - 126s 147ms/step - loss: 40.4858 - mae: 4.9869 - val_loss: 1576.2673 - val_mae: 37.3563 - lr: 5.0000e-04
# Epoch 52/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0148 - mae: 4.9576
# Epoch 52: val_loss did not improve from 13.27963
# 856/856 [==============================] - 128s 149ms/step - loss: 40.0081 - mae: 4.9571 - val_loss: 1328.5286 - val_mae: 34.3523 - lr: 5.0000e-04
# Epoch 53/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.3273 - mae: 4.9746
# Epoch 53: val_loss did not improve from 13.27963
# 856/856 [==============================] - 129s 150ms/step - loss: 40.3259 - mae: 4.9744 - val_loss: 1196.9189 - val_mae: 32.4551 - lr: 5.0000e-04
# Epoch 54/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.9724 - mae: 4.9544
# Epoch 54: val_loss did not improve from 13.27963
# 856/856 [==============================] - 134s 156ms/step - loss: 39.9707 - mae: 4.9544 - val_loss: 1678.0211 - val_mae: 37.2518 - lr: 5.0000e-04
# Epoch 55/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.2560 - mae: 4.9673
# Epoch 55: val_loss did not improve from 13.27963
# 856/856 [==============================] - 130s 152ms/step - loss: 40.2576 - mae: 4.9674 - val_loss: 3466.9609 - val_mae: 55.1956 - lr: 5.0000e-04
# Epoch 56/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.2032 - mae: 4.9747
# Epoch 56: val_loss did not improve from 13.27963
# 856/856 [==============================] - 130s 152ms/step - loss: 40.2052 - mae: 4.9749 - val_loss: 265.1150 - val_mae: 13.3532 - lr: 5.0000e-04
# Epoch 57/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0341 - mae: 4.9592
# Epoch 57: val_loss did not improve from 13.27963
# 856/856 [==============================] - 130s 151ms/step - loss: 40.0372 - mae: 4.9594 - val_loss: 1651.8065 - val_mae: 38.2086 - lr: 5.0000e-04
# Epoch 58/100
# 856/856 [==============================] - ETA: 0s - loss: 40.0371 - mae: 4.9597
# Epoch 58: val_loss did not improve from 13.27963
# 856/856 [==============================] - 133s 155ms/step - loss: 40.0371 - mae: 4.9597 - val_loss: 6598.8750 - val_mae: 79.2677 - lr: 5.0000e-04
# Epoch 59/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.1518 - mae: 4.9717
# Epoch 59: val_loss did not improve from 13.27963
# 856/856 [==============================] - 126s 147ms/step - loss: 40.1573 - mae: 4.9718 - val_loss: 7511.7407 - val_mae: 84.4596 - lr: 5.0000e-04
# Epoch 60/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.3694 - mae: 4.9711
# Epoch 60: val_loss did not improve from 13.27963
# 856/856 [==============================] - 127s 148ms/step - loss: 40.3673 - mae: 4.9709 - val_loss: 538.3332 - val_mae: 19.2605 - lr: 5.0000e-04
# Epoch 61/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0544 - mae: 4.9687
# Epoch 61: val_loss did not improve from 13.27963
# 856/856 [==============================] - 131s 153ms/step - loss: 40.0574 - mae: 4.9689 - val_loss: 1487.4595 - val_mae: 35.1380 - lr: 5.0000e-04
# Epoch 62/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.5787 - mae: 4.9983
# Epoch 62: val_loss did not improve from 13.27963
# 856/856 [==============================] - 130s 151ms/step - loss: 40.5769 - mae: 4.9982 - val_loss: 15.9287 - val_mae: 3.0647 - lr: 5.0000e-04
# Epoch 63/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.1849 - mae: 4.9663
# Epoch 63: val_loss improved from 13.27963 to 9.32639, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 129s 150ms/step - loss: 40.1832 - mae: 4.9661 - val_loss: 9.3264 - val_mae: 2.2685 - lr: 5.0000e-04
# Epoch 64/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0537 - mae: 4.9602
# Epoch 64: val_loss did not improve from 9.32639
# 856/856 [==============================] - 130s 152ms/step - loss: 40.0522 - mae: 4.9601 - val_loss: 162.7508 - val_mae: 10.2926 - lr: 5.0000e-04
# Epoch 65/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.2272 - mae: 4.9731
# Epoch 65: val_loss did not improve from 9.32639
# 856/856 [==============================] - 128s 149ms/step - loss: 40.2251 - mae: 4.9731 - val_loss: 59.2810 - val_mae: 6.0101 - lr: 5.0000e-04
# Epoch 66/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.4079 - mae: 4.9809
# Epoch 66: val_loss did not improve from 9.32639
# 856/856 [==============================] - 127s 148ms/step - loss: 40.4055 - mae: 4.9809 - val_loss: 1015.5630 - val_mae: 29.7391 - lr: 5.0000e-04
# Epoch 67/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0688 - mae: 4.9543
# Epoch 67: val_loss did not improve from 9.32639
# 856/856 [==============================] - 128s 149ms/step - loss: 40.0693 - mae: 4.9545 - val_loss: 292.4157 - val_mae: 13.9963 - lr: 5.0000e-04
# Epoch 68/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.1666 - mae: 4.9628
# Epoch 68: val_loss did not improve from 9.32639
# 856/856 [==============================] - 128s 149ms/step - loss: 40.1727 - mae: 4.9632 - val_loss: 6597.7456 - val_mae: 78.8277 - lr: 5.0000e-04
# Epoch 69/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.1251 - mae: 4.9624
# Epoch 69: val_loss did not improve from 9.32639
# 856/856 [==============================] - 129s 151ms/step - loss: 40.1241 - mae: 4.9624 - val_loss: 1518.1550 - val_mae: 35.9499 - lr: 5.0000e-04
# Epoch 70/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.1985 - mae: 4.9743
# Epoch 70: val_loss did not improve from 9.32639
# 856/856 [==============================] - 133s 155ms/step - loss: 40.1991 - mae: 4.9745 - val_loss: 16.8194 - val_mae: 3.1508 - lr: 5.0000e-04
# Epoch 71/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.9810 - mae: 4.9550
# Epoch 71: val_loss did not improve from 9.32639
# 856/856 [==============================] - 130s 151ms/step - loss: 39.9794 - mae: 4.9550 - val_loss: 67.7504 - val_mae: 5.7611 - lr: 5.0000e-04
# Epoch 72/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.8821 - mae: 4.9551
# Epoch 72: val_loss did not improve from 9.32639
# 856/856 [==============================] - 126s 147ms/step - loss: 39.8829 - mae: 4.9551 - val_loss: 507.9315 - val_mae: 18.8798 - lr: 5.0000e-04
# Epoch 73/100
# 856/856 [==============================] - ETA: 0s - loss: 39.8882 - mae: 4.9530
# Epoch 73: val_loss did not improve from 9.32639
# 856/856 [==============================] - 127s 148ms/step - loss: 39.8882 - mae: 4.9530 - val_loss: 877.2122 - val_mae: 23.2213 - lr: 5.0000e-04
# Epoch 74/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.7841 - mae: 4.9503
# Epoch 74: val_loss did not improve from 9.32639
# 856/856 [==============================] - 127s 148ms/step - loss: 39.7786 - mae: 4.9499 - val_loss: 7683.9502 - val_mae: 84.9823 - lr: 5.0000e-04
# Epoch 75/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.2724 - mae: 4.9756
# Epoch 75: val_loss did not improve from 9.32639
# 856/856 [==============================] - 131s 153ms/step - loss: 40.2675 - mae: 4.9753 - val_loss: 136.3405 - val_mae: 9.7603 - lr: 5.0000e-04
# Epoch 76/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.9505 - mae: 4.9608
# Epoch 76: val_loss did not improve from 9.32639
# 856/856 [==============================] - 129s 150ms/step - loss: 39.9586 - mae: 4.9612 - val_loss: 1360.5437 - val_mae: 34.4471 - lr: 5.0000e-04
# Epoch 77/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.2605 - mae: 4.9730
# Epoch 77: val_loss did not improve from 9.32639
# 856/856 [==============================] - 130s 151ms/step - loss: 40.2557 - mae: 4.9727 - val_loss: 4972.4111 - val_mae: 68.6535 - lr: 5.0000e-04
# Epoch 78/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.8927 - mae: 4.9494
# Epoch 78: val_loss did not improve from 9.32639
# 856/856 [==============================] - 129s 150ms/step - loss: 39.8939 - mae: 4.9495 - val_loss: 27.6972 - val_mae: 4.2369 - lr: 5.0000e-04
# Epoch 79/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.7615 - mae: 4.9428
# Epoch 79: val_loss did not improve from 9.32639
# 856/856 [==============================] - 125s 146ms/step - loss: 39.7619 - mae: 4.9427 - val_loss: 5434.9526 - val_mae: 71.0028 - lr: 5.0000e-04
# Epoch 80/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.6393 - mae: 4.9340
# Epoch 80: val_loss did not improve from 9.32639
# 856/856 [==============================] - 129s 150ms/step - loss: 39.6343 - mae: 4.9337 - val_loss: 5686.8994 - val_mae: 73.2128 - lr: 5.0000e-04
# Epoch 81/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0424 - mae: 4.9616
# Epoch 81: val_loss improved from 9.32639 to 6.76336, saving model to v3s_sgd_b16_lr001.h5
# 856/856 [==============================] - 130s 152ms/step - loss: 40.0433 - mae: 4.9617 - val_loss: 6.7634 - val_mae: 1.9311 - lr: 5.0000e-04
# Epoch 82/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.8963 - mae: 4.9533
# Epoch 82: val_loss did not improve from 6.76336
# 856/856 [==============================] - 130s 151ms/step - loss: 39.8911 - mae: 4.9530 - val_loss: 2127.0859 - val_mae: 42.7534 - lr: 5.0000e-04
# Epoch 83/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0666 - mae: 4.9646
# Epoch 83: val_loss did not improve from 6.76336
# 856/856 [==============================] - 138s 161ms/step - loss: 40.0659 - mae: 4.9646 - val_loss: 3527.3889 - val_mae: 56.8498 - lr: 5.0000e-04
# Epoch 84/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.5179 - mae: 4.9275
# Epoch 84: val_loss did not improve from 6.76336
# 856/856 [==============================] - 126s 147ms/step - loss: 39.5218 - mae: 4.9278 - val_loss: 16.5876 - val_mae: 2.8806 - lr: 5.0000e-04
# Epoch 85/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.6221 - mae: 4.9356
# Epoch 85: val_loss did not improve from 6.76336
# 856/856 [==============================] - 125s 146ms/step - loss: 39.6241 - mae: 4.9358 - val_loss: 901.3207 - val_mae: 27.3941 - lr: 5.0000e-04
# Epoch 86/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.4259 - mae: 4.9182
# Epoch 86: val_loss did not improve from 6.76336
# 856/856 [==============================] - 128s 150ms/step - loss: 39.4272 - mae: 4.9183 - val_loss: 320.4857 - val_mae: 15.4454 - lr: 5.0000e-04
# Epoch 87/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.6207 - mae: 4.9333
# Epoch 87: val_loss did not improve from 6.76336
# 856/856 [==============================] - 127s 148ms/step - loss: 39.6238 - mae: 4.9335 - val_loss: 921.7792 - val_mae: 27.7119 - lr: 5.0000e-04
# Epoch 88/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.4488 - mae: 4.9156
# Epoch 88: val_loss did not improve from 6.76336
# 856/856 [==============================] - 125s 146ms/step - loss: 39.4473 - mae: 4.9154 - val_loss: 8690.6660 - val_mae: 90.9140 - lr: 5.0000e-04
# Epoch 89/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.7571 - mae: 4.9370
# Epoch 89: val_loss did not improve from 6.76336
# 856/856 [==============================] - 127s 148ms/step - loss: 39.7561 - mae: 4.9369 - val_loss: 3988.1958 - val_mae: 60.5344 - lr: 5.0000e-04
# Epoch 90/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.7024 - mae: 4.9354
# Epoch 90: val_loss did not improve from 6.76336
# 856/856 [==============================] - 124s 145ms/step - loss: 39.7084 - mae: 4.9357 - val_loss: 84.7248 - val_mae: 6.9851 - lr: 5.0000e-04
# Epoch 91/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.6436 - mae: 4.9319
# Epoch 91: val_loss did not improve from 6.76336
# 856/856 [==============================] - 128s 150ms/step - loss: 39.6433 - mae: 4.9319 - val_loss: 9.1259 - val_mae: 2.2443 - lr: 5.0000e-04
# Epoch 92/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0567 - mae: 4.9625
# Epoch 92: val_loss did not improve from 6.76336
# 856/856 [==============================] - 140s 162ms/step - loss: 40.0602 - mae: 4.9626 - val_loss: 8.5393 - val_mae: 2.1961 - lr: 5.0000e-04
# Epoch 93/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.5640 - mae: 4.9253
# Epoch 93: val_loss did not improve from 6.76336
# 856/856 [==============================] - 147s 172ms/step - loss: 39.5760 - mae: 4.9260 - val_loss: 19.6018 - val_mae: 3.4773 - lr: 5.0000e-04
# Epoch 94/100
# 856/856 [==============================] - ETA: 0s - loss: 39.5405 - mae: 4.9259
# Epoch 94: val_loss did not improve from 6.76336
# 856/856 [==============================] - 136s 158ms/step - loss: 39.5405 - mae: 4.9259 - val_loss: 874.7889 - val_mae: 27.8709 - lr: 5.0000e-04
# Epoch 95/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.6126 - mae: 4.9386
# Epoch 95: val_loss did not improve from 6.76336
# 856/856 [==============================] - 145s 169ms/step - loss: 39.6111 - mae: 4.9384 - val_loss: 1329.0065 - val_mae: 31.5275 - lr: 5.0000e-04
# Epoch 96/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.1661 - mae: 4.8950
# Epoch 96: val_loss did not improve from 6.76336
# 856/856 [==============================] - 139s 163ms/step - loss: 39.1654 - mae: 4.8949 - val_loss: 280.2557 - val_mae: 14.9599 - lr: 5.0000e-04
# Epoch 97/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.3134 - mae: 4.9121
# Epoch 97: val_loss did not improve from 6.76336
# 856/856 [==============================] - 136s 159ms/step - loss: 39.3126 - mae: 4.9121 - val_loss: 8259.7100 - val_mae: 88.3477 - lr: 5.0000e-04
# Epoch 98/100
# 856/856 [==============================] - ETA: 0s - loss: 39.7415 - mae: 4.9293
# Epoch 98: val_loss did not improve from 6.76336
# 856/856 [==============================] - 141s 165ms/step - loss: 39.7415 - mae: 4.9293 - val_loss: 71.1432 - val_mae: 6.4967 - lr: 5.0000e-04
# Epoch 99/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.3339 - mae: 4.9168
# Epoch 99: val_loss did not improve from 6.76336
# 856/856 [==============================] - 142s 166ms/step - loss: 39.3358 - mae: 4.9171 - val_loss: 8.1852 - val_mae: 2.0934 - lr: 5.0000e-04
# Epoch 100/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.3521 - mae: 4.9183
# Epoch 100: val_loss did not improve from 6.76336
# 856/856 [==============================] - 147s 172ms/step - loss: 39.3526 - mae: 4.9184 - val_loss: 8314.6572 - val_mae: 88.5157 - lr: 5.0000e-04

# %%
# 평균 에포크 시간 계산 및 출력
average_epoch_time = np.mean(time_callback.times)
print(f"에포크당 평균 소요 시간: {average_epoch_time:.2f}초")
# Out:
# 에포크당 평균 소요 시간: 130.98초

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()

# %%
b_m = tf.keras.models.load_model('v3s_sgd_b16_lr001.h5')

# %%
def plot_predicted_keypoints(model, image_path, image_dir, original_width=720, original_height=1280, target_size=224):
    """
    모델을 사용하여 이미지의 키포인트를 예측하고 시각화하는 함수.

    Parameters:
        model (tf.keras.Model): 사전 학습된 모델.
        image_path (str): 예측할 이미지의 경로.
        image_dir (str): 이미지가 저장된 디렉토리 경로.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.
        target_size (int): 모델의 입력 이미지 크기.
    """
    # 이미지 로드 및 전처리
    image_full_path = os.path.join(image_dir, image_path)
    image = cv2.imread(image_full_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_full_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 원본 크기와 종횡비 계산
    orig_h, orig_w = image_rgb.shape[:2]
    scale = min(target_size / orig_w, target_size / orig_h)
    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)

    print(f"Original size: ({orig_w}, {orig_h})")
    print(f"Scale factor: {scale}")
    print(f"Resized size: ({new_w}, {new_h})")

    # 종횡비 유지하며 리사이징
    image_resized = cv2.resize(image_rgb, (new_w, new_h)) / 255.0

    # 패딩 추가
    pad_w = target_size - new_w
    pad_h = target_size - new_h
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top

    print(f"Padding (left, top): ({pad_left}, {pad_top})")
    print(f"Padding (right, bottom): ({pad_right}, {pad_bottom})")

    image_padded = cv2.copyMakeBorder(
        image_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=0
    )

    # 모델 입력 준비
    input_image = np.expand_dims(image_padded, axis=0).astype(np.float32)

    # 예측
    predicted_keypoints = model.predict(input_image)[0]

    # print(f"Predicted keypoints (raw): {predicted_keypoints}")

    # 키포인트 스케일 조정 및 이동 (패딩 고려)
    # 전처리 시 사용된 스케일과 동일하게 되돌리기
    scale_back = 1 / scale

    x_scaled = (predicted_keypoints[::2] - pad_left) * scale_back
    y_scaled = (predicted_keypoints[1::2] - pad_top) * scale_back

    # print(f"Scaled keypoints (x): {x_scaled}")
    # print(f"Scaled keypoints (y): {y_scaled}")

    predicted_keypoints_scaled = np.empty_like(predicted_keypoints)
    predicted_keypoints_scaled[::2] = x_scaled
    predicted_keypoints_scaled[1::2] = y_scaled

    # print(f"Scaled keypoints (combined): {predicted_keypoints_scaled}")

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)

    for i in range(0, len(predicted_keypoints_scaled), 2):
        x = predicted_keypoints_scaled[i]
        y = predicted_keypoints_scaled[i + 1]
        # 키포인트가 이미지 범위 내에 있는지 확인
        if 0 <= x < orig_w and 0 <= y < orig_h:
            plt.scatter(x, y, c='r', s=10)

    plt.title('Predicted Keypoints')
    plt.axis('off')
    plt.show()

# 예측 및 시각화
sample_image_path = val_image_paths[50]
plot_predicted_keypoints(b_m, sample_image_path, val_image_dir)
# Out:
# Original size: (720, 1280)
# Scale factor: 0.175
# Resized size: (125, 224)
# Padding (left, top): (49, 0)
# Padding (right, bottom): (50, 0)
# 1/1 [==============================] - 2s 2s/step
