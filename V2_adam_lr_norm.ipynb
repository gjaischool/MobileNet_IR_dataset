# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.applications import MobileNetV2
from keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow_addons as tfa
from tensorflow.keras import mixed_precision

# %% [markdown]
# # 데이터셋 로더

# %%
# **1. GPU 메모리 성장 설정 (가장 먼저 실행)**
physical_devices = tf.config.list_physical_devices('GPU')
for gpu in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"메모리 성장 설정 완료: {gpu}")
    except RuntimeError as e:
        print(f"메모리 성장 설정 실패: {gpu} - {e}")

# **2. 분산 전략 설정**
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# **3. Mixed Precision 비활성화**
policy = mixed_precision.Policy('float32')
mixed_precision.set_global_policy(policy)

# **4. 데이터셋 로더 함수**
def load_data(csv_file, image_dir):
    df = pd.read_csv(csv_file)
    image_paths = df['image_path'].tolist()
    keypoints = df.iloc[:, 1:].values.astype(np.float32)
    return image_paths, keypoints

# **5. 키포인트 스케일링 함수 정의**
def scale_keypoints(keypoints, original_width=720, original_height=1280, target_size=224):
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    x_scale = target_size / original_width
    y_scale = target_size / original_height
    x_scaled = x_coords * x_scale
    y_scaled = y_coords * y_scale
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    return scaled_keypoints

# **6. 데이터 증강 함수 정의 **
def augment(image, keypoints):
    # 랜덤 회전
    angle = tf.random.uniform([], -15, 15, dtype=tf.float32)
    angle_rad = angle * np.pi / 180.0
    image = tfa.image.rotate(image, angles=angle_rad, fill_mode='nearest')
    
    # 키포인트 회전
    center_x = 720.0 / 2 * (224 / 720.0)  # 224x224 이미지 기준 (720 -> 224)
    center_y = 1280.0 / 2 * (224 / 1280.0)  # 1280 -> 224
    rotation_matrix = tf.reshape([
        tf.cos(angle_rad), -tf.sin(angle_rad),
        tf.sin(angle_rad), tf.cos(angle_rad)
    ], [2, 2])
    keypoints = tf.reshape(keypoints, [NUM_KEYPOINTS, 2])
    keypoints = tf.matmul(keypoints - tf.constant([center_x, center_y]), rotation_matrix) + tf.constant([center_x, center_y])
    keypoints = tf.reshape(keypoints, [-1])
    
    return image, keypoints

# **7. 이미지 및 키포인트 전처리 함수 (종횡비 유지 및 패딩 추가)**
def preprocess_image(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    # 이미지 경로 결합
    image_full_path = tf.strings.join([image_dir, '/', image_path])
    
    # 이미지 로드 및 디코드
    image = tf.io.read_file(image_full_path)
    image = tf.image.decode_jpeg(image, channels=3)
    
    # 이미지가 정상적으로 로드되었는지 확인하고, float32로 변환 및 [0,1] 범위로 스케일링
    image = tf.cond(tf.equal(tf.size(image), 0),
                   lambda: tf.zeros([target_size, target_size, 3], dtype=tf.float32),
                   lambda: tf.image.convert_image_dtype(image, tf.float32))
    
    # 원본 크기 가져오기
    orig_shape = tf.shape(image)[:2]
    orig_height_img = tf.cast(orig_shape[0], tf.float32)
    orig_width_img = tf.cast(orig_shape[1], tf.float32)
    
    # 종횡비 유지하며 리사이징
    scale = tf.minimum(target_size / orig_width_img, target_size / orig_height_img)
    new_width = tf.cast(tf.round(orig_width_img * scale), tf.int32)
    new_height = tf.cast(tf.round(orig_height_img * scale), tf.int32)
    
    image = tf.image.resize(image, [new_height, new_width])
    
    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_width = target_size - new_width
    pad_height = target_size - new_height
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    
    image = tf.pad(image, [[pad_top, pad_bottom], [pad_left, pad_right], [0, 0]], constant_values=0)
    
    # 키포인트 스케일 조정 및 이동 후 정규화
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    
    # 스케일링 및 이동
    x_scale = scale
    y_scale = scale
    
    x_scaled = x_coords * x_scale + tf.cast(pad_left, tf.float32)
    y_scaled = y_coords * y_scale + tf.cast(pad_top, tf.float32)
    
    # 정규화
    x_normalized = x_scaled / target_size
    y_normalized = y_scaled / target_size
    
    scaled_keypoints = tf.stack([x_normalized, y_normalized], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    
    return image, scaled_keypoints

# **8. 데이터셋 전처리 및 증강 함수**
def preprocess_image_aug(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    image, keypoints = preprocess_image(image_path, keypoints, image_dir, target_size, original_width, original_height)
    image, keypoints = augment(image, keypoints)
    return image, keypoints

# **9. 데이터셋 생성 함수 수정**
def create_dataset(image_paths, keypoints, image_dir, batch_size=64, shuffle=True, augment_data=False, target_size=224, original_width=720, original_height=1280):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, keypoints))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(image_paths))
    
    # image_dir을 TensorFlow 상수로 변환
    image_dir_tf = tf.constant(image_dir)
    
    if augment_data:
        # 데이터 증강 적용
        dataset = dataset.map(lambda x, y: preprocess_image_aug(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        # 데이터 증강 미적용
        dataset = dataset.map(lambda x, y: preprocess_image(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset
# Out:
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3

# %%
# CSV 파일 경로
train_csv = 'keras_dataset/annotations/train_annotations.csv'
val_csv = 'keras_dataset/annotations/val_annotations.csv'

# 이미지 디렉토리
train_image_dir = 'keras_dataset/images/train'
val_image_dir = 'keras_dataset/images/val'

# 로드된 데이터
train_image_paths, train_keypoints = load_data(train_csv, train_image_dir)
val_image_paths, val_keypoints = load_data(val_csv, val_image_dir)

# 전체 배치 크기 설정
BATCH_SIZE_PER_REPLICA = 16  # 각 GPU당 배치 크기 (메모리 문제를 방지하기 위해 줄임)
GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync  # 전체 배치 크기

# 훈련 및 검증 데이터셋 생성
train_dataset = create_dataset(
    train_image_paths, 
    train_keypoints, 
    train_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=True, 
    augment_data=False,  # 현재 데이터 증강 비활성화
    target_size=224, 
    original_width=720, 
    original_height=1280
)

val_dataset = create_dataset(
    val_image_paths, 
    val_keypoints, 
    val_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=False, 
    augment_data=False, 
    target_size=224, 
    original_width=720, 
    original_height=1280
)

# %% [markdown]
# # 키포인트 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터셋 일부 시각화 (디버깅 용도)
def visualize_sample(image, keypoints, title='Sample', image_size=224):
    image_np = image.numpy()
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np)
    # 키포인트를 224x224 이미지에 맞게 스케일링
    x = keypoints[::2].numpy() * image_size  # [0,1] 범위를 [0,224]로 변환
    y = keypoints[1::2].numpy() * image_size
    plt.scatter(x, y, c='r', s=10)
    plt.title(title)
    plt.axis('off')
    plt.show()

# 데이터셋에서 샘플 가져오기
for images, keypoints in train_dataset.take(1):
    for i in range(3):  # 첫 3개 샘플 시각화
        visualize_sample(images[i], keypoints[i], title=f"Sample {i+1}")

# %%
print("키포인트 최소값:", tf.reduce_min(keypoints))
print("키포인트 최대값:", tf.reduce_max(keypoints))
print("이미지 크기:", images[0].shape)
# Out:
# 키포인트 최소값: tf.Tensor(0.29829842, shape=(), dtype=float32)
# 키포인트 최대값: tf.Tensor(0.9308437, shape=(), dtype=float32)
# 이미지 크기: (224, 224, 3)

# %% [markdown]
# # 모델학습

# %%
import keras
from keras import layers

# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 입력 레이어 정의
    inputs = layers.Input(shape=(224, 224, 3))
    x = preprocess_input(inputs)

    # 백본 모델 로드 (pre-trained MobileNetV3Large)
    base_model = MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    base_model.trainable = True  # 백본 모델을 학습하도록 설정

    x = base_model(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)

    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표 (총 140개 출력)
    # 타겟 값이 [0, 1] 범위로 정규화되었다면 sigmoid 활성화 함수 사용
    x = layers.Dense(NUM_KEYPOINTS * 2, activation='sigmoid', dtype='float32')(x)

    # 모델 정의
    model = keras.Model(inputs=inputs, outputs=x)

    # 모델 컴파일
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 140)               179340
#
# =================================================================
# Total params: 2437324 (9.30 MB)
# Trainable params: 2403212 (9.17 MB)
# Non-trainable params: 34112 (133.25 KB)
# _________________________________________________________________

# %%
len(base_model.layers)
# Out:
# 154

# %%
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import time

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001  # 첫 50 에포크 동안 학습률은 0.001
    else:
        return 0.0001  # 에포크 51부터 100까지 학습률은 0.0005

# 에포크 시간 측정을 위한 콜백 클래스 정의
class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
        
# 콜백 설정
checkpoint = ModelCheckpoint('v2_adam_norm.h5', monitor='val_loss', save_best_only=True, verbose=1)
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)
time_callback = TimeHistory()
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, lr_scheduler_callback, time_callback]
)
# Out:
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2024-11-08 00:18:12.158950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-08 00:18:12.175391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-08 00:18:12.200190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-08 00:18:16.023469: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f2013f73cc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-08 00:18:16.023524: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-11-08 00:18:16.023530: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-11-08 00:18:16.023537: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla T4, Compute Capability 7.5
# 2024-11-08 00:18:16.034563: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-08 00:18:16.168039: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 856/856 [==============================] - ETA: 0s - loss: 6.4661e-04 - mae: 0.0168
# Epoch 1: val_loss improved from inf to 0.10002, saving model to v2_adam_norm.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 198s 156ms/step - loss: 6.4661e-04 - mae: 0.0168 - val_loss: 0.1000 - val_mae: 0.2910 - lr: 0.0010
# Epoch 2/100
# 856/856 [==============================] - ETA: 0s - loss: 1.5794e-04 - mae: 0.0096
# Epoch 2: val_loss improved from 0.10002 to 0.05139, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 128s 150ms/step - loss: 1.5794e-04 - mae: 0.0096 - val_loss: 0.0514 - val_mae: 0.2040 - lr: 0.0010
# Epoch 3/100
# 856/856 [==============================] - ETA: 0s - loss: 1.1814e-04 - mae: 0.0083
# Epoch 3: val_loss improved from 0.05139 to 0.05106, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 141s 164ms/step - loss: 1.1814e-04 - mae: 0.0083 - val_loss: 0.0511 - val_mae: 0.2015 - lr: 0.0010
# Epoch 4/100
# 856/856 [==============================] - ETA: 0s - loss: 9.9186e-05 - mae: 0.0076
# Epoch 4: val_loss did not improve from 0.05106
# 856/856 [==============================] - 123s 143ms/step - loss: 9.9186e-05 - mae: 0.0076 - val_loss: 0.0533 - val_mae: 0.2004 - lr: 0.0010
# Epoch 5/100
# 856/856 [==============================] - ETA: 0s - loss: 8.6149e-05 - mae: 0.0070
# Epoch 5: val_loss improved from 0.05106 to 0.02340, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 124s 144ms/step - loss: 8.6149e-05 - mae: 0.0070 - val_loss: 0.0234 - val_mae: 0.1268 - lr: 0.0010
# Epoch 6/100
# 856/856 [==============================] - ETA: 0s - loss: 7.9329e-05 - mae: 0.0067
# Epoch 6: val_loss improved from 0.02340 to 0.01212, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 123s 143ms/step - loss: 7.9329e-05 - mae: 0.0067 - val_loss: 0.0121 - val_mae: 0.0912 - lr: 0.0010
# Epoch 7/100
# 856/856 [==============================] - ETA: 0s - loss: 7.1913e-05 - mae: 0.0064
# Epoch 7: val_loss did not improve from 0.01212
# 856/856 [==============================] - 122s 142ms/step - loss: 7.1913e-05 - mae: 0.0064 - val_loss: 0.0145 - val_mae: 0.0931 - lr: 0.0010
# Epoch 8/100
# 856/856 [==============================] - ETA: 0s - loss: 6.6862e-05 - mae: 0.0061
# Epoch 8: val_loss improved from 0.01212 to 0.00855, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 122s 142ms/step - loss: 6.6862e-05 - mae: 0.0061 - val_loss: 0.0085 - val_mae: 0.0716 - lr: 0.0010
# Epoch 9/100
# 856/856 [==============================] - ETA: 0s - loss: 6.3353e-05 - mae: 0.0060
# Epoch 9: val_loss did not improve from 0.00855
# 856/856 [==============================] - 125s 145ms/step - loss: 6.3353e-05 - mae: 0.0060 - val_loss: 0.0270 - val_mae: 0.1321 - lr: 0.0010
# Epoch 10/100
# 856/856 [==============================] - ETA: 0s - loss: 6.0176e-05 - mae: 0.0058
# Epoch 10: val_loss did not improve from 0.00855
# 856/856 [==============================] - 126s 147ms/step - loss: 6.0176e-05 - mae: 0.0058 - val_loss: 0.0120 - val_mae: 0.0885 - lr: 0.0010
# Epoch 11/100
# 856/856 [==============================] - ETA: 0s - loss: 5.9113e-05 - mae: 0.0057
# Epoch 11: val_loss did not improve from 0.00855
# 856/856 [==============================] - 125s 146ms/step - loss: 5.9113e-05 - mae: 0.0057 - val_loss: 0.0453 - val_mae: 0.1773 - lr: 0.0010
# Epoch 12/100
# 856/856 [==============================] - ETA: 0s - loss: 5.4048e-05 - mae: 0.0055
# Epoch 12: val_loss did not improve from 0.00855
# 856/856 [==============================] - 122s 141ms/step - loss: 5.4048e-05 - mae: 0.0055 - val_loss: 0.0276 - val_mae: 0.1464 - lr: 0.0010
# Epoch 13/100
# 856/856 [==============================] - ETA: 0s - loss: 5.0620e-05 - mae: 0.0053
# Epoch 13: val_loss did not improve from 0.00855
# 856/856 [==============================] - 123s 143ms/step - loss: 5.0620e-05 - mae: 0.0053 - val_loss: 0.0989 - val_mae: 0.2710 - lr: 0.0010
# Epoch 14/100
# 856/856 [==============================] - ETA: 0s - loss: 4.9843e-05 - mae: 0.0052
# Epoch 14: val_loss did not improve from 0.00855
# 856/856 [==============================] - 124s 144ms/step - loss: 4.9843e-05 - mae: 0.0052 - val_loss: 0.0381 - val_mae: 0.1664 - lr: 0.0010
# Epoch 15/100
# 856/856 [==============================] - ETA: 0s - loss: 4.7537e-05 - mae: 0.0051
# Epoch 15: val_loss improved from 0.00855 to 0.00244, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 120s 140ms/step - loss: 4.7537e-05 - mae: 0.0051 - val_loss: 0.0024 - val_mae: 0.0341 - lr: 0.0010
# Epoch 16/100
# 856/856 [==============================] - ETA: 0s - loss: 4.6739e-05 - mae: 0.0051
# Epoch 16: val_loss did not improve from 0.00244
# 856/856 [==============================] - 117s 137ms/step - loss: 4.6739e-05 - mae: 0.0051 - val_loss: 0.0555 - val_mae: 0.1898 - lr: 0.0010
# Epoch 17/100
# 856/856 [==============================] - ETA: 0s - loss: 4.5255e-05 - mae: 0.0050
# Epoch 17: val_loss did not improve from 0.00244
# 856/856 [==============================] - 120s 140ms/step - loss: 4.5255e-05 - mae: 0.0050 - val_loss: 0.0282 - val_mae: 0.1521 - lr: 0.0010
# Epoch 18/100
# 856/856 [==============================] - ETA: 0s - loss: 4.3803e-05 - mae: 0.0049
# Epoch 18: val_loss did not improve from 0.00244
# 856/856 [==============================] - 121s 141ms/step - loss: 4.3803e-05 - mae: 0.0049 - val_loss: 0.0944 - val_mae: 0.2399 - lr: 0.0010
# Epoch 19/100
# 856/856 [==============================] - ETA: 0s - loss: 4.3017e-05 - mae: 0.0048
# Epoch 19: val_loss did not improve from 0.00244
# 856/856 [==============================] - 120s 140ms/step - loss: 4.3017e-05 - mae: 0.0048 - val_loss: 0.0360 - val_mae: 0.1681 - lr: 0.0010
# Epoch 20/100
# 856/856 [==============================] - ETA: 0s - loss: 4.2039e-05 - mae: 0.0048
# Epoch 20: val_loss did not improve from 0.00244
# 856/856 [==============================] - 122s 142ms/step - loss: 4.2039e-05 - mae: 0.0048 - val_loss: 0.0675 - val_mae: 0.2208 - lr: 0.0010
# Epoch 21/100
# 856/856 [==============================] - ETA: 0s - loss: 4.1227e-05 - mae: 0.0047
# Epoch 21: val_loss did not improve from 0.00244
# 856/856 [==============================] - 123s 143ms/step - loss: 4.1227e-05 - mae: 0.0047 - val_loss: 0.0392 - val_mae: 0.1717 - lr: 0.0010
# Epoch 22/100
# 856/856 [==============================] - ETA: 0s - loss: 4.0313e-05 - mae: 0.0047
# Epoch 22: val_loss did not improve from 0.00244
# 856/856 [==============================] - 127s 148ms/step - loss: 4.0313e-05 - mae: 0.0047 - val_loss: 0.1112 - val_mae: 0.2583 - lr: 0.0010
# Epoch 23/100
# 856/856 [==============================] - ETA: 0s - loss: 3.9054e-05 - mae: 0.0046
# Epoch 23: val_loss did not improve from 0.00244
# 856/856 [==============================] - 121s 141ms/step - loss: 3.9054e-05 - mae: 0.0046 - val_loss: 0.0547 - val_mae: 0.2056 - lr: 0.0010
# Epoch 24/100
# 856/856 [==============================] - ETA: 0s - loss: 3.9438e-05 - mae: 0.0046
# Epoch 24: val_loss did not improve from 0.00244
# 856/856 [==============================] - 120s 139ms/step - loss: 3.9438e-05 - mae: 0.0046 - val_loss: 0.0468 - val_mae: 0.1639 - lr: 0.0010
# Epoch 25/100
# 856/856 [==============================] - ETA: 0s - loss: 3.8278e-05 - mae: 0.0046
# Epoch 25: val_loss did not improve from 0.00244
# 856/856 [==============================] - 122s 141ms/step - loss: 3.8278e-05 - mae: 0.0046 - val_loss: 0.0093 - val_mae: 0.0693 - lr: 0.0010
# Epoch 26/100
# 856/856 [==============================] - ETA: 0s - loss: 3.8034e-05 - mae: 0.0045
# Epoch 26: val_loss did not improve from 0.00244
# 856/856 [==============================] - 122s 142ms/step - loss: 3.8034e-05 - mae: 0.0045 - val_loss: 0.0512 - val_mae: 0.1894 - lr: 0.0010
# Epoch 27/100
# 856/856 [==============================] - ETA: 0s - loss: 3.7170e-05 - mae: 0.0045
# Epoch 27: val_loss did not improve from 0.00244
# 856/856 [==============================] - 121s 140ms/step - loss: 3.7170e-05 - mae: 0.0045 - val_loss: 0.0385 - val_mae: 0.1628 - lr: 0.0010
# Epoch 28/100
# 856/856 [==============================] - ETA: 0s - loss: 3.6832e-05 - mae: 0.0045
# Epoch 28: val_loss did not improve from 0.00244
# 856/856 [==============================] - 120s 140ms/step - loss: 3.6832e-05 - mae: 0.0045 - val_loss: 0.1027 - val_mae: 0.2483 - lr: 0.0010
# Epoch 29/100
# 856/856 [==============================] - ETA: 0s - loss: 3.6239e-05 - mae: 0.0044
# Epoch 29: val_loss did not improve from 0.00244
# 856/856 [==============================] - 124s 144ms/step - loss: 3.6239e-05 - mae: 0.0044 - val_loss: 0.0527 - val_mae: 0.1864 - lr: 0.0010
# Epoch 30/100
# 856/856 [==============================] - ETA: 0s - loss: 3.5766e-05 - mae: 0.0044
# Epoch 30: val_loss did not improve from 0.00244
# 856/856 [==============================] - 122s 142ms/step - loss: 3.5766e-05 - mae: 0.0044 - val_loss: 0.0170 - val_mae: 0.1002 - lr: 0.0010
# Epoch 31/100
# 856/856 [==============================] - ETA: 0s - loss: 3.5627e-05 - mae: 0.0044
# Epoch 31: val_loss did not improve from 0.00244
# 856/856 [==============================] - 122s 142ms/step - loss: 3.5627e-05 - mae: 0.0044 - val_loss: 0.0446 - val_mae: 0.1625 - lr: 0.0010
# Epoch 32/100
# 856/856 [==============================] - ETA: 0s - loss: 3.5181e-05 - mae: 0.0044
# Epoch 32: val_loss improved from 0.00244 to 0.00059, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 123s 143ms/step - loss: 3.5181e-05 - mae: 0.0044 - val_loss: 5.9122e-04 - val_mae: 0.0177 - lr: 0.0010
# Epoch 33/100
# 856/856 [==============================] - ETA: 0s - loss: 3.4634e-05 - mae: 0.0044
# Epoch 33: val_loss did not improve from 0.00059
# 856/856 [==============================] - 125s 145ms/step - loss: 3.4634e-05 - mae: 0.0044 - val_loss: 0.0737 - val_mae: 0.2168 - lr: 0.0010
# Epoch 34/100
# 856/856 [==============================] - ETA: 0s - loss: 3.4346e-05 - mae: 0.0043
# Epoch 34: val_loss did not improve from 0.00059
# 856/856 [==============================] - 124s 144ms/step - loss: 3.4346e-05 - mae: 0.0043 - val_loss: 0.0811 - val_mae: 0.2129 - lr: 0.0010
# Epoch 35/100
# 856/856 [==============================] - ETA: 0s - loss: 3.3910e-05 - mae: 0.0043
# Epoch 35: val_loss did not improve from 0.00059
# 856/856 [==============================] - 122s 142ms/step - loss: 3.3910e-05 - mae: 0.0043 - val_loss: 0.0129 - val_mae: 0.0855 - lr: 0.0010
# Epoch 36/100
# 856/856 [==============================] - ETA: 0s - loss: 3.4195e-05 - mae: 0.0043
# Epoch 36: val_loss did not improve from 0.00059
# 856/856 [==============================] - 122s 142ms/step - loss: 3.4195e-05 - mae: 0.0043 - val_loss: 0.1032 - val_mae: 0.2466 - lr: 0.0010
# Epoch 37/100
# 856/856 [==============================] - ETA: 0s - loss: 3.3417e-05 - mae: 0.0043
# Epoch 37: val_loss did not improve from 0.00059
# 856/856 [==============================] - 126s 147ms/step - loss: 3.3417e-05 - mae: 0.0043 - val_loss: 0.0994 - val_mae: 0.2530 - lr: 0.0010
# Epoch 38/100
# 856/856 [==============================] - ETA: 0s - loss: 3.3187e-05 - mae: 0.0043
# Epoch 38: val_loss did not improve from 0.00059
# 856/856 [==============================] - 125s 146ms/step - loss: 3.3187e-05 - mae: 0.0043 - val_loss: 0.0594 - val_mae: 0.1940 - lr: 0.0010
# Epoch 39/100
# 856/856 [==============================] - ETA: 0s - loss: 3.2646e-05 - mae: 0.0042
# Epoch 39: val_loss did not improve from 0.00059
# 856/856 [==============================] - 128s 149ms/step - loss: 3.2646e-05 - mae: 0.0042 - val_loss: 0.0326 - val_mae: 0.1451 - lr: 0.0010
# Epoch 40/100
# 856/856 [==============================] - ETA: 0s - loss: 3.2721e-05 - mae: 0.0042
# Epoch 40: val_loss did not improve from 0.00059
# 856/856 [==============================] - 124s 144ms/step - loss: 3.2721e-05 - mae: 0.0042 - val_loss: 0.0300 - val_mae: 0.1444 - lr: 0.0010
# Epoch 41/100
# 856/856 [==============================] - ETA: 0s - loss: 3.2350e-05 - mae: 0.0042
# Epoch 41: val_loss did not improve from 0.00059
# 856/856 [==============================] - 125s 146ms/step - loss: 3.2350e-05 - mae: 0.0042 - val_loss: 0.0161 - val_mae: 0.0998 - lr: 0.0010
# Epoch 42/100
# 856/856 [==============================] - ETA: 0s - loss: 3.2216e-05 - mae: 0.0042
# Epoch 42: val_loss did not improve from 0.00059
# 856/856 [==============================] - 125s 145ms/step - loss: 3.2216e-05 - mae: 0.0042 - val_loss: 0.0053 - val_mae: 0.0567 - lr: 0.0010
# Epoch 43/100
# 856/856 [==============================] - ETA: 0s - loss: 3.1861e-05 - mae: 0.0042
# Epoch 43: val_loss did not improve from 0.00059
# 856/856 [==============================] - 124s 145ms/step - loss: 3.1861e-05 - mae: 0.0042 - val_loss: 0.0311 - val_mae: 0.1311 - lr: 0.0010
# Epoch 44/100
# 856/856 [==============================] - ETA: 0s - loss: 3.1884e-05 - mae: 0.0042
# Epoch 44: val_loss did not improve from 0.00059
# 856/856 [==============================] - 124s 145ms/step - loss: 3.1884e-05 - mae: 0.0042 - val_loss: 0.0166 - val_mae: 0.0985 - lr: 0.0010
# Epoch 45/100
# 856/856 [==============================] - ETA: 0s - loss: 3.1355e-05 - mae: 0.0041
# Epoch 45: val_loss did not improve from 0.00059
# 856/856 [==============================] - 123s 143ms/step - loss: 3.1355e-05 - mae: 0.0041 - val_loss: 0.0133 - val_mae: 0.0902 - lr: 0.0010
# Epoch 46/100
# 856/856 [==============================] - ETA: 0s - loss: 3.1252e-05 - mae: 0.0041
# Epoch 46: val_loss did not improve from 0.00059
# 856/856 [==============================] - 128s 149ms/step - loss: 3.1252e-05 - mae: 0.0041 - val_loss: 0.0429 - val_mae: 0.1649 - lr: 0.0010
# Epoch 47/100
# 856/856 [==============================] - ETA: 0s - loss: 3.1081e-05 - mae: 0.0041
# Epoch 47: val_loss did not improve from 0.00059
# 856/856 [==============================] - 124s 145ms/step - loss: 3.1081e-05 - mae: 0.0041 - val_loss: 0.0027 - val_mae: 0.0421 - lr: 0.0010
# Epoch 48/100
# 856/856 [==============================] - ETA: 0s - loss: 3.0807e-05 - mae: 0.0041
# Epoch 48: val_loss did not improve from 0.00059
# 856/856 [==============================] - 129s 149ms/step - loss: 3.0807e-05 - mae: 0.0041 - val_loss: 0.0489 - val_mae: 0.1628 - lr: 0.0010
# Epoch 49/100
# 856/856 [==============================] - ETA: 0s - loss: 3.0601e-05 - mae: 0.0041
# Epoch 49: val_loss did not improve from 0.00059
# 856/856 [==============================] - 121s 141ms/step - loss: 3.0601e-05 - mae: 0.0041 - val_loss: 0.0367 - val_mae: 0.1474 - lr: 0.0010
# Epoch 50/100
# 856/856 [==============================] - ETA: 0s - loss: 3.0642e-05 - mae: 0.0041
# Epoch 50: val_loss did not improve from 0.00059
# 856/856 [==============================] - 126s 147ms/step - loss: 3.0642e-05 - mae: 0.0041 - val_loss: 0.0010 - val_mae: 0.0249 - lr: 0.0010
# Epoch 51/100
# 856/856 [==============================] - ETA: 0s - loss: 2.6696e-05 - mae: 0.0038
# Epoch 51: val_loss improved from 0.00059 to 0.00048, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 123s 143ms/step - loss: 2.6696e-05 - mae: 0.0038 - val_loss: 4.8362e-04 - val_mae: 0.0183 - lr: 1.0000e-04
# Epoch 52/100
# 856/856 [==============================] - ETA: 0s - loss: 2.6065e-05 - mae: 0.0038
# Epoch 52: val_loss improved from 0.00048 to 0.00011, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 130s 152ms/step - loss: 2.6065e-05 - mae: 0.0038 - val_loss: 1.0819e-04 - val_mae: 0.0080 - lr: 1.0000e-04
# Epoch 53/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5906e-05 - mae: 0.0038
# Epoch 53: val_loss improved from 0.00011 to 0.00006, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 129s 149ms/step - loss: 2.5906e-05 - mae: 0.0038 - val_loss: 5.5610e-05 - val_mae: 0.0051 - lr: 1.0000e-04
# Epoch 54/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5630e-05 - mae: 0.0037
# Epoch 54: val_loss did not improve from 0.00006
# 856/856 [==============================] - 132s 154ms/step - loss: 2.5630e-05 - mae: 0.0037 - val_loss: 8.9219e-05 - val_mae: 0.0071 - lr: 1.0000e-04
# Epoch 55/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5493e-05 - mae: 0.0037
# Epoch 55: val_loss did not improve from 0.00006
# 856/856 [==============================] - 120s 140ms/step - loss: 2.5493e-05 - mae: 0.0037 - val_loss: 1.2672e-04 - val_mae: 0.0088 - lr: 1.0000e-04
# Epoch 56/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5346e-05 - mae: 0.0037
# Epoch 56: val_loss did not improve from 0.00006
# 856/856 [==============================] - 122s 142ms/step - loss: 2.5346e-05 - mae: 0.0037 - val_loss: 1.6813e-04 - val_mae: 0.0103 - lr: 1.0000e-04
# Epoch 57/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5229e-05 - mae: 0.0037
# Epoch 57: val_loss did not improve from 0.00006
# 856/856 [==============================] - 123s 144ms/step - loss: 2.5229e-05 - mae: 0.0037 - val_loss: 1.7196e-04 - val_mae: 0.0101 - lr: 1.0000e-04
# Epoch 58/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5078e-05 - mae: 0.0037
# Epoch 58: val_loss did not improve from 0.00006
# 856/856 [==============================] - 121s 140ms/step - loss: 2.5078e-05 - mae: 0.0037 - val_loss: 1.0978e-04 - val_mae: 0.0081 - lr: 1.0000e-04
# Epoch 59/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5173e-05 - mae: 0.0037
# Epoch 59: val_loss did not improve from 0.00006
# 856/856 [==============================] - 123s 143ms/step - loss: 2.5173e-05 - mae: 0.0037 - val_loss: 8.9147e-04 - val_mae: 0.0247 - lr: 1.0000e-04
# Epoch 60/100
# 856/856 [==============================] - ETA: 0s - loss: 2.5056e-05 - mae: 0.0037
# Epoch 60: val_loss did not improve from 0.00006
# 856/856 [==============================] - 120s 139ms/step - loss: 2.5056e-05 - mae: 0.0037 - val_loss: 0.0028 - val_mae: 0.0430 - lr: 1.0000e-04
# Epoch 61/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4856e-05 - mae: 0.0037
# Epoch 61: val_loss did not improve from 0.00006
# 856/856 [==============================] - 122s 142ms/step - loss: 2.4856e-05 - mae: 0.0037 - val_loss: 3.2143e-04 - val_mae: 0.0144 - lr: 1.0000e-04
# Epoch 62/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4832e-05 - mae: 0.0037
# Epoch 62: val_loss did not improve from 0.00006
# 856/856 [==============================] - 122s 143ms/step - loss: 2.4832e-05 - mae: 0.0037 - val_loss: 1.9005e-04 - val_mae: 0.0109 - lr: 1.0000e-04
# Epoch 63/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4824e-05 - mae: 0.0037
# Epoch 63: val_loss did not improve from 0.00006
# 856/856 [==============================] - 122s 142ms/step - loss: 2.4824e-05 - mae: 0.0037 - val_loss: 2.9799e-04 - val_mae: 0.0140 - lr: 1.0000e-04
# Epoch 64/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4727e-05 - mae: 0.0037
# Epoch 64: val_loss did not improve from 0.00006
# 856/856 [==============================] - 123s 143ms/step - loss: 2.4727e-05 - mae: 0.0037 - val_loss: 2.9728e-04 - val_mae: 0.0139 - lr: 1.0000e-04
# Epoch 65/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4699e-05 - mae: 0.0037
# Epoch 65: val_loss did not improve from 0.00006
# 856/856 [==============================] - 123s 143ms/step - loss: 2.4699e-05 - mae: 0.0037 - val_loss: 1.3171e-04 - val_mae: 0.0092 - lr: 1.0000e-04
# Epoch 66/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4583e-05 - mae: 0.0037
# Epoch 66: val_loss did not improve from 0.00006
# 856/856 [==============================] - 122s 142ms/step - loss: 2.4583e-05 - mae: 0.0037 - val_loss: 9.4565e-05 - val_mae: 0.0071 - lr: 1.0000e-04
# Epoch 67/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4505e-05 - mae: 0.0037
# Epoch 67: val_loss did not improve from 0.00006
# 856/856 [==============================] - 118s 138ms/step - loss: 2.4505e-05 - mae: 0.0037 - val_loss: 6.6090e-04 - val_mae: 0.0213 - lr: 1.0000e-04
# Epoch 68/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4522e-05 - mae: 0.0037
# Epoch 68: val_loss did not improve from 0.00006
# 856/856 [==============================] - 120s 140ms/step - loss: 2.4522e-05 - mae: 0.0037 - val_loss: 7.5485e-05 - val_mae: 0.0065 - lr: 1.0000e-04
# Epoch 69/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4533e-05 - mae: 0.0037
# Epoch 69: val_loss did not improve from 0.00006
# 856/856 [==============================] - 125s 146ms/step - loss: 2.4533e-05 - mae: 0.0037 - val_loss: 8.9263e-05 - val_mae: 0.0072 - lr: 1.0000e-04
# Epoch 70/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4528e-05 - mae: 0.0037
# Epoch 70: val_loss did not improve from 0.00006
# 856/856 [==============================] - 123s 143ms/step - loss: 2.4528e-05 - mae: 0.0037 - val_loss: 1.2046e-04 - val_mae: 0.0084 - lr: 1.0000e-04
# Epoch 71/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4367e-05 - mae: 0.0037
# Epoch 71: val_loss improved from 0.00006 to 0.00005, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 124s 144ms/step - loss: 2.4367e-05 - mae: 0.0037 - val_loss: 5.1456e-05 - val_mae: 0.0051 - lr: 1.0000e-04
# Epoch 72/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4275e-05 - mae: 0.0037
# Epoch 72: val_loss did not improve from 0.00005
# 856/856 [==============================] - 124s 144ms/step - loss: 2.4275e-05 - mae: 0.0037 - val_loss: 1.2828e-04 - val_mae: 0.0089 - lr: 1.0000e-04
# Epoch 73/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4312e-05 - mae: 0.0037
# Epoch 73: val_loss did not improve from 0.00005
# 856/856 [==============================] - 121s 141ms/step - loss: 2.4312e-05 - mae: 0.0037 - val_loss: 1.1459e-04 - val_mae: 0.0083 - lr: 1.0000e-04
# Epoch 74/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4176e-05 - mae: 0.0037
# Epoch 74: val_loss did not improve from 0.00005
# 856/856 [==============================] - 123s 143ms/step - loss: 2.4176e-05 - mae: 0.0037 - val_loss: 5.4554e-04 - val_mae: 0.0192 - lr: 1.0000e-04
# Epoch 75/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4167e-05 - mae: 0.0037
# Epoch 75: val_loss did not improve from 0.00005
# 856/856 [==============================] - 122s 143ms/step - loss: 2.4167e-05 - mae: 0.0037 - val_loss: 1.7392e-04 - val_mae: 0.0102 - lr: 1.0000e-04
# Epoch 76/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4245e-05 - mae: 0.0037
# Epoch 76: val_loss did not improve from 0.00005
# 856/856 [==============================] - 126s 146ms/step - loss: 2.4245e-05 - mae: 0.0037 - val_loss: 7.8868e-05 - val_mae: 0.0067 - lr: 1.0000e-04
# Epoch 77/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4134e-05 - mae: 0.0037
# Epoch 77: val_loss did not improve from 0.00005
# 856/856 [==============================] - 125s 145ms/step - loss: 2.4134e-05 - mae: 0.0037 - val_loss: 7.1491e-04 - val_mae: 0.0220 - lr: 1.0000e-04
# Epoch 78/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4248e-05 - mae: 0.0037
# Epoch 78: val_loss did not improve from 0.00005
# 856/856 [==============================] - 126s 147ms/step - loss: 2.4248e-05 - mae: 0.0037 - val_loss: 5.4947e-04 - val_mae: 0.0183 - lr: 1.0000e-04
# Epoch 79/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4089e-05 - mae: 0.0036
# Epoch 79: val_loss did not improve from 0.00005
# 856/856 [==============================] - 125s 145ms/step - loss: 2.4089e-05 - mae: 0.0036 - val_loss: 5.9899e-05 - val_mae: 0.0056 - lr: 1.0000e-04
# Epoch 80/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4045e-05 - mae: 0.0036
# Epoch 80: val_loss did not improve from 0.00005
# 856/856 [==============================] - 123s 143ms/step - loss: 2.4045e-05 - mae: 0.0036 - val_loss: 7.9374e-04 - val_mae: 0.0228 - lr: 1.0000e-04
# Epoch 81/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4018e-05 - mae: 0.0036
# Epoch 81: val_loss did not improve from 0.00005
# 856/856 [==============================] - 126s 146ms/step - loss: 2.4018e-05 - mae: 0.0036 - val_loss: 6.7195e-05 - val_mae: 0.0061 - lr: 1.0000e-04
# Epoch 82/100
# 856/856 [==============================] - ETA: 0s - loss: 2.4053e-05 - mae: 0.0036
# Epoch 82: val_loss did not improve from 0.00005
# 856/856 [==============================] - 128s 149ms/step - loss: 2.4053e-05 - mae: 0.0036 - val_loss: 1.1374e-04 - val_mae: 0.0083 - lr: 1.0000e-04
# Epoch 83/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3953e-05 - mae: 0.0036
# Epoch 83: val_loss did not improve from 0.00005
# 856/856 [==============================] - 125s 145ms/step - loss: 2.3953e-05 - mae: 0.0036 - val_loss: 0.0015 - val_mae: 0.0320 - lr: 1.0000e-04
# Epoch 84/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3958e-05 - mae: 0.0036
# Epoch 84: val_loss did not improve from 0.00005
# 856/856 [==============================] - 127s 147ms/step - loss: 2.3958e-05 - mae: 0.0036 - val_loss: 1.1623e-04 - val_mae: 0.0083 - lr: 1.0000e-04
# Epoch 85/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3998e-05 - mae: 0.0036
# Epoch 85: val_loss did not improve from 0.00005
# 856/856 [==============================] - 123s 143ms/step - loss: 2.3998e-05 - mae: 0.0036 - val_loss: 1.1542e-04 - val_mae: 0.0080 - lr: 1.0000e-04
# Epoch 86/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3974e-05 - mae: 0.0036
# Epoch 86: val_loss did not improve from 0.00005
# 856/856 [==============================] - 127s 148ms/step - loss: 2.3974e-05 - mae: 0.0036 - val_loss: 1.2242e-04 - val_mae: 0.0087 - lr: 1.0000e-04
# Epoch 87/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3843e-05 - mae: 0.0036
# Epoch 87: val_loss did not improve from 0.00005
# 856/856 [==============================] - 122s 142ms/step - loss: 2.3843e-05 - mae: 0.0036 - val_loss: 0.0017 - val_mae: 0.0336 - lr: 1.0000e-04
# Epoch 88/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3821e-05 - mae: 0.0036
# Epoch 88: val_loss did not improve from 0.00005
# 856/856 [==============================] - 126s 147ms/step - loss: 2.3821e-05 - mae: 0.0036 - val_loss: 9.5982e-05 - val_mae: 0.0075 - lr: 1.0000e-04
# Epoch 89/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3785e-05 - mae: 0.0036
# Epoch 89: val_loss did not improve from 0.00005
# 856/856 [==============================] - 124s 144ms/step - loss: 2.3785e-05 - mae: 0.0036 - val_loss: 8.9012e-05 - val_mae: 0.0073 - lr: 1.0000e-04
# Epoch 90/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3729e-05 - mae: 0.0036
# Epoch 90: val_loss did not improve from 0.00005
# 856/856 [==============================] - 125s 145ms/step - loss: 2.3729e-05 - mae: 0.0036 - val_loss: 5.8719e-05 - val_mae: 0.0056 - lr: 1.0000e-04
# Epoch 91/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3623e-05 - mae: 0.0036
# Epoch 91: val_loss did not improve from 0.00005
# 856/856 [==============================] - 130s 151ms/step - loss: 2.3623e-05 - mae: 0.0036 - val_loss: 2.4308e-04 - val_mae: 0.0126 - lr: 1.0000e-04
# Epoch 92/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3603e-05 - mae: 0.0036
# Epoch 92: val_loss improved from 0.00005 to 0.00005, saving model to v2_adam_norm.h5
# 856/856 [==============================] - 127s 148ms/step - loss: 2.3603e-05 - mae: 0.0036 - val_loss: 4.7635e-05 - val_mae: 0.0049 - lr: 1.0000e-04
# Epoch 93/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3699e-05 - mae: 0.0036
# Epoch 93: val_loss did not improve from 0.00005
# 856/856 [==============================] - 128s 149ms/step - loss: 2.3699e-05 - mae: 0.0036 - val_loss: 7.7615e-05 - val_mae: 0.0064 - lr: 1.0000e-04
# Epoch 94/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3626e-05 - mae: 0.0036
# Epoch 94: val_loss did not improve from 0.00005
# 856/856 [==============================] - 131s 152ms/step - loss: 2.3626e-05 - mae: 0.0036 - val_loss: 7.7970e-05 - val_mae: 0.0066 - lr: 1.0000e-04
# Epoch 95/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3605e-05 - mae: 0.0036
# Epoch 95: val_loss did not improve from 0.00005
# 856/856 [==============================] - 123s 143ms/step - loss: 2.3605e-05 - mae: 0.0036 - val_loss: 1.7587e-04 - val_mae: 0.0104 - lr: 1.0000e-04
# Epoch 96/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3612e-05 - mae: 0.0036
# Epoch 96: val_loss did not improve from 0.00005
# 856/856 [==============================] - 122s 142ms/step - loss: 2.3612e-05 - mae: 0.0036 - val_loss: 5.5310e-05 - val_mae: 0.0054 - lr: 1.0000e-04
# Epoch 97/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3544e-05 - mae: 0.0036
# Epoch 97: val_loss did not improve from 0.00005
# 856/856 [==============================] - 122s 142ms/step - loss: 2.3544e-05 - mae: 0.0036 - val_loss: 2.6020e-04 - val_mae: 0.0126 - lr: 1.0000e-04
# Epoch 98/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3561e-05 - mae: 0.0036
# Epoch 98: val_loss did not improve from 0.00005
# 856/856 [==============================] - 120s 140ms/step - loss: 2.3561e-05 - mae: 0.0036 - val_loss: 0.0016 - val_mae: 0.0323 - lr: 1.0000e-04
# Epoch 99/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3602e-05 - mae: 0.0036
# Epoch 99: val_loss did not improve from 0.00005
# 856/856 [==============================] - 121s 141ms/step - loss: 2.3602e-05 - mae: 0.0036 - val_loss: 7.2871e-04 - val_mae: 0.0219 - lr: 1.0000e-04
# Epoch 100/100
# 856/856 [==============================] - ETA: 0s - loss: 2.3519e-05 - mae: 0.0036
# Epoch 100: val_loss did not improve from 0.00005
# 856/856 [==============================] - 121s 141ms/step - loss: 2.3519e-05 - mae: 0.0036 - val_loss: 8.3703e-05 - val_mae: 0.0069 - lr: 1.0000e-04

# %%
# 평균 에포크 시간 계산 및 출력
average_epoch_time = np.mean(time_callback.times)
print(f"에포크당 평균 소요 시간: {average_epoch_time:.2f}초")
# Out:
# 에포크당 평균 소요 시간: 124.60초

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'][50:], label='Train Loss')
plt.plot(history.history['val_loss'][50:], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'][50:], label='Train MAE')
plt.plot(history.history['val_mae'][50:], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()

# %%
b_m = tf.keras.models.load_model('v2_adam_norm.h5')

# %%
def plot_predicted_keypoints(model, image_path, image_dir, target_size=224):
    """
    모델을 사용하여 이미지의 키포인트를 예측하고 시각화하는 함수.

    Parameters:
        model (tf.keras.Model): 사전 학습된 모델.
        image_path (str): 예측할 이미지의 경로.
        image_dir (str): 이미지가 저장된 디렉토리 경로.
        target_size (int): 모델의 입력 이미지 크기.
    """
    # 이미지 로드 및 전처리
    image_full_path = os.path.join(image_dir, image_path)
    image = cv2.imread(image_full_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_full_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    orig_h, orig_w = image_rgb.shape[:2]

    # 이미지 전처리 (학습 시 사용한 방식과 동일하게)
    # 종횡비 유지하며 리사이즈
    scale = min(target_size / orig_w, target_size / orig_h)
    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)
    image_resized = cv2.resize(image_rgb, (new_w, new_h))

    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_w = target_size - new_w
    pad_h = target_size - new_h
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top

    image_padded = cv2.copyMakeBorder(
        image_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=0
    )

    # 이미지 흑백 변환 및 3채널로 확장 (모델 학습 시에 흑백 이미지를 사용한 경우)
    image_gray = cv2.cvtColor(image_padded, cv2.COLOR_RGB2GRAY)
    print(image_gray.shape)
    image_input = cv2.cvtColor(image_gray, cv2.COLOR_GRAY2RGB)
    print(image_input.shape)
    
    # 정규화 및 배치 차원 추가
    input_image = image_input / 255.0
    input_image = np.expand_dims(input_image, axis=0).astype(np.float32)

    # 예측
    predicted_keypoints = model.predict(input_image)[0]

    # 모델 출력이 [0,1] 범위이므로, 이를 [0, target_size]로 변환
    predicted_keypoints = predicted_keypoints * target_size

    # 패딩 제거 및 원본 이미지 크기로 복원
    predicted_keypoints[::2] = (predicted_keypoints[::2] - pad_left) / scale
    predicted_keypoints[1::2] = (predicted_keypoints[1::2] - pad_top) / scale

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)

    num_keypoints = len(predicted_keypoints) // 2

    for i in range(num_keypoints):
        x = predicted_keypoints[2 * i]
        y = predicted_keypoints[2 * i + 1]
        # 키포인트가 이미지 범위 내에 있는지 확인
        if 0 <= x < orig_w and 0 <= y < orig_h:
            plt.scatter(x, y, c='r', s=10)
        else:
            print(f"키포인트 {i}가 이미지 범위를 벗어났습니다: ({x}, {y})")

    plt.title('Predicted Keypoints')
    plt.axis('off')
    plt.show()

# 예측 및 시각화
sample_image_path = val_image_paths[55]
plot_predicted_keypoints(b_m, sample_image_path, val_image_dir)
# Out:
# (224, 224)
# (224, 224, 3)
# 1/1 [==============================] - 2s 2s/step
