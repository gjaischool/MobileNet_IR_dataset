# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow_addons as tfa
from tensorflow.keras import mixed_precision
# Out:
# 2024-10-29 02:43:03.382311: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 02:43:03.446443: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 02:43:03.446489: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 02:43:03.446529: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 02:43:03.458659: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 02:43:04.639170: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jovyan/.local/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # 데이터셋 로더

# %%
# **1. GPU 메모리 성장 설정 (가장 먼저 실행)**
physical_devices = tf.config.list_physical_devices('GPU')
for gpu in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"메모리 성장 설정 완료: {gpu}")
    except RuntimeError as e:
        print(f"메모리 성장 설정 실패: {gpu} - {e}")

# **2. 분산 전략 설정**
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# **3. Mixed Precision 비활성화**
policy = mixed_precision.Policy('float32')
mixed_precision.set_global_policy(policy)

# **4. 데이터셋 로더 함수**
def load_data(csv_file, image_dir):
    df = pd.read_csv(csv_file)
    image_paths = df['image_path'].tolist()
    keypoints = df.iloc[:, 1:].values.astype(np.float32)
    return image_paths, keypoints

# **5. 키포인트 스케일링 함수 정의**
def scale_keypoints(keypoints, original_width=720, original_height=1280, target_size=224):
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    x_scale = target_size / original_width
    y_scale = target_size / original_height
    x_scaled = x_coords * x_scale
    y_scaled = y_coords * y_scale
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    return scaled_keypoints

# **6. 데이터 증강 함수 정의 (현재 사용 안 함)**
def augment(image, keypoints):
    # 랜덤 회전
    angle = tf.random.uniform([], -15, 15, dtype=tf.float32)
    angle_rad = angle * np.pi / 180.0
    image = tfa.image.rotate(image, angles=angle_rad, fill_mode='nearest')
    
    # 키포인트 회전
    center_x = 720.0 / 2 * (224 / 720.0)  # 224x224 이미지 기준 (720 -> 224)
    center_y = 1280.0 / 2 * (224 / 1280.0)  # 1280 -> 224
    rotation_matrix = tf.reshape([
        tf.cos(angle_rad), -tf.sin(angle_rad),
        tf.sin(angle_rad), tf.cos(angle_rad)
    ], [2, 2])
    keypoints = tf.reshape(keypoints, [NUM_KEYPOINTS, 2])
    keypoints = tf.matmul(keypoints - tf.constant([center_x, center_y]), rotation_matrix) + tf.constant([center_x, center_y])
    keypoints = tf.reshape(keypoints, [-1])
    
    return image, keypoints

# **7. 이미지 및 키포인트 전처리 함수 (종횡비 유지 및 패딩 추가)**
def preprocess_image(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    """
    이미지와 키포인트를 전처리하는 함수.

    Parameters:
        image_path (tf.Tensor): 이미지 파일 경로.
        keypoints (tf.Tensor): 키포인트 좌표.
        image_dir (tf.Tensor): 이미지가 저장된 디렉토리 경로.
        target_size (int): 모델 입력 이미지의 크기.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.

    Returns:
        image (tf.Tensor): 전처리된 이미지.
        scaled_keypoints (tf.Tensor): 스케일 조정된 키포인트 좌표.
    """
    # 이미지 경로 결합
    image_full_path = tf.strings.join([image_dir, '/', image_path])
    
    # 이미지 로드 및 디코드
    image = tf.io.read_file(image_full_path)
    image = tf.image.decode_jpeg(image, channels=3)
    
    # 이미지가 정상적으로 로드되었는지 확인하고, float32로 변환 및 [0,1] 범위로 스케일링
    image = tf.cond(tf.equal(tf.size(image), 0),
                   lambda: tf.zeros([target_size, target_size, 3], dtype=tf.float32),
                   lambda: tf.image.convert_image_dtype(image, tf.float32))
    
    # 원본 크기 가져오기
    orig_shape = tf.shape(image)[:2]
    orig_height_img = tf.cast(orig_shape[0], tf.float32)
    orig_width_img = tf.cast(orig_shape[1], tf.float32)
    
    # 종횡비 유지하며 리사이징
    scale = tf.minimum(target_size / orig_width_img, target_size / orig_height_img)
    new_width = tf.cast(tf.round(orig_width_img * scale), tf.int32)
    new_height = tf.cast(tf.round(orig_height_img * scale), tf.int32)
    
    image = tf.image.resize(image, [new_height, new_width])
    
    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_width = target_size - new_width
    pad_height = target_size - new_height
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    
    image = tf.pad(image, [[pad_top, pad_bottom], [pad_left, pad_right], [0, 0]], constant_values=0)
    
    # 키포인트 스케일 조정 및 이동
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    
    # 스케일링
    x_scale = scale
    y_scale = scale
    
    x_scaled = x_coords * x_scale + tf.cast(pad_left, tf.float32)
    y_scaled = y_coords * y_scale + tf.cast(pad_top, tf.float32)
    
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    
    return image, scaled_keypoints

# **8. 데이터셋 전처리 및 증강 함수**
def preprocess_image_aug(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    image, keypoints = preprocess_image(image_path, keypoints, image_dir, target_size, original_width, original_height)
    image, keypoints = augment(image, keypoints)
    return image, keypoints

# **9. 데이터셋 생성 함수 수정**
def create_dataset(image_paths, keypoints, image_dir, batch_size=64, shuffle=True, augment_data=False, target_size=224, original_width=720, original_height=1280):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, keypoints))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(image_paths))
    
    # image_dir을 TensorFlow 상수로 변환
    image_dir_tf = tf.constant(image_dir)
    
    if augment_data:
        # 데이터 증강 적용
        dataset = dataset.map(lambda x, y: preprocess_image_aug(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        # 데이터 증강 미적용
        dataset = dataset.map(lambda x, y: preprocess_image(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset
# Out:
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3
# 2024-10-29 02:43:06.685533: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.689545: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.693288: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.748963: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.752732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.756317: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.760298: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.763976: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:06.767543: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.601054: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.603199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.605213: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.607190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.609146: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.611024: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.612883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.614839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.616721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.647944: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.649964: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.651897: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.653779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.655726: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.657629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.659508: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.661427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:08.0, compute capability: 7.5
# 2024-10-29 02:43:07.661918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.663797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13775 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5
# 2024-10-29 02:43:07.664173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 02:43:07.666028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 13775 MB memory:  -> device: 2, name: Tesla T4, pci bus id: 0000:00:0a.0, compute capability: 7.5

# %%
# CSV 파일 경로
train_csv = 'keras_dataset/annotations/train_annotations.csv'
val_csv = 'keras_dataset/annotations/val_annotations.csv'

# 이미지 디렉토리
train_image_dir = 'keras_dataset/images/train'
val_image_dir = 'keras_dataset/images/val'

# 로드된 데이터
train_image_paths, train_keypoints = load_data(train_csv, train_image_dir)
val_image_paths, val_keypoints = load_data(val_csv, val_image_dir)

# 전체 배치 크기 설정
BATCH_SIZE_PER_REPLICA = 16  # 각 GPU당 배치 크기 (메모리 문제를 방지하기 위해 줄임)
GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync  # 전체 배치 크기

# 훈련 및 검증 데이터셋 생성
train_dataset = create_dataset(
    train_image_paths, 
    train_keypoints, 
    train_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=True, 
    augment_data=False,  # 현재 데이터 증강 비활성화
    target_size=224, 
    original_width=720, 
    original_height=1280
)

val_dataset = create_dataset(
    val_image_paths, 
    val_keypoints, 
    val_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=False, 
    augment_data=False, 
    target_size=224, 
    original_width=720, 
    original_height=1280
)

# %% [markdown]
# # 키포인트 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터셋 일부 시각화 (디버깅 용도)
def visualize_sample(image, keypoints, title='Sample'):
    image_np = image.numpy()
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np)
    # 키포인트를 224x224 이미지에 맞게 그리기
    x = keypoints[::2].numpy()
    y = keypoints[1::2].numpy()
    plt.scatter(x, y, c='r', s=10)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# 데이터셋에서 샘플 가져오기
for images, keypoints in train_dataset.take(1):
    for i in range(3):  # 첫 3개 샘플 시각화
        visualize_sample(images[i], keypoints[i], title=f"Sample {i+1}")

# %% [markdown]
# # 모델학습

# %%
import keras


# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 백본 모델 로드 (pre-trained MobileNetV3Small)
    base_model = MobileNetV3Small(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # 백본 모델 학습
    base_model.trainable = True
    
    # 글로벌 풀링
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    
    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표
    x = Dense(NUM_KEYPOINTS * 2, activation='linear', dtype='float32')(x)  # mixed precision 시 출력 dtype 설정
    
    # 모델 정의
    model = Model(inputs=base_model.input, outputs=x)
    
    # 모델 컴파일
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add (TFOpLambda)    (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#
#  re_lu (ReLU)                (None, 112, 112, 16)         0         ['tf.math.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 112, 112, 16)         0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_1[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_1 (TFOpLambda)  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#                                                                     /Conv_1[0][0]']
#
#  re_lu_2 (ReLU)              (None, 1, 1, 16)             0         ['tf.math.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 16)             0         ['re_lu_2[0][0]']
#  mbda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_1[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_3 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_3[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_4 (ReLU)              (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_4[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_5 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_6 (ReLU)              (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_6[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_2 (TFOpLambda)  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_7 (ReLU)              (None, 28, 28, 96)           0         ['tf.math.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 28, 28, 96)           0         ['re_lu_7[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_3 (TFOpLambda)  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_8 (ReLU)              (None, 14, 14, 96)           0         ['tf.math.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 14, 14, 96)           0         ['re_lu_8[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_3[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_2[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_4 (TFOpLambda)  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_9 (ReLU)              (None, 1, 1, 96)             0         ['tf.math.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None, 1, 1, 96)             0         ['re_lu_9[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_2[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_5 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_10 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_10[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_6 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_11 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_11[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_4[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_7 (TFOpLambda)  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_12 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 1, 1, 240)            0         ['re_lu_12[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_4[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_8 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_13 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_13[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_9 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_14 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_14[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_6[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_10 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_15 (ReLU)             (None, 1, 1, 240)            0         ['tf.math.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_15[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_6[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_11 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_16[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_12 (TFOpLambda  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 120)          0         ['tf.math.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpL  (None, 14, 14, 120)          0         ['re_lu_17[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_8[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_13 (TFOpLambda  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_18 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_18[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_8[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_14 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_14[0][0]']
#
#  tf.math.multiply_14 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_19[0][0]']
#  ambda)
#
#  multiply_9 (Multiply)       (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_15 (TFOpLambda  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 144)          0         ['tf.math.add_15[0][0]']
#
#  tf.math.multiply_15 (TFOpL  (None, 14, 14, 144)          0         ['re_lu_20[0][0]']
#  ambda)
#
#  multiply_10 (Multiply)      (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_16 (TFOpLambda  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_21 (ReLU)             (None, 1, 1, 144)            0         ['tf.math.add_16[0][0]']
# ...
#  ambda)
#
#  multiply_13 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_20[0][0]']
#
#  expanded_conv_9/depthwise   (None, 7, 7, 576)            14400     ['multiply_13[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 7, 7, 576)            2304      ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_21 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_26 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_26[0][0]']
#  ambda)
#
#  multiply_14 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_21[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_14[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_22 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_27 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_27[0][0]']
#  ambda)
#
#  expanded_conv_9/squeeze_ex  (None, 7, 7, 576)            0         ['multiply_14[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_22[0][0]']
#
#  expanded_conv_9/project (C  (None, 7, 7, 96)             55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, 7, 7, 96)             384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 7, 7, 96)             0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 7, 7, 576)            55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 7, 7, 576)            2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_23 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#  )                                                                  hNorm[0][0]']
#
#  re_lu_28 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_28[0][0]']
#  ambda)
#
#  multiply_15 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_23[0][0]']
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_15[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_24 (TFOpLambda  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_29 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_29[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_25 (TFOpLambda  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_30 (ReLU)             (None, 1, 1, 576)            0         ['tf.math.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpL  (None, 1, 1, 576)            0         ['re_lu_30[0][0]']
#  ambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_25[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_26 (TFOpLambda  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  )
#
#  re_lu_31 (ReLU)             (None, 7, 7, 576)            0         ['tf.math.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpL  (None, 7, 7, 576)            0         ['re_lu_31[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_26[0][0]']
#
#  global_average_pooling2d (  (None, 576)                  0         ['multiply_17[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 576)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 140)                  80780     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1019900 (3.89 MB)
# Trainable params: 1007788 (3.84 MB)
# Non-trainable params: 12112 (47.31 KB)
# __________________________________________________________________________________________________

# %%
len(base_model.layers)
# Out:
# 229

# %%
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import time

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001  # 첫 50 에포크 동안 학습률은 0.001
    else:
        return 0.0005  # 에포크 51부터 100까지 학습률은 0.0005

# 에포크 시간 측정을 위한 콜백 클래스 정의
class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
        
# 콜백 설정
checkpoint = ModelCheckpoint('v3s_b16_lr001.h5', monitor='val_loss', save_best_only=True, verbose=1)
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)
time_callback = TimeHistory()
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, lr_scheduler_callback, time_callback]
)
# Out:
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 140 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 140 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2024-10-29 02:43:56.476024: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 02:43:56.492524: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 02:43:56.507436: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 02:44:00.176214: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8f4a90ee50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-29 02:44:00.176256: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-10-29 02:44:00.176262: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-10-29 02:44:00.176267: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla T4, Compute Capability 7.5
# 2024-10-29 02:44:00.184882: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-29 02:44:00.304210: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 856/856 [==============================] - ETA: 0s - loss: 1322.1003 - mae: 21.1212
# Epoch 1: val_loss improved from inf to 19669.09570, saving model to v3s_b16_lr001.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 191s 157ms/step - loss: 1322.1003 - mae: 21.1212 - val_loss: 19669.0957 - val_mae: 137.4412 - lr: 0.0010
# Epoch 2/100
# 855/856 [============================>.] - ETA: 0s - loss: 74.5305 - mae: 6.7244
# Epoch 2: val_loss improved from 19669.09570 to 19511.95508, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 131s 152ms/step - loss: 74.5240 - mae: 6.7241 - val_loss: 19511.9551 - val_mae: 136.8406 - lr: 0.0010
# Epoch 3/100
# 855/856 [============================>.] - ETA: 0s - loss: 58.9663 - mae: 6.0432
# Epoch 3: val_loss improved from 19511.95508 to 19312.76367, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 129s 150ms/step - loss: 58.9658 - mae: 6.0433 - val_loss: 19312.7637 - val_mae: 136.0926 - lr: 0.0010
# Epoch 4/100
# 855/856 [============================>.] - ETA: 0s - loss: 54.4574 - mae: 5.8133
# Epoch 4: val_loss improved from 19312.76367 to 2608.67700, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 127s 148ms/step - loss: 54.4644 - mae: 5.8137 - val_loss: 2608.6770 - val_mae: 46.7437 - lr: 0.0010
# Epoch 5/100
# 855/856 [============================>.] - ETA: 0s - loss: 51.3757 - mae: 5.6479
# Epoch 5: val_loss improved from 2608.67700 to 1875.94800, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 129s 150ms/step - loss: 51.3878 - mae: 5.6486 - val_loss: 1875.9480 - val_mae: 41.5038 - lr: 0.0010
# Epoch 6/100
# 855/856 [============================>.] - ETA: 0s - loss: 48.7986 - mae: 5.4952
# Epoch 6: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 129s 151ms/step - loss: 48.8028 - mae: 5.4954 - val_loss: 9434.6035 - val_mae: 95.2791 - lr: 0.0010
# Epoch 7/100
# 855/856 [============================>.] - ETA: 0s - loss: 47.8401 - mae: 5.4374
# Epoch 7: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 129s 150ms/step - loss: 47.8413 - mae: 5.4375 - val_loss: 8590.8574 - val_mae: 91.4063 - lr: 0.0010
# Epoch 8/100
# 855/856 [============================>.] - ETA: 0s - loss: 46.5066 - mae: 5.3623
# Epoch 8: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 129s 150ms/step - loss: 46.5186 - mae: 5.3629 - val_loss: 1996.3759 - val_mae: 34.4718 - lr: 0.0010
# Epoch 9/100
# 855/856 [============================>.] - ETA: 0s - loss: 45.9914 - mae: 5.3285
# Epoch 9: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 129s 150ms/step - loss: 45.9903 - mae: 5.3285 - val_loss: 9409.2490 - val_mae: 94.0105 - lr: 0.0010
# Epoch 10/100
# 855/856 [============================>.] - ETA: 0s - loss: 45.5149 - mae: 5.2986
# Epoch 10: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 130s 152ms/step - loss: 45.5180 - mae: 5.2989 - val_loss: 5986.9185 - val_mae: 75.3851 - lr: 0.0010
# Epoch 11/100
# 855/856 [============================>.] - ETA: 0s - loss: 44.6420 - mae: 5.2477
# Epoch 11: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 129s 151ms/step - loss: 44.6494 - mae: 5.2483 - val_loss: 5937.2837 - val_mae: 75.0454 - lr: 0.0010
# Epoch 12/100
# 856/856 [==============================] - ETA: 0s - loss: 44.3104 - mae: 5.2281
# Epoch 12: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 128s 149ms/step - loss: 44.3104 - mae: 5.2281 - val_loss: 2634.3723 - val_mae: 49.2866 - lr: 0.0010
# Epoch 13/100
# 855/856 [============================>.] - ETA: 0s - loss: 43.4989 - mae: 5.1679
# Epoch 13: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 126s 148ms/step - loss: 43.5027 - mae: 5.1680 - val_loss: 2021.7727 - val_mae: 41.2112 - lr: 0.0010
# Epoch 14/100
# 855/856 [============================>.] - ETA: 0s - loss: 43.1992 - mae: 5.1569
# Epoch 14: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 127s 148ms/step - loss: 43.1972 - mae: 5.1567 - val_loss: 16289.6152 - val_mae: 125.3955 - lr: 0.0010
# Epoch 15/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.7126 - mae: 5.1321
# Epoch 15: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 128s 150ms/step - loss: 42.7176 - mae: 5.1325 - val_loss: 9848.0469 - val_mae: 96.1663 - lr: 0.0010
# Epoch 16/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.4911 - mae: 5.1107
# Epoch 16: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 127s 148ms/step - loss: 42.4904 - mae: 5.1106 - val_loss: 12880.9697 - val_mae: 111.3034 - lr: 0.0010
# Epoch 17/100
# 855/856 [============================>.] - ETA: 0s - loss: 42.1543 - mae: 5.0918
# Epoch 17: val_loss did not improve from 1875.94800
# 856/856 [==============================] - 124s 145ms/step - loss: 42.1611 - mae: 5.0923 - val_loss: 15558.6182 - val_mae: 122.6982 - lr: 0.0010
# Epoch 18/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.9268 - mae: 5.0847
# Epoch 18: val_loss improved from 1875.94800 to 1110.74646, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 128s 149ms/step - loss: 41.9203 - mae: 5.0843 - val_loss: 1110.7465 - val_mae: 27.6017 - lr: 0.0010
# Epoch 19/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.7622 - mae: 5.0716
# Epoch 19: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 131s 153ms/step - loss: 41.7647 - mae: 5.0717 - val_loss: 2411.8237 - val_mae: 40.6244 - lr: 0.0010
# Epoch 20/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.2308 - mae: 5.0310
# Epoch 20: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 134s 156ms/step - loss: 41.2367 - mae: 5.0315 - val_loss: 8618.0117 - val_mae: 90.9114 - lr: 0.0010
# Epoch 21/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.5740 - mae: 5.0593
# Epoch 21: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 133s 154ms/step - loss: 41.5732 - mae: 5.0593 - val_loss: 8054.5840 - val_mae: 87.8593 - lr: 0.0010
# Epoch 22/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.5972 - mae: 5.0588
# Epoch 22: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 129s 151ms/step - loss: 41.5966 - mae: 5.0588 - val_loss: 3806.2295 - val_mae: 55.5460 - lr: 0.0010
# Epoch 23/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.3130 - mae: 5.0413
# Epoch 23: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 128s 149ms/step - loss: 41.3201 - mae: 5.0417 - val_loss: 1761.8569 - val_mae: 36.0241 - lr: 0.0010
# Epoch 24/100
# 855/856 [============================>.] - ETA: 0s - loss: 41.0323 - mae: 5.0212
# Epoch 24: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 130s 151ms/step - loss: 41.0336 - mae: 5.0213 - val_loss: 1379.3538 - val_mae: 32.6381 - lr: 0.0010
# Epoch 25/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.6062 - mae: 4.9927
# Epoch 25: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 130s 151ms/step - loss: 40.6120 - mae: 4.9931 - val_loss: 1867.9377 - val_mae: 38.0114 - lr: 0.0010
# Epoch 26/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.3901 - mae: 4.9823
# Epoch 26: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 128s 149ms/step - loss: 40.3937 - mae: 4.9826 - val_loss: 2290.1184 - val_mae: 45.7371 - lr: 0.0010
# Epoch 27/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.5349 - mae: 4.9950
# Epoch 27: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 130s 152ms/step - loss: 40.5357 - mae: 4.9950 - val_loss: 16399.1250 - val_mae: 124.3603 - lr: 0.0010
# Epoch 28/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.5437 - mae: 5.0007
# Epoch 28: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 131s 152ms/step - loss: 40.5436 - mae: 5.0007 - val_loss: 11411.5664 - val_mae: 103.7943 - lr: 0.0010
# Epoch 29/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.7061 - mae: 4.9933
# Epoch 29: val_loss did not improve from 1110.74646
# 856/856 [==============================] - 128s 149ms/step - loss: 40.7140 - mae: 4.9937 - val_loss: 7786.4565 - val_mae: 78.5268 - lr: 0.0010
# Epoch 30/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.9215 - mae: 4.9462
# Epoch 30: val_loss improved from 1110.74646 to 305.82593, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 129s 150ms/step - loss: 39.9232 - mae: 4.9463 - val_loss: 305.8259 - val_mae: 15.5273 - lr: 0.0010
# Epoch 31/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0682 - mae: 4.9579
# Epoch 31: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 153ms/step - loss: 40.0798 - mae: 4.9585 - val_loss: 9720.9004 - val_mae: 96.4933 - lr: 0.0010
# Epoch 32/100
# 855/856 [============================>.] - ETA: 0s - loss: 40.0313 - mae: 4.9504
# Epoch 32: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 152ms/step - loss: 40.0281 - mae: 4.9503 - val_loss: 551.7501 - val_mae: 16.4662 - lr: 0.0010
# Epoch 33/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.3753 - mae: 4.9204
# Epoch 33: val_loss did not improve from 305.82593
# 856/856 [==============================] - 133s 156ms/step - loss: 39.3777 - mae: 4.9206 - val_loss: 4641.1152 - val_mae: 64.6464 - lr: 0.0010
# Epoch 34/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.5597 - mae: 4.9323
# Epoch 34: val_loss did not improve from 305.82593
# 856/856 [==============================] - 128s 149ms/step - loss: 39.5544 - mae: 4.9319 - val_loss: 4286.0234 - val_mae: 60.3467 - lr: 0.0010
# Epoch 35/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.3925 - mae: 4.9242
# Epoch 35: val_loss did not improve from 305.82593
# 856/856 [==============================] - 126s 147ms/step - loss: 39.3871 - mae: 4.9238 - val_loss: 9889.2295 - val_mae: 95.4042 - lr: 0.0010
# Epoch 36/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.9464 - mae: 4.8869
# Epoch 36: val_loss did not improve from 305.82593
# 856/856 [==============================] - 127s 148ms/step - loss: 38.9453 - mae: 4.8868 - val_loss: 5566.5732 - val_mae: 65.4696 - lr: 0.0010
# Epoch 37/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.2706 - mae: 4.9215
# Epoch 37: val_loss did not improve from 305.82593
# 856/856 [==============================] - 126s 148ms/step - loss: 39.2697 - mae: 4.9216 - val_loss: 16743.4043 - val_mae: 126.9008 - lr: 0.0010
# Epoch 38/100
# 855/856 [============================>.] - ETA: 0s - loss: 39.2260 - mae: 4.9059
# Epoch 38: val_loss did not improve from 305.82593
# 856/856 [==============================] - 129s 150ms/step - loss: 39.2347 - mae: 4.9063 - val_loss: 12000.5420 - val_mae: 106.7162 - lr: 0.0010
# Epoch 39/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.8849 - mae: 4.8893
# Epoch 39: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 153ms/step - loss: 38.8871 - mae: 4.8894 - val_loss: 9250.9199 - val_mae: 93.4062 - lr: 0.0010
# Epoch 40/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.8996 - mae: 4.8943
# Epoch 40: val_loss did not improve from 305.82593
# 856/856 [==============================] - 133s 155ms/step - loss: 38.8952 - mae: 4.8939 - val_loss: 4151.8613 - val_mae: 61.9797 - lr: 0.0010
# Epoch 41/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.4889 - mae: 4.8661
# Epoch 41: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 152ms/step - loss: 38.4852 - mae: 4.8659 - val_loss: 2728.6731 - val_mae: 50.3668 - lr: 0.0010
# Epoch 42/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.4119 - mae: 4.8584
# Epoch 42: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 153ms/step - loss: 38.4091 - mae: 4.8582 - val_loss: 1836.2744 - val_mae: 35.7415 - lr: 0.0010
# Epoch 43/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.6319 - mae: 4.8803
# Epoch 43: val_loss did not improve from 305.82593
# 856/856 [==============================] - 128s 150ms/step - loss: 38.6332 - mae: 4.8804 - val_loss: 845.5543 - val_mae: 24.1842 - lr: 0.0010
# Epoch 44/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.2998 - mae: 4.8482
# Epoch 44: val_loss did not improve from 305.82593
# 856/856 [==============================] - 131s 153ms/step - loss: 38.2987 - mae: 4.8481 - val_loss: 2960.0784 - val_mae: 51.5620 - lr: 0.0010
# Epoch 45/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.5891 - mae: 4.8666
# Epoch 45: val_loss did not improve from 305.82593
# 856/856 [==============================] - 134s 156ms/step - loss: 38.5946 - mae: 4.8670 - val_loss: 9183.1602 - val_mae: 94.2343 - lr: 0.0010
# Epoch 46/100
# 855/856 [============================>.] - ETA: 0s - loss: 37.9748 - mae: 4.8277
# Epoch 46: val_loss did not improve from 305.82593
# 856/856 [==============================] - 128s 149ms/step - loss: 37.9743 - mae: 4.8277 - val_loss: 5589.9370 - val_mae: 71.8159 - lr: 0.0010
# Epoch 47/100
# 855/856 [============================>.] - ETA: 0s - loss: 38.0616 - mae: 4.8392
# Epoch 47: val_loss did not improve from 305.82593
# 856/856 [==============================] - 127s 149ms/step - loss: 38.0625 - mae: 4.8394 - val_loss: 14222.0264 - val_mae: 116.7830 - lr: 0.0010
# Epoch 48/100
# 855/856 [============================>.] - ETA: 0s - loss: 37.9783 - mae: 4.8293
# Epoch 48: val_loss did not improve from 305.82593
# 856/856 [==============================] - 125s 145ms/step - loss: 37.9824 - mae: 4.8295 - val_loss: 3251.2991 - val_mae: 53.1617 - lr: 0.0010
# Epoch 49/100
# 855/856 [============================>.] - ETA: 0s - loss: 37.7058 - mae: 4.8206
# Epoch 49: val_loss did not improve from 305.82593
# 856/856 [==============================] - 130s 152ms/step - loss: 37.7094 - mae: 4.8209 - val_loss: 5164.5762 - val_mae: 65.4605 - lr: 0.0010
# Epoch 50/100
# 855/856 [============================>.] - ETA: 0s - loss: 37.7999 - mae: 4.8199
# Epoch 50: val_loss did not improve from 305.82593
# 856/856 [==============================] - 130s 152ms/step - loss: 37.7990 - mae: 4.8198 - val_loss: 2697.2114 - val_mae: 48.6335 - lr: 0.0010
# Epoch 51/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.8778 - mae: 4.7555
# Epoch 51: val_loss improved from 305.82593 to 46.52795, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 132s 153ms/step - loss: 36.8813 - mae: 4.7557 - val_loss: 46.5280 - val_mae: 4.4947 - lr: 5.0000e-04
# Epoch 52/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.9752 - mae: 4.7602
# Epoch 52: val_loss improved from 46.52795 to 32.58451, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 135s 157ms/step - loss: 36.9752 - mae: 4.7603 - val_loss: 32.5845 - val_mae: 3.6519 - lr: 5.0000e-04
# Epoch 53/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.8639 - mae: 4.7507
# Epoch 53: val_loss did not improve from 32.58451
# 856/856 [==============================] - 132s 154ms/step - loss: 36.8689 - mae: 4.7509 - val_loss: 2881.2075 - val_mae: 45.5002 - lr: 5.0000e-04
# Epoch 54/100
# 855/856 [============================>.] - ETA: 0s - loss: 37.1162 - mae: 4.7704
# Epoch 54: val_loss did not improve from 32.58451
# 856/856 [==============================] - 128s 149ms/step - loss: 37.1166 - mae: 4.7704 - val_loss: 1432.2051 - val_mae: 29.7533 - lr: 5.0000e-04
# Epoch 55/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.9586 - mae: 4.7644
# Epoch 55: val_loss did not improve from 32.58451
# 856/856 [==============================] - 127s 148ms/step - loss: 36.9548 - mae: 4.7641 - val_loss: 2052.5098 - val_mae: 36.7244 - lr: 5.0000e-04
# Epoch 56/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.6132 - mae: 4.7318
# Epoch 56: val_loss did not improve from 32.58451
# 856/856 [==============================] - 128s 149ms/step - loss: 36.6110 - mae: 4.7316 - val_loss: 1053.7795 - val_mae: 28.4566 - lr: 5.0000e-04
# Epoch 57/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.9134 - mae: 4.7522
# Epoch 57: val_loss did not improve from 32.58451
# 856/856 [==============================] - 128s 149ms/step - loss: 36.9134 - mae: 4.7522 - val_loss: 1531.3726 - val_mae: 34.7114 - lr: 5.0000e-04
# Epoch 58/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.3245 - mae: 4.7189
# Epoch 58: val_loss did not improve from 32.58451
# 856/856 [==============================] - 126s 146ms/step - loss: 36.3238 - mae: 4.7189 - val_loss: 1425.6787 - val_mae: 34.8991 - lr: 5.0000e-04
# Epoch 59/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.3421 - mae: 4.7211
# Epoch 59: val_loss did not improve from 32.58451
# 856/856 [==============================] - 124s 145ms/step - loss: 36.3438 - mae: 4.7212 - val_loss: 4331.8911 - val_mae: 59.8322 - lr: 5.0000e-04
# Epoch 60/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.4440 - mae: 4.7264
# Epoch 60: val_loss did not improve from 32.58451
# 856/856 [==============================] - 128s 149ms/step - loss: 36.4435 - mae: 4.7265 - val_loss: 47.1568 - val_mae: 5.0764 - lr: 5.0000e-04
# Epoch 61/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.1726 - mae: 4.7077
# Epoch 61: val_loss did not improve from 32.58451
# 856/856 [==============================] - 129s 150ms/step - loss: 36.1742 - mae: 4.7078 - val_loss: 1602.1909 - val_mae: 35.6769 - lr: 5.0000e-04
# Epoch 62/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.2688 - mae: 4.7058
# Epoch 62: val_loss did not improve from 32.58451
# 856/856 [==============================] - 127s 148ms/step - loss: 36.2670 - mae: 4.7056 - val_loss: 5463.1880 - val_mae: 67.4733 - lr: 5.0000e-04
# Epoch 63/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.4216 - mae: 4.7304
# Epoch 63: val_loss did not improve from 32.58451
# 856/856 [==============================] - 125s 145ms/step - loss: 36.4208 - mae: 4.7303 - val_loss: 1529.4247 - val_mae: 32.7390 - lr: 5.0000e-04
# Epoch 64/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.2168 - mae: 4.7070
# Epoch 64: val_loss did not improve from 32.58451
# 856/856 [==============================] - 129s 151ms/step - loss: 36.2195 - mae: 4.7072 - val_loss: 49.5520 - val_mae: 4.7794 - lr: 5.0000e-04
# Epoch 65/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.0562 - mae: 4.7001
# Epoch 65: val_loss improved from 32.58451 to 27.78898, saving model to v3s_b16_lr001.h5
# 856/856 [==============================] - 130s 152ms/step - loss: 36.0579 - mae: 4.7001 - val_loss: 27.7890 - val_mae: 3.8681 - lr: 5.0000e-04
# Epoch 66/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.1827 - mae: 4.7060
# Epoch 66: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 36.1792 - mae: 4.7058 - val_loss: 5953.9033 - val_mae: 72.1677 - lr: 5.0000e-04
# Epoch 67/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.2884 - mae: 4.7190
# Epoch 67: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 150ms/step - loss: 36.2923 - mae: 4.7193 - val_loss: 2200.4043 - val_mae: 44.2450 - lr: 5.0000e-04
# Epoch 68/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.4696 - mae: 4.7198
# Epoch 68: val_loss did not improve from 27.78898
# 856/856 [==============================] - 134s 155ms/step - loss: 36.4703 - mae: 4.7199 - val_loss: 2300.5508 - val_mae: 44.5569 - lr: 5.0000e-04
# Epoch 69/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.4659 - mae: 4.7278
# Epoch 69: val_loss did not improve from 27.78898
# 856/856 [==============================] - 134s 156ms/step - loss: 36.4765 - mae: 4.7284 - val_loss: 170.4617 - val_mae: 10.0360 - lr: 5.0000e-04
# Epoch 70/100
# 856/856 [==============================] - ETA: 0s - loss: 35.7770 - mae: 4.6847
# Epoch 70: val_loss did not improve from 27.78898
# 856/856 [==============================] - 132s 154ms/step - loss: 35.7770 - mae: 4.6847 - val_loss: 2286.6082 - val_mae: 39.8503 - lr: 5.0000e-04
# Epoch 71/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.8710 - mae: 4.6974
# Epoch 71: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.8704 - mae: 4.6974 - val_loss: 2832.0088 - val_mae: 48.3426 - lr: 5.0000e-04
# Epoch 72/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.1657 - mae: 4.7107
# Epoch 72: val_loss did not improve from 27.78898
# 856/856 [==============================] - 129s 150ms/step - loss: 36.1700 - mae: 4.7110 - val_loss: 9866.0742 - val_mae: 97.6366 - lr: 5.0000e-04
# Epoch 73/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.7210 - mae: 4.6751
# Epoch 73: val_loss did not improve from 27.78898
# 856/856 [==============================] - 129s 151ms/step - loss: 35.7180 - mae: 4.6749 - val_loss: 400.0514 - val_mae: 15.3956 - lr: 5.0000e-04
# Epoch 74/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.9628 - mae: 4.6960
# Epoch 74: val_loss did not improve from 27.78898
# 856/856 [==============================] - 132s 153ms/step - loss: 35.9596 - mae: 4.6958 - val_loss: 868.7681 - val_mae: 21.6365 - lr: 5.0000e-04
# Epoch 75/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.3814 - mae: 4.6542
# Epoch 75: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.3845 - mae: 4.6544 - val_loss: 1833.9075 - val_mae: 35.6824 - lr: 5.0000e-04
# Epoch 76/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.8997 - mae: 4.6844
# Epoch 76: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.9059 - mae: 4.6847 - val_loss: 1311.3767 - val_mae: 30.0490 - lr: 5.0000e-04
# Epoch 77/100
# 855/856 [============================>.] - ETA: 0s - loss: 36.1653 - mae: 4.7120
# Epoch 77: val_loss did not improve from 27.78898
# 856/856 [==============================] - 126s 147ms/step - loss: 36.1643 - mae: 4.7120 - val_loss: 482.4262 - val_mae: 17.9869 - lr: 5.0000e-04
# Epoch 78/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.5934 - mae: 4.6650
# Epoch 78: val_loss did not improve from 27.78898
# 856/856 [==============================] - 130s 152ms/step - loss: 35.5913 - mae: 4.6649 - val_loss: 280.1624 - val_mae: 13.3067 - lr: 5.0000e-04
# Epoch 79/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.3242 - mae: 4.6547
# Epoch 79: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.3248 - mae: 4.6548 - val_loss: 628.1115 - val_mae: 21.4194 - lr: 5.0000e-04
# Epoch 80/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.5078 - mae: 4.6644
# Epoch 80: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 148ms/step - loss: 35.5098 - mae: 4.6646 - val_loss: 50.5181 - val_mae: 5.7240 - lr: 5.0000e-04
# Epoch 81/100
# 856/856 [==============================] - ETA: 0s - loss: 35.2245 - mae: 4.6478
# Epoch 81: val_loss did not improve from 27.78898
# 856/856 [==============================] - 130s 151ms/step - loss: 35.2245 - mae: 4.6478 - val_loss: 2439.8538 - val_mae: 47.1587 - lr: 5.0000e-04
# Epoch 82/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.5249 - mae: 4.6695
# Epoch 82: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 148ms/step - loss: 35.5263 - mae: 4.6697 - val_loss: 1962.7762 - val_mae: 41.0645 - lr: 5.0000e-04
# Epoch 83/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.0121 - mae: 4.6293
# Epoch 83: val_loss did not improve from 27.78898
# 856/856 [==============================] - 139s 161ms/step - loss: 35.0142 - mae: 4.6295 - val_loss: 1981.6853 - val_mae: 42.1198 - lr: 5.0000e-04
# Epoch 84/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.5048 - mae: 4.6654
# Epoch 84: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.5073 - mae: 4.6655 - val_loss: 9910.0918 - val_mae: 96.9592 - lr: 5.0000e-04
# Epoch 85/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.1843 - mae: 4.6496
# Epoch 85: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 35.1899 - mae: 4.6500 - val_loss: 2137.6885 - val_mae: 43.8031 - lr: 5.0000e-04
# Epoch 86/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.1090 - mae: 4.6376
# Epoch 86: val_loss did not improve from 27.78898
# 856/856 [==============================] - 130s 152ms/step - loss: 35.1103 - mae: 4.6377 - val_loss: 511.2398 - val_mae: 19.2932 - lr: 5.0000e-04
# Epoch 87/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.8479 - mae: 4.6172
# Epoch 87: val_loss did not improve from 27.78898
# 856/856 [==============================] - 127s 148ms/step - loss: 34.8483 - mae: 4.6173 - val_loss: 380.6649 - val_mae: 15.2400 - lr: 5.0000e-04
# Epoch 88/100
# 855/856 [============================>.] - ETA: 0s - loss: 35.0885 - mae: 4.6409
# Epoch 88: val_loss did not improve from 27.78898
# 856/856 [==============================] - 126s 147ms/step - loss: 35.0846 - mae: 4.6406 - val_loss: 970.9590 - val_mae: 26.9511 - lr: 5.0000e-04
# Epoch 89/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.9522 - mae: 4.6342
# Epoch 89: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 149ms/step - loss: 34.9565 - mae: 4.6344 - val_loss: 6946.5498 - val_mae: 77.4844 - lr: 5.0000e-04
# Epoch 90/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6813 - mae: 4.6119
# Epoch 90: val_loss did not improve from 27.78898
# 856/856 [==============================] - 132s 154ms/step - loss: 34.6829 - mae: 4.6121 - val_loss: 4134.1885 - val_mae: 59.1977 - lr: 5.0000e-04
# Epoch 91/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.9350 - mae: 4.6268
# Epoch 91: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 149ms/step - loss: 34.9358 - mae: 4.6268 - val_loss: 6351.6313 - val_mae: 75.3542 - lr: 5.0000e-04
# Epoch 92/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6041 - mae: 4.5995
# Epoch 92: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 149ms/step - loss: 34.6083 - mae: 4.5998 - val_loss: 2308.1685 - val_mae: 40.4605 - lr: 5.0000e-04
# Epoch 93/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6018 - mae: 4.6072
# Epoch 93: val_loss did not improve from 27.78898
# 856/856 [==============================] - 132s 153ms/step - loss: 34.6086 - mae: 4.6074 - val_loss: 233.3980 - val_mae: 13.3449 - lr: 5.0000e-04
# Epoch 94/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.8725 - mae: 4.6163
# Epoch 94: val_loss did not improve from 27.78898
# 856/856 [==============================] - 129s 150ms/step - loss: 34.8768 - mae: 4.6167 - val_loss: 3846.8591 - val_mae: 55.9722 - lr: 5.0000e-04
# Epoch 95/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6800 - mae: 4.6125
# Epoch 95: val_loss did not improve from 27.78898
# 856/856 [==============================] - 133s 155ms/step - loss: 34.6856 - mae: 4.6129 - val_loss: 15872.5098 - val_mae: 123.0497 - lr: 5.0000e-04
# Epoch 96/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6273 - mae: 4.6133
# Epoch 96: val_loss did not improve from 27.78898
# 856/856 [==============================] - 131s 152ms/step - loss: 34.6258 - mae: 4.6132 - val_loss: 12217.3828 - val_mae: 108.1692 - lr: 5.0000e-04
# Epoch 97/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.4873 - mae: 4.5944
# Epoch 97: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 150ms/step - loss: 34.4851 - mae: 4.5941 - val_loss: 1285.8351 - val_mae: 32.6207 - lr: 5.0000e-04
# Epoch 98/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.8450 - mae: 4.6258
# Epoch 98: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 149ms/step - loss: 34.8451 - mae: 4.6259 - val_loss: 838.3515 - val_mae: 26.4951 - lr: 5.0000e-04
# Epoch 99/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.8025 - mae: 4.6156
# Epoch 99: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 150ms/step - loss: 34.7998 - mae: 4.6154 - val_loss: 2027.3455 - val_mae: 37.8463 - lr: 5.0000e-04
# Epoch 100/100
# 855/856 [============================>.] - ETA: 0s - loss: 34.6249 - mae: 4.6073
# Epoch 100: val_loss did not improve from 27.78898
# 856/856 [==============================] - 128s 149ms/step - loss: 34.6324 - mae: 4.6078 - val_loss: 6147.8618 - val_mae: 74.1658 - lr: 5.0000e-04

# %%
# 평균 에포크 시간 계산 및 출력
average_epoch_time = np.mean(time_callback.times)
print(f"에포크당 평균 소요 시간: {average_epoch_time:.2f}초")
# Out:
# 에포크당 평균 소요 시간: 129.71초

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'][50:], label='Train Loss')
plt.plot(history.history['val_loss'][50:], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()

# %%
b_m = tf.keras.models.load_model('v3s_b16_lr001.h5')

# %%
def plot_predicted_keypoints(model, image_path, image_dir, original_width=720, original_height=1280, target_size=224):
    """
    모델을 사용하여 이미지의 키포인트를 예측하고 시각화하는 함수.

    Parameters:
        model (tf.keras.Model): 사전 학습된 모델.
        image_path (str): 예측할 이미지의 경로.
        image_dir (str): 이미지가 저장된 디렉토리 경로.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.
        target_size (int): 모델의 입력 이미지 크기.
    """
    # 이미지 로드 및 전처리
    image_full_path = os.path.join(image_dir, image_path)
    image = cv2.imread(image_full_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_full_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 원본 크기와 종횡비 계산
    orig_h, orig_w = image_rgb.shape[:2]
    scale = min(target_size / orig_w, target_size / orig_h)
    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)

    print(f"Original size: ({orig_w}, {orig_h})")
    print(f"Scale factor: {scale}")
    print(f"Resized size: ({new_w}, {new_h})")

    # 종횡비 유지하며 리사이징
    image_resized = cv2.resize(image_rgb, (new_w, new_h)) / 255.0

    # 패딩 추가
    pad_w = target_size - new_w
    pad_h = target_size - new_h
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top

    print(f"Padding (left, top): ({pad_left}, {pad_top})")
    print(f"Padding (right, bottom): ({pad_right}, {pad_bottom})")

    image_padded = cv2.copyMakeBorder(
        image_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=0
    )

    # 모델 입력 준비
    input_image = np.expand_dims(image_padded, axis=0).astype(np.float32)

    # 예측
    predicted_keypoints = model.predict(input_image)[0]

    # print(f"Predicted keypoints (raw): {predicted_keypoints}")

    # 키포인트 스케일 조정 및 이동 (패딩 고려)
    # 전처리 시 사용된 스케일과 동일하게 되돌리기
    scale_back = 1 / scale

    x_scaled = (predicted_keypoints[::2] - pad_left) * scale_back
    y_scaled = (predicted_keypoints[1::2] - pad_top) * scale_back

    # print(f"Scaled keypoints (x): {x_scaled}")
    # print(f"Scaled keypoints (y): {y_scaled}")

    predicted_keypoints_scaled = np.empty_like(predicted_keypoints)
    predicted_keypoints_scaled[::2] = x_scaled
    predicted_keypoints_scaled[1::2] = y_scaled

    # print(f"Scaled keypoints (combined): {predicted_keypoints_scaled}")

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)

    for i in range(0, len(predicted_keypoints_scaled), 2):
        x = predicted_keypoints_scaled[i]
        y = predicted_keypoints_scaled[i + 1]
        # 키포인트가 이미지 범위 내에 있는지 확인
        if 0 <= x < orig_w and 0 <= y < orig_h:
            plt.scatter(x, y, c='r', s=10)

    plt.title('Predicted Keypoints')
    plt.axis('off')
    plt.show()

# 예측 및 시각화
sample_image_path = val_image_paths[50]
plot_predicted_keypoints(b_m, sample_image_path, val_image_dir)
# Out:
# Original size: (720, 1280)
# Scale factor: 0.175
# Resized size: (125, 224)
# Padding (left, top): (49, 0)
# Padding (right, bottom): (50, 0)
# 1/1 [==============================] - 0s 57ms/step

# %%
import keras


# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 백본 모델 로드 (pre-trained MobileNetV3Small)
    base_model = b_m(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # 백본 모델 학습
    base_model.trainable = True
    
    # 글로벌 풀링
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    
    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표
    x = Dense(NUM_KEYPOINTS * 2, activation='linear', dtype='float32')(x)  # mixed precision 시 출력 dtype 설정
    
    # 모델 정의
    model = Model(inputs=base_model.input, outputs=x)
    
    # 모델 컴파일
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()

# %%
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import time

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001  # 첫 50 에포크 동안 학습률은 0.001
    else:
        return 0.0005  # 에포크 51부터 100까지 학습률은 0.0005

# 에포크 시간 측정을 위한 콜백 클래스 정의
class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
        
# 콜백 설정
checkpoint = ModelCheckpoint('v3s_b16_lr001.h5', monitor='val_loss', save_best_only=True, verbose=1)
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)
time_callback = TimeHistory()
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, lr_scheduler_callback, time_callback]
)
