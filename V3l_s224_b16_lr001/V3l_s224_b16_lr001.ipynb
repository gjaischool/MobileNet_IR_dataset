# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.applications import MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow_addons as tfa
from tensorflow.keras import mixed_precision

# %% [markdown]
# # 데이터셋 로더

# %%
# **1. GPU 메모리 성장 설정 (가장 먼저 실행)**
physical_devices = tf.config.list_physical_devices('GPU')
for gpu in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"메모리 성장 설정 완료: {gpu}")
    except RuntimeError as e:
        print(f"메모리 성장 설정 실패: {gpu} - {e}")

# **2. 분산 전략 설정**
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# **3. Mixed Precision 비활성화**
policy = mixed_precision.Policy('float32')
mixed_precision.set_global_policy(policy)

# **4. 데이터셋 로더 함수**
def load_data(csv_file, image_dir):
    df = pd.read_csv(csv_file)
    image_paths = df['image_path'].tolist()
    keypoints = df.iloc[:, 1:].values.astype(np.float32)
    return image_paths, keypoints

# **5. 키포인트 스케일링 함수 정의**
def scale_keypoints(keypoints, original_width=720, original_height=1280, target_size=224):
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    x_scale = target_size / original_width
    y_scale = target_size / original_height
    x_scaled = x_coords * x_scale
    y_scaled = y_coords * y_scale
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    return scaled_keypoints

# **6. 데이터 증강 함수 정의 (현재 사용 안 함)**
def augment(image, keypoints):
    # 랜덤 회전
    angle = tf.random.uniform([], -15, 15, dtype=tf.float32)
    angle_rad = angle * np.pi / 180.0
    image = tfa.image.rotate(image, angles=angle_rad, fill_mode='nearest')
    
    # 키포인트 회전
    center_x = 720.0 / 2 * (224 / 720.0)  # 224x224 이미지 기준 (720 -> 224)
    center_y = 1280.0 / 2 * (224 / 1280.0)  # 1280 -> 224
    rotation_matrix = tf.reshape([
        tf.cos(angle_rad), -tf.sin(angle_rad),
        tf.sin(angle_rad), tf.cos(angle_rad)
    ], [2, 2])
    keypoints = tf.reshape(keypoints, [NUM_KEYPOINTS, 2])
    keypoints = tf.matmul(keypoints - tf.constant([center_x, center_y]), rotation_matrix) + tf.constant([center_x, center_y])
    keypoints = tf.reshape(keypoints, [-1])
    
    return image, keypoints

# **7. 이미지 및 키포인트 전처리 함수 (종횡비 유지 및 패딩 추가)**
def preprocess_image(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    """
    이미지와 키포인트를 전처리하는 함수.

    Parameters:
        image_path (tf.Tensor): 이미지 파일 경로.
        keypoints (tf.Tensor): 키포인트 좌표.
        image_dir (tf.Tensor): 이미지가 저장된 디렉토리 경로.
        target_size (int): 모델 입력 이미지의 크기.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.

    Returns:
        image (tf.Tensor): 전처리된 이미지.
        scaled_keypoints (tf.Tensor): 스케일 조정된 키포인트 좌표.
    """
    # 이미지 경로 결합
    image_full_path = tf.strings.join([image_dir, '/', image_path])
    
    # 이미지 로드 및 디코드
    image = tf.io.read_file(image_full_path)
    image = tf.image.decode_jpeg(image, channels=3)
    
    # 이미지가 정상적으로 로드되었는지 확인하고, float32로 변환 및 [0,1] 범위로 스케일링
    image = tf.cond(tf.equal(tf.size(image), 0),
                   lambda: tf.zeros([target_size, target_size, 3], dtype=tf.float32),
                   lambda: tf.image.convert_image_dtype(image, tf.float32))
    
    # 원본 크기 가져오기
    orig_shape = tf.shape(image)[:2]
    orig_height_img = tf.cast(orig_shape[0], tf.float32)
    orig_width_img = tf.cast(orig_shape[1], tf.float32)
    
    # 종횡비 유지하며 리사이징
    scale = tf.minimum(target_size / orig_width_img, target_size / orig_height_img)
    new_width = tf.cast(tf.round(orig_width_img * scale), tf.int32)
    new_height = tf.cast(tf.round(orig_height_img * scale), tf.int32)
    
    image = tf.image.resize(image, [new_height, new_width])
    
    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_width = target_size - new_width
    pad_height = target_size - new_height
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    
    image = tf.pad(image, [[pad_top, pad_bottom], [pad_left, pad_right], [0, 0]], constant_values=0)
    
    # 키포인트 스케일 조정 및 이동
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    
    # 스케일링
    x_scale = scale
    y_scale = scale
    
    x_scaled = x_coords * x_scale + tf.cast(pad_left, tf.float32)
    y_scaled = y_coords * y_scale + tf.cast(pad_top, tf.float32)
    
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    
    return image, scaled_keypoints

# **8. 데이터셋 전처리 및 증강 함수**
def preprocess_image_aug(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    image, keypoints = preprocess_image(image_path, keypoints, image_dir, target_size, original_width, original_height)
    image, keypoints = augment(image, keypoints)
    return image, keypoints

# **9. 데이터셋 생성 함수 수정**
def create_dataset(image_paths, keypoints, image_dir, batch_size=64, shuffle=True, augment_data=False, target_size=224, original_width=720, original_height=1280):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, keypoints))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(image_paths))
    
    # image_dir을 TensorFlow 상수로 변환
    image_dir_tf = tf.constant(image_dir)
    
    if augment_data:
        # 데이터 증강 적용
        dataset = dataset.map(lambda x, y: preprocess_image_aug(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        # 데이터 증강 미적용
        dataset = dataset.map(lambda x, y: preprocess_image(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset
# Out:
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3
# 2024-10-29 08:45:40.338101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.342008: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.345925: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.417516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.421186: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.424835: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.428804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.440397: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:40.444878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.245484: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.247522: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.249611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.252012: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.253837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.255727: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.257651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.259451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.261335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.294152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.296010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.297933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.299900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.301690: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.303667: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.305637: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.307439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:06.0, compute capability: 7.5
# 2024-10-29 08:45:41.307996: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.309867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13775 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:08.0, compute capability: 7.5
# 2024-10-29 08:45:41.310252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 08:45:41.312158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 13775 MB memory:  -> device: 2, name: Tesla T4, pci bus id: 0000:00:0b.0, compute capability: 7.5

# %%
# CSV 파일 경로
train_csv = 'keras_dataset/annotations/train_annotations.csv'
val_csv = 'keras_dataset/annotations/val_annotations.csv'

# 이미지 디렉토리
train_image_dir = 'keras_dataset/images/train'
val_image_dir = 'keras_dataset/images/val'

# 로드된 데이터
train_image_paths, train_keypoints = load_data(train_csv, train_image_dir)
val_image_paths, val_keypoints = load_data(val_csv, val_image_dir)

# 전체 배치 크기 설정
BATCH_SIZE_PER_REPLICA = 16  # 각 GPU당 배치 크기 (메모리 문제를 방지하기 위해 줄임)
GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync  # 전체 배치 크기

# 훈련 및 검증 데이터셋 생성
train_dataset = create_dataset(
    train_image_paths, 
    train_keypoints, 
    train_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=True, 
    augment_data=False,  # 현재 데이터 증강 비활성화
    target_size=224, 
    original_width=720, 
    original_height=1280
)

val_dataset = create_dataset(
    val_image_paths, 
    val_keypoints, 
    val_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=False, 
    augment_data=False, 
    target_size=224, 
    original_width=720, 
    original_height=1280
)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# 이미지 파일 경로
t_path = 'keras_dataset/images/val/Q_098_20_F_01_M0_G0_C0_01.jpg'

# 이미지를 로드합니다. 원하는 크기로 조정할 수도 있습니다.
t_image = load_img(t_path)

# 이미지를 배열로 변환합니다.
image_array = img_to_array(t_image)

# 이미지의 shape을 출력합니다.
print("이미지의 shape:", image_array.shape)

# 각 채널 분리
red_channel = image_array[:, :, 0]
green_channel = image_array[:, :, 1]
blue_channel = image_array[:, :, 2]

# 시각화 설정
plt.figure(figsize=(15, 5))

# Red 채널
plt.subplot(1, 3, 1)
plt.imshow(red_channel)
plt.title('Red Channel')
plt.axis('off')

# Green 채널
plt.subplot(1, 3, 2)
plt.imshow(green_channel)
plt.title('Green Channel')
plt.axis('off')

# Blue 채널
plt.subplot(1, 3, 3)
plt.imshow(blue_channel)
plt.title('Blue Channel')
plt.axis('off')

# 전체 이미지 표시
plt.show()
# Out:
# 이미지의 shape: (1280, 720, 3)

# %% [markdown]
# # 키포인트 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터셋 일부 시각화 (디버깅 용도)
def visualize_sample(image, keypoints, title='Sample'):
    image_np = image.numpy()
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np)
    # 키포인트를 224x224 이미지에 맞게 그리기
    x = keypoints[::2].numpy()
    y = keypoints[1::2].numpy()
    plt.scatter(x, y, c='r', s=10)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# 데이터셋에서 샘플 가져오기
for images, keypoints in train_dataset.take(1):
    for i in range(3):  # 첫 3개 샘플 시각화
        visualize_sample(images[i], keypoints[i], title=f"Sample {i+1}")

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 140), dtype=tf.float32, name=None))>

# %% [markdown]
# # 모델학습

# %%
import keras


# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 백본 모델 로드 (pre-trained MobileNetV3Large)
    base_model = MobileNetV3Large(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # 백본 모델 학습
    base_model.trainable = True
    
    # 글로벌 풀링
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    
    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표
    x = Dense(NUM_KEYPOINTS * 2, activation='linear', dtype='float32')(x)  # mixed precision 시 출력 dtype 설정
    
    # 모델 정의
    model = Model(inputs=base_model.input, outputs=x)
    
    # 모델 컴파일
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add (TFOpLambda)    (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#
#  re_lu (ReLU)                (None, 112, 112, 16)         0         ['tf.math.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 112, 112, 16)         0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (D  (None, 112, 112, 16)         144       ['multiply[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 112, 112, 16)         64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 16)         0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 112, 112, 16)         256       ['re_lu_1[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 112, 112, 16)         64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 112, 112, 16)         0         ['multiply[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 112, 112, 64)         1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 112, 112, 64)         256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_2 (ReLU)              (None, 112, 112, 64)         0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 113, 113, 64)         0         ['re_lu_2[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 56, 56, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 56, 56, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 56, 56, 24)           1536      ['re_lu_3[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_4 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 56, 56, 72)           648       ['re_lu_4[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 56, 56, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 56, 56, 24)           1728      ['re_lu_5[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 56, 56, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_6 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 59, 59, 72)           0         ['re_lu_6[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 28, 28, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_7 (ReLU)              (None, 28, 28, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_7[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_1 (TFOpLambda)  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_8 (ReLU)              (None, 1, 1, 72)             0         ['tf.math.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 72)             0         ['re_lu_8[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 28, 28, 72)           0         ['re_lu_7[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (C  (None, 28, 28, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_9 (ReLU)              (None, 28, 28, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 28, 28, 120)          3000      ['re_lu_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_10 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_2 (TFOpLambda)  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_11 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_11[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_10[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_12 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 28, 28, 120)          3000      ['re_lu_12[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_13[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_3 (TFOpLambda)  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#                                                                     te/Conv_1[0][0]']
#
#  re_lu_14 (ReLU)             (None, 1, 1, 120)            0         ['tf.math.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_14[0][0]']
#  mbda)
#
#  expanded_conv_5/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_13[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 28, 28, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 28, 28, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_4 (TFOpLambda)  (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_15 (ReLU)             (None, 28, 28, 240)          0         ['tf.math.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None, 28, 28, 240)          0         ['re_lu_15[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 29, 29, 240)          0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 14, 14, 240)          2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_5 (TFOpLambda)  (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 240)          0         ['tf.math.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_16[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 80)           19200     ['multiply_2[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 200)          16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 200)          800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_6 (TFOpLambda)  (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 200)          0         ['tf.math.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None, 14, 14, 200)          0         ['re_lu_17[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 200)          1800      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 200)          800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_7 (TFOpLambda)  (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_18 (ReLU)             (None, 14, 14, 200)          0         ['tf.math.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 14, 14, 200)          0         ['re_lu_18[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 80)           16000     ['multiply_4[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_8 (TFOpLambda)  (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 184)          0         ['tf.math.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 14, 14, 184)          0         ['re_lu_19[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise   (None, 14, 14, 184)          1656      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_9 (TFOpLambda)  (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 184)          0         ['tf.math.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 14, 14, 184)          0         ['re_lu_20[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (C  (None, 14, 14, 80)           14720     ['multiply_6[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_10 (TFOpLambda  (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_21 (ReLU)             (None, 14, 14, 184)          0         ['tf.math.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_21[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise   (None, 14, 14, 184)          1656      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_11 (TFOpLambda  (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_22 (ReLU)             (None, 14, 14, 184)          0         ['tf.math.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_22[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (C  (None, 14, 14, 80)           14720     ['multiply_8[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 14, 14, 480)          38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
# ...
#  ambda)
#
#  multiply_15 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_13/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_21[0][0]']
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            24000     ['multiply_15[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_22 (TFOpLambda  (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_33 (ReLU)             (None, 7, 7, 960)            0         ['tf.math.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_33[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_23 (TFOpLambda  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_34 (ReLU)             (None, 1, 1, 960)            0         ['tf.math.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_34[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 7, 7, 960)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (  (None, 7, 7, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 7, 7, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 7, 7, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 7, 7, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_24 (TFOpLambda  (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#  )                                                                  hNorm[0][0]']
#
#  re_lu_35 (ReLU)             (None, 7, 7, 960)            0         ['tf.math.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_35[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            24000     ['multiply_17[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_25 (TFOpLambda  (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#  )                                                                  atchNorm[0][0]']
#
#  re_lu_36 (ReLU)             (None, 7, 7, 960)            0         ['tf.math.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_36[0][0]']
#  ambda)
#
#  multiply_18 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_18[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_26 (TFOpLambda  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  )                                                                  ite/Conv_1[0][0]']
#
#  re_lu_37 (ReLU)             (None, 1, 1, 960)            0         ['tf.math.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_37[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 7, 7, 960)            0         ['multiply_18[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (  (None, 7, 7, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 7, 7, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_27 (TFOpLambda  (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  )
#
#  re_lu_38 (ReLU)             (None, 7, 7, 960)            0         ['tf.math.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_38[0][0]']
#  ambda)
#
#  multiply_19 (Multiply)      (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_27[0][0]']
#
#  global_average_pooling2d (  (None, 960)                  0         ['multiply_19[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 960)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 140)                  134540    ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 3130892 (11.94 MB)
# Trainable params: 3106492 (11.85 MB)
# Non-trainable params: 24400 (95.31 KB)
# __________________________________________________________________________________________________

# %%
len(base_model.layers)
# Out:
# 263

# %%
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
import time

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001  # 첫 50 에포크 동안 학습률은 0.001
    else:
        return 0.0001  # 에포크 51부터 100까지 학습률은 0.0005

# 에포크 시간 측정을 위한 콜백 클래스 정의
class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

time_callback = TimeHistory()
        
# 콜백 설정
checkpoint = ModelCheckpoint('v3l_b16_lr001.h5', monitor='val_loss', save_best_only=True, verbose=1)
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)
time_callback = TimeHistory()
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, lr_scheduler_callback, time_callback]
)
# Out:
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 172 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 172 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2024-10-29 08:48:52.846550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 08:48:53.287798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 08:48:53.293212: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-29 08:48:57.509457: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc3279938f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-29 08:48:57.509496: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-10-29 08:48:57.509503: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-10-29 08:48:57.509509: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla T4, Compute Capability 7.5
# 2024-10-29 08:48:57.519534: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-29 08:48:57.656590: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 856/856 [==============================] - ETA: 0s - loss: 807.0114 - mae: 14.4746
# Epoch 1: val_loss improved from inf to 18885.04688, saving model to v3l_b16_lr001.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 188s 134ms/step - loss: 807.0114 - mae: 14.4746 - val_loss: 18885.0469 - val_mae: 134.6422 - lr: 0.0010
# Epoch 2/100
# 856/856 [==============================] - ETA: 0s - loss: 43.8515 - mae: 5.2078
# Epoch 2: val_loss improved from 18885.04688 to 14552.13184, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 147s 171ms/step - loss: 43.8515 - mae: 5.2078 - val_loss: 14552.1318 - val_mae: 117.3153 - lr: 0.0010
# Epoch 3/100
# 856/856 [==============================] - ETA: 0s - loss: 38.1142 - mae: 4.8601
# Epoch 3: val_loss improved from 14552.13184 to 4475.89551, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 147s 171ms/step - loss: 38.1142 - mae: 4.8601 - val_loss: 4475.8955 - val_mae: 64.4465 - lr: 0.0010
# Epoch 4/100
# 856/856 [==============================] - ETA: 0s - loss: 34.1679 - mae: 4.6006
# Epoch 4: val_loss improved from 4475.89551 to 620.25336, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 145s 169ms/step - loss: 34.1679 - mae: 4.6006 - val_loss: 620.2534 - val_mae: 20.9962 - lr: 0.0010
# Epoch 5/100
# 856/856 [==============================] - ETA: 0s - loss: 32.3346 - mae: 4.4656
# Epoch 5: val_loss did not improve from 620.25336
# 856/856 [==============================] - 143s 167ms/step - loss: 32.3346 - mae: 4.4656 - val_loss: 1923.3752 - val_mae: 34.9810 - lr: 0.0010
# Epoch 6/100
# 856/856 [==============================] - ETA: 0s - loss: 30.5785 - mae: 4.3428
# Epoch 6: val_loss did not improve from 620.25336
# 856/856 [==============================] - 150s 175ms/step - loss: 30.5785 - mae: 4.3428 - val_loss: 917.5546 - val_mae: 25.7819 - lr: 0.0010
# Epoch 7/100
# 856/856 [==============================] - ETA: 0s - loss: 29.6444 - mae: 4.2760
# Epoch 7: val_loss did not improve from 620.25336
# 856/856 [==============================] - 147s 171ms/step - loss: 29.6444 - mae: 4.2760 - val_loss: 7477921280.0000 - val_mae: 83033.6719 - lr: 0.0010
# Epoch 8/100
# 856/856 [==============================] - ETA: 0s - loss: 28.8688 - mae: 4.2164
# Epoch 8: val_loss did not improve from 620.25336
# 856/856 [==============================] - 144s 167ms/step - loss: 28.8688 - mae: 4.2164 - val_loss: 15006532608.0000 - val_mae: 118980.5859 - lr: 0.0010
# Epoch 9/100
# 856/856 [==============================] - ETA: 0s - loss: 28.7790 - mae: 4.2083
# Epoch 9: val_loss did not improve from 620.25336
# 856/856 [==============================] - 146s 170ms/step - loss: 28.7790 - mae: 4.2083 - val_loss: 596241416192.0000 - val_mae: 767644.6250 - lr: 0.0010
# Epoch 10/100
# 856/856 [==============================] - ETA: 0s - loss: 28.1377 - mae: 4.1671
# Epoch 10: val_loss did not improve from 620.25336
# 856/856 [==============================] - 150s 175ms/step - loss: 28.1377 - mae: 4.1671 - val_loss: 123386863616.0000 - val_mae: 350152.8125 - lr: 0.0010
# Epoch 11/100
# 856/856 [==============================] - ETA: 0s - loss: 28.1151 - mae: 4.1647
# Epoch 11: val_loss did not improve from 620.25336
# 856/856 [==============================] - 146s 170ms/step - loss: 28.1151 - mae: 4.1647 - val_loss: 122573896.0000 - val_mae: 10950.1504 - lr: 0.0010
# Epoch 12/100
# 856/856 [==============================] - ETA: 0s - loss: 27.5763 - mae: 4.1306
# Epoch 12: val_loss did not improve from 620.25336
# 856/856 [==============================] - 153s 177ms/step - loss: 27.5763 - mae: 4.1306 - val_loss: 2922633984.0000 - val_mae: 53621.8438 - lr: 0.0010
# Epoch 13/100
# 856/856 [==============================] - ETA: 0s - loss: 27.5306 - mae: 4.1160
# Epoch 13: val_loss did not improve from 620.25336
# 856/856 [==============================] - 146s 170ms/step - loss: 27.5306 - mae: 4.1160 - val_loss: 20710.4941 - val_mae: 139.4545 - lr: 0.0010
# Epoch 14/100
# 856/856 [==============================] - ETA: 0s - loss: 27.4275 - mae: 4.1088
# Epoch 14: val_loss did not improve from 620.25336
# 856/856 [==============================] - 144s 167ms/step - loss: 27.4275 - mae: 4.1088 - val_loss: 292593.8438 - val_mae: 484.6667 - lr: 0.0010
# Epoch 15/100
# 856/856 [==============================] - ETA: 0s - loss: 27.2031 - mae: 4.0920
# Epoch 15: val_loss did not improve from 620.25336
# 856/856 [==============================] - 145s 169ms/step - loss: 27.2031 - mae: 4.0920 - val_loss: 7163212.0000 - val_mae: 2661.0486 - lr: 0.0010
# Epoch 16/100
# 856/856 [==============================] - ETA: 0s - loss: 27.2469 - mae: 4.0899
# Epoch 16: val_loss did not improve from 620.25336
# 856/856 [==============================] - 146s 170ms/step - loss: 27.2469 - mae: 4.0899 - val_loss: 8175.2485 - val_mae: 86.9033 - lr: 0.0010
# Epoch 17/100
# 856/856 [==============================] - ETA: 0s - loss: 26.7387 - mae: 4.0637
# Epoch 17: val_loss did not improve from 620.25336
# 856/856 [==============================] - 145s 169ms/step - loss: 26.7387 - mae: 4.0637 - val_loss: 16419.2578 - val_mae: 124.5397 - lr: 0.0010
# Epoch 18/100
# 856/856 [==============================] - ETA: 0s - loss: 26.8971 - mae: 4.0694
# Epoch 18: val_loss did not improve from 620.25336
# 856/856 [==============================] - 152s 176ms/step - loss: 26.8971 - mae: 4.0694 - val_loss: 5307.2876 - val_mae: 65.9998 - lr: 0.0010
# Epoch 19/100
# 856/856 [==============================] - ETA: 0s - loss: 26.6290 - mae: 4.0519
# Epoch 19: val_loss did not improve from 620.25336
# 856/856 [==============================] - 151s 176ms/step - loss: 26.6290 - mae: 4.0519 - val_loss: 3705.4565 - val_mae: 56.4038 - lr: 0.0010
# Epoch 20/100
# 856/856 [==============================] - ETA: 0s - loss: 26.5266 - mae: 4.0430
# Epoch 20: val_loss did not improve from 620.25336
# 856/856 [==============================] - 151s 176ms/step - loss: 26.5266 - mae: 4.0430 - val_loss: 905.7535 - val_mae: 24.2031 - lr: 0.0010
# Epoch 21/100
# 856/856 [==============================] - ETA: 0s - loss: 26.5783 - mae: 4.0447
# Epoch 21: val_loss did not improve from 620.25336
# 856/856 [==============================] - 158s 184ms/step - loss: 26.5783 - mae: 4.0447 - val_loss: 16938.0645 - val_mae: 126.5518 - lr: 0.0010
# Epoch 22/100
# 856/856 [==============================] - ETA: 0s - loss: 25.9214 - mae: 3.9951
# Epoch 22: val_loss did not improve from 620.25336
# 856/856 [==============================] - 144s 168ms/step - loss: 25.9214 - mae: 3.9951 - val_loss: 823.3760 - val_mae: 22.3942 - lr: 0.0010
# Epoch 23/100
# 856/856 [==============================] - ETA: 0s - loss: 25.9489 - mae: 3.9946
# Epoch 23: val_loss did not improve from 620.25336
# 856/856 [==============================] - 144s 167ms/step - loss: 25.9489 - mae: 3.9946 - val_loss: 86493.9297 - val_mae: 258.9720 - lr: 0.0010
# Epoch 24/100
# 856/856 [==============================] - ETA: 0s - loss: 26.3097 - mae: 4.0246
# Epoch 24: val_loss did not improve from 620.25336
# 856/856 [==============================] - 144s 168ms/step - loss: 26.3097 - mae: 4.0246 - val_loss: 933.7792 - val_mae: 25.6703 - lr: 0.0010
# Epoch 25/100
# 856/856 [==============================] - ETA: 0s - loss: 26.1206 - mae: 4.0102
# Epoch 25: val_loss improved from 620.25336 to 423.81213, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 156s 181ms/step - loss: 26.1206 - mae: 4.0102 - val_loss: 423.8121 - val_mae: 17.7018 - lr: 0.0010
# Epoch 26/100
# 856/856 [==============================] - ETA: 0s - loss: 25.7891 - mae: 3.9898
# Epoch 26: val_loss improved from 423.81213 to 285.28311, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 147s 171ms/step - loss: 25.7891 - mae: 3.9898 - val_loss: 285.2831 - val_mae: 14.0571 - lr: 0.0010
# Epoch 27/100
# 856/856 [==============================] - ETA: 0s - loss: 26.0688 - mae: 4.0042
# Epoch 27: val_loss did not improve from 285.28311
# 856/856 [==============================] - 151s 176ms/step - loss: 26.0688 - mae: 4.0042 - val_loss: 4323.0703 - val_mae: 57.1684 - lr: 0.0010
# Epoch 28/100
# 856/856 [==============================] - ETA: 0s - loss: 25.9043 - mae: 4.0011
# Epoch 28: val_loss improved from 285.28311 to 17.76746, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 156s 182ms/step - loss: 25.9043 - mae: 4.0011 - val_loss: 17.7675 - val_mae: 3.1633 - lr: 0.0010
# Epoch 29/100
# 856/856 [==============================] - ETA: 0s - loss: 25.7533 - mae: 3.9883
# Epoch 29: val_loss did not improve from 17.76746
# 856/856 [==============================] - 149s 173ms/step - loss: 25.7533 - mae: 3.9883 - val_loss: 14775.3232 - val_mae: 117.7143 - lr: 0.0010
# Epoch 30/100
# 856/856 [==============================] - ETA: 0s - loss: 25.5327 - mae: 3.9607
# Epoch 30: val_loss did not improve from 17.76746
# 856/856 [==============================] - 144s 167ms/step - loss: 25.5327 - mae: 3.9607 - val_loss: 3578633.5000 - val_mae: 1872.7329 - lr: 0.0010
# Epoch 31/100
# 856/856 [==============================] - ETA: 0s - loss: 25.6484 - mae: 3.9733
# Epoch 31: val_loss did not improve from 17.76746
# 856/856 [==============================] - 148s 172ms/step - loss: 25.6484 - mae: 3.9733 - val_loss: 10542584.0000 - val_mae: 3225.3647 - lr: 0.0010
# Epoch 32/100
# 856/856 [==============================] - ETA: 0s - loss: 25.7947 - mae: 3.9860
# Epoch 32: val_loss did not improve from 17.76746
# 856/856 [==============================] - 145s 168ms/step - loss: 25.7947 - mae: 3.9860 - val_loss: 583466.1875 - val_mae: 751.3696 - lr: 0.0010
# Epoch 33/100
# 856/856 [==============================] - ETA: 0s - loss: 25.3461 - mae: 3.9510
# Epoch 33: val_loss did not improve from 17.76746
# 856/856 [==============================] - 147s 171ms/step - loss: 25.3461 - mae: 3.9510 - val_loss: 7620.9614 - val_mae: 84.4461 - lr: 0.0010
# Epoch 34/100
# 856/856 [==============================] - ETA: 0s - loss: 25.6367 - mae: 3.9728
# Epoch 34: val_loss did not improve from 17.76746
# 856/856 [==============================] - 147s 171ms/step - loss: 25.6367 - mae: 3.9728 - val_loss: 157.2699 - val_mae: 10.6318 - lr: 0.0010
# Epoch 35/100
# 856/856 [==============================] - ETA: 0s - loss: 25.3174 - mae: 3.9476
# Epoch 35: val_loss did not improve from 17.76746
# 856/856 [==============================] - 145s 169ms/step - loss: 25.3174 - mae: 3.9476 - val_loss: 319.7788 - val_mae: 14.9996 - lr: 0.0010
# Epoch 36/100
# 856/856 [==============================] - ETA: 0s - loss: 25.4614 - mae: 3.9614
# Epoch 36: val_loss did not improve from 17.76746
# 856/856 [==============================] - 146s 169ms/step - loss: 25.4614 - mae: 3.9614 - val_loss: 2136.2505 - val_mae: 37.5881 - lr: 0.0010
# Epoch 37/100
# 856/856 [==============================] - ETA: 0s - loss: 25.4640 - mae: 3.9630
# Epoch 37: val_loss did not improve from 17.76746
# 856/856 [==============================] - 143s 166ms/step - loss: 25.4640 - mae: 3.9630 - val_loss: 195.0085 - val_mae: 11.1622 - lr: 0.0010
# Epoch 38/100
# 856/856 [==============================] - ETA: 0s - loss: 25.1040 - mae: 3.9301
# Epoch 38: val_loss did not improve from 17.76746
# 856/856 [==============================] - 144s 168ms/step - loss: 25.1040 - mae: 3.9301 - val_loss: 106.7740 - val_mae: 8.7466 - lr: 0.0010
# Epoch 39/100
# 856/856 [==============================] - ETA: 0s - loss: 25.0113 - mae: 3.9170
# Epoch 39: val_loss did not improve from 17.76746
# 856/856 [==============================] - 142s 165ms/step - loss: 25.0113 - mae: 3.9170 - val_loss: 2202.5676 - val_mae: 35.6642 - lr: 0.0010
# Epoch 40/100
# 856/856 [==============================] - ETA: 0s - loss: 25.1293 - mae: 3.9336
# Epoch 40: val_loss did not improve from 17.76746
# 856/856 [==============================] - 143s 167ms/step - loss: 25.1293 - mae: 3.9336 - val_loss: 16810.1055 - val_mae: 126.7203 - lr: 0.0010
# Epoch 41/100
# 856/856 [==============================] - ETA: 0s - loss: 25.0092 - mae: 3.9249
# Epoch 41: val_loss did not improve from 17.76746
# 856/856 [==============================] - 143s 167ms/step - loss: 25.0092 - mae: 3.9249 - val_loss: 1764.7997 - val_mae: 35.1910 - lr: 0.0010
# Epoch 42/100
# 856/856 [==============================] - ETA: 0s - loss: 24.8947 - mae: 3.9151
# Epoch 42: val_loss did not improve from 17.76746
# 856/856 [==============================] - 150s 174ms/step - loss: 24.8947 - mae: 3.9151 - val_loss: 1115.0160 - val_mae: 26.7574 - lr: 0.0010
# Epoch 43/100
# 856/856 [==============================] - ETA: 0s - loss: 24.7820 - mae: 3.9024
# Epoch 43: val_loss did not improve from 17.76746
# 856/856 [==============================] - 146s 170ms/step - loss: 24.7820 - mae: 3.9024 - val_loss: 12871.4580 - val_mae: 109.2032 - lr: 0.0010
# Epoch 44/100
# 856/856 [==============================] - ETA: 0s - loss: 24.7770 - mae: 3.8990
# Epoch 44: val_loss did not improve from 17.76746
# 856/856 [==============================] - 143s 167ms/step - loss: 24.7770 - mae: 3.8990 - val_loss: 4536.0586 - val_mae: 61.4336 - lr: 0.0010
# Epoch 45/100
# 856/856 [==============================] - ETA: 0s - loss: 24.8484 - mae: 3.9087
# Epoch 45: val_loss did not improve from 17.76746
# 856/856 [==============================] - 142s 166ms/step - loss: 24.8484 - mae: 3.9087 - val_loss: 2796.5581 - val_mae: 42.7470 - lr: 0.0010
# Epoch 46/100
# 856/856 [==============================] - ETA: 0s - loss: 24.6354 - mae: 3.8942
# Epoch 46: val_loss did not improve from 17.76746
# 856/856 [==============================] - 145s 168ms/step - loss: 24.6354 - mae: 3.8942 - val_loss: 1441.5355 - val_mae: 33.1429 - lr: 0.0010
# Epoch 47/100
# 856/856 [==============================] - ETA: 0s - loss: 24.6623 - mae: 3.8933
# Epoch 47: val_loss did not improve from 17.76746
# 856/856 [==============================] - 144s 167ms/step - loss: 24.6623 - mae: 3.8933 - val_loss: 147.4645 - val_mae: 9.7750 - lr: 0.0010
# Epoch 48/100
# 856/856 [==============================] - ETA: 0s - loss: 24.5626 - mae: 3.8786
# Epoch 48: val_loss did not improve from 17.76746
# 856/856 [==============================] - 146s 170ms/step - loss: 24.5626 - mae: 3.8786 - val_loss: 14062.3154 - val_mae: 115.3841 - lr: 0.0010
# Epoch 49/100
# 856/856 [==============================] - ETA: 0s - loss: 24.5814 - mae: 3.8878
# Epoch 49: val_loss did not improve from 17.76746
# 856/856 [==============================] - 146s 170ms/step - loss: 24.5814 - mae: 3.8878 - val_loss: 1283.1021 - val_mae: 29.3390 - lr: 0.0010
# Epoch 50/100
# 856/856 [==============================] - ETA: 0s - loss: 24.5664 - mae: 3.8830
# Epoch 50: val_loss did not improve from 17.76746
# 856/856 [==============================] - 142s 166ms/step - loss: 24.5664 - mae: 3.8830 - val_loss: 13693.8994 - val_mae: 113.8148 - lr: 0.0010
# Epoch 51/100
# 856/856 [==============================] - ETA: 0s - loss: 23.6109 - mae: 3.8152
# Epoch 51: val_loss improved from 17.76746 to 9.80660, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 143s 167ms/step - loss: 23.6109 - mae: 3.8152 - val_loss: 9.8066 - val_mae: 2.2748 - lr: 1.0000e-04
# Epoch 52/100
# 856/856 [==============================] - ETA: 0s - loss: 23.4371 - mae: 3.7905
# Epoch 52: val_loss did not improve from 9.80660
# 856/856 [==============================] - 144s 167ms/step - loss: 23.4371 - mae: 3.7905 - val_loss: 39.1460 - val_mae: 4.9626 - lr: 1.0000e-04
# Epoch 53/100
# 856/856 [==============================] - ETA: 0s - loss: 23.4841 - mae: 3.7963
# Epoch 53: val_loss did not improve from 9.80660
# 856/856 [==============================] - 143s 167ms/step - loss: 23.4841 - mae: 3.7963 - val_loss: 103.5295 - val_mae: 7.9975 - lr: 1.0000e-04
# Epoch 54/100
# 856/856 [==============================] - ETA: 0s - loss: 23.4672 - mae: 3.8016
# Epoch 54: val_loss did not improve from 9.80660
# 856/856 [==============================] - 143s 167ms/step - loss: 23.4672 - mae: 3.8016 - val_loss: 142.1491 - val_mae: 8.9912 - lr: 1.0000e-04
# Epoch 55/100
# 856/856 [==============================] - ETA: 0s - loss: 23.9107 - mae: 3.8299
# Epoch 55: val_loss improved from 9.80660 to 4.41614, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 145s 168ms/step - loss: 23.9107 - mae: 3.8299 - val_loss: 4.4161 - val_mae: 1.5599 - lr: 1.0000e-04
# Epoch 56/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3379 - mae: 3.7875
# Epoch 56: val_loss did not improve from 4.41614
# 856/856 [==============================] - 150s 174ms/step - loss: 23.3379 - mae: 3.7875 - val_loss: 54.7856 - val_mae: 6.0431 - lr: 1.0000e-04
# Epoch 57/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2593 - mae: 3.7830
# Epoch 57: val_loss did not improve from 4.41614
# 856/856 [==============================] - 146s 170ms/step - loss: 23.2593 - mae: 3.7830 - val_loss: 104.3519 - val_mae: 8.1407 - lr: 1.0000e-04
# Epoch 58/100
# 856/856 [==============================] - ETA: 0s - loss: 23.4142 - mae: 3.7934
# Epoch 58: val_loss did not improve from 4.41614
# 856/856 [==============================] - 147s 171ms/step - loss: 23.4142 - mae: 3.7934 - val_loss: 99.1405 - val_mae: 7.5863 - lr: 1.0000e-04
# Epoch 59/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2190 - mae: 3.7774
# Epoch 59: val_loss did not improve from 4.41614
# 856/856 [==============================] - 146s 170ms/step - loss: 23.2190 - mae: 3.7774 - val_loss: 1432.8492 - val_mae: 31.5950 - lr: 1.0000e-04
# Epoch 60/100
# 856/856 [==============================] - ETA: 0s - loss: 23.5665 - mae: 3.8016
# Epoch 60: val_loss did not improve from 4.41614
# 856/856 [==============================] - 144s 168ms/step - loss: 23.5665 - mae: 3.8016 - val_loss: 154.0931 - val_mae: 7.2032 - lr: 1.0000e-04
# Epoch 61/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2831 - mae: 3.7818
# Epoch 61: val_loss did not improve from 4.41614
# 856/856 [==============================] - 145s 168ms/step - loss: 23.2831 - mae: 3.7818 - val_loss: 21.8337 - val_mae: 3.6836 - lr: 1.0000e-04
# Epoch 62/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1894 - mae: 3.7728
# Epoch 62: val_loss improved from 4.41614 to 3.50238, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 147s 172ms/step - loss: 23.1894 - mae: 3.7728 - val_loss: 3.5024 - val_mae: 1.3549 - lr: 1.0000e-04
# Epoch 63/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1881 - mae: 3.7730
# Epoch 63: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 167ms/step - loss: 23.1881 - mae: 3.7730 - val_loss: 27.4303 - val_mae: 3.6328 - lr: 1.0000e-04
# Epoch 64/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3093 - mae: 3.7776
# Epoch 64: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 171ms/step - loss: 23.3093 - mae: 3.7776 - val_loss: 70.8908 - val_mae: 6.3176 - lr: 1.0000e-04
# Epoch 65/100
# 856/856 [==============================] - ETA: 0s - loss: 23.5315 - mae: 3.8057
# Epoch 65: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 170ms/step - loss: 23.5315 - mae: 3.8057 - val_loss: 7.7758 - val_mae: 2.2088 - lr: 1.0000e-04
# Epoch 66/100
# 856/856 [==============================] - ETA: 0s - loss: 22.8481 - mae: 3.7460
# Epoch 66: val_loss did not improve from 3.50238
# 856/856 [==============================] - 152s 177ms/step - loss: 22.8481 - mae: 3.7460 - val_loss: 61.5073 - val_mae: 6.2846 - lr: 1.0000e-04
# Epoch 67/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3577 - mae: 3.7776
# Epoch 67: val_loss did not improve from 3.50238
# 856/856 [==============================] - 145s 169ms/step - loss: 23.3577 - mae: 3.7776 - val_loss: 100.9321 - val_mae: 7.9316 - lr: 1.0000e-04
# Epoch 68/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1222 - mae: 3.7685
# Epoch 68: val_loss did not improve from 3.50238
# 856/856 [==============================] - 153s 178ms/step - loss: 23.1222 - mae: 3.7685 - val_loss: 48.5953 - val_mae: 5.3993 - lr: 1.0000e-04
# Epoch 69/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9994 - mae: 3.7598
# Epoch 69: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 168ms/step - loss: 22.9994 - mae: 3.7598 - val_loss: 8.4112 - val_mae: 2.2581 - lr: 1.0000e-04
# Epoch 70/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3444 - mae: 3.7834
# Epoch 70: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 168ms/step - loss: 23.3444 - mae: 3.7834 - val_loss: 6.4783 - val_mae: 1.9300 - lr: 1.0000e-04
# Epoch 71/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0935 - mae: 3.7658
# Epoch 71: val_loss did not improve from 3.50238
# 856/856 [==============================] - 142s 166ms/step - loss: 23.0935 - mae: 3.7658 - val_loss: 24.9600 - val_mae: 3.9897 - lr: 1.0000e-04
# Epoch 72/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3284 - mae: 3.7778
# Epoch 72: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 168ms/step - loss: 23.3284 - mae: 3.7778 - val_loss: 22.8399 - val_mae: 3.7322 - lr: 1.0000e-04
# Epoch 73/100
# 856/856 [==============================] - ETA: 0s - loss: 23.3363 - mae: 3.7812
# Epoch 73: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 167ms/step - loss: 23.3363 - mae: 3.7812 - val_loss: 880.4647 - val_mae: 21.8183 - lr: 1.0000e-04
# Epoch 74/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1778 - mae: 3.7712
# Epoch 74: val_loss did not improve from 3.50238
# 856/856 [==============================] - 145s 169ms/step - loss: 23.1778 - mae: 3.7712 - val_loss: 50.0593 - val_mae: 5.8116 - lr: 1.0000e-04
# Epoch 75/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2087 - mae: 3.7707
# Epoch 75: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 170ms/step - loss: 23.2087 - mae: 3.7707 - val_loss: 62.2243 - val_mae: 4.9885 - lr: 1.0000e-04
# Epoch 76/100
# 856/856 [==============================] - ETA: 0s - loss: 23.4834 - mae: 3.7934
# Epoch 76: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 167ms/step - loss: 23.4834 - mae: 3.7934 - val_loss: 266.5342 - val_mae: 8.8264 - lr: 1.0000e-04
# Epoch 77/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2118 - mae: 3.7777
# Epoch 77: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 166ms/step - loss: 23.2118 - mae: 3.7777 - val_loss: 65.3256 - val_mae: 5.9693 - lr: 1.0000e-04
# Epoch 78/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0110 - mae: 3.7545
# Epoch 78: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 167ms/step - loss: 23.0110 - mae: 3.7545 - val_loss: 54.6423 - val_mae: 6.1013 - lr: 1.0000e-04
# Epoch 79/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0428 - mae: 3.7587
# Epoch 79: val_loss did not improve from 3.50238
# 856/856 [==============================] - 152s 176ms/step - loss: 23.0428 - mae: 3.7587 - val_loss: 3579.5317 - val_mae: 52.7373 - lr: 1.0000e-04
# Epoch 80/100
# 856/856 [==============================] - ETA: 0s - loss: 22.8839 - mae: 3.7501
# Epoch 80: val_loss did not improve from 3.50238
# 856/856 [==============================] - 145s 169ms/step - loss: 22.8839 - mae: 3.7501 - val_loss: 7.3706 - val_mae: 1.9839 - lr: 1.0000e-04
# Epoch 81/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9481 - mae: 3.7512
# Epoch 81: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 171ms/step - loss: 22.9481 - mae: 3.7512 - val_loss: 11.7961 - val_mae: 2.6118 - lr: 1.0000e-04
# Epoch 82/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2623 - mae: 3.7746
# Epoch 82: val_loss did not improve from 3.50238
# 856/856 [==============================] - 145s 169ms/step - loss: 23.2623 - mae: 3.7746 - val_loss: 56.7646 - val_mae: 5.7339 - lr: 1.0000e-04
# Epoch 83/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1363 - mae: 3.7660
# Epoch 83: val_loss did not improve from 3.50238
# 856/856 [==============================] - 145s 168ms/step - loss: 23.1363 - mae: 3.7660 - val_loss: 7.3737 - val_mae: 2.1065 - lr: 1.0000e-04
# Epoch 84/100
# 856/856 [==============================] - ETA: 0s - loss: 23.2570 - mae: 3.7826
# Epoch 84: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 168ms/step - loss: 23.2570 - mae: 3.7826 - val_loss: 18.5929 - val_mae: 3.3452 - lr: 1.0000e-04
# Epoch 85/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1468 - mae: 3.7686
# Epoch 85: val_loss did not improve from 3.50238
# 856/856 [==============================] - 149s 174ms/step - loss: 23.1468 - mae: 3.7686 - val_loss: 37.4975 - val_mae: 4.7416 - lr: 1.0000e-04
# Epoch 86/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0321 - mae: 3.7545
# Epoch 86: val_loss did not improve from 3.50238
# 856/856 [==============================] - 151s 175ms/step - loss: 23.0321 - mae: 3.7545 - val_loss: 74.6498 - val_mae: 5.1707 - lr: 1.0000e-04
# Epoch 87/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0128 - mae: 3.7594
# Epoch 87: val_loss did not improve from 3.50238
# 856/856 [==============================] - 150s 174ms/step - loss: 23.0128 - mae: 3.7594 - val_loss: 33.6599 - val_mae: 4.7871 - lr: 1.0000e-04
# Epoch 88/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9418 - mae: 3.7545
# Epoch 88: val_loss did not improve from 3.50238
# 856/856 [==============================] - 149s 173ms/step - loss: 22.9418 - mae: 3.7545 - val_loss: 49.3880 - val_mae: 5.8908 - lr: 1.0000e-04
# Epoch 89/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0337 - mae: 3.7612
# Epoch 89: val_loss did not improve from 3.50238
# 856/856 [==============================] - 153s 177ms/step - loss: 23.0337 - mae: 3.7612 - val_loss: 14.3158 - val_mae: 2.7638 - lr: 1.0000e-04
# Epoch 90/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0922 - mae: 3.7624
# Epoch 90: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 170ms/step - loss: 23.0922 - mae: 3.7624 - val_loss: 6862.8032 - val_mae: 77.0795 - lr: 1.0000e-04
# Epoch 91/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1491 - mae: 3.7638
# Epoch 91: val_loss did not improve from 3.50238
# 856/856 [==============================] - 142s 166ms/step - loss: 23.1491 - mae: 3.7638 - val_loss: 46.5501 - val_mae: 5.5610 - lr: 1.0000e-04
# Epoch 92/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9682 - mae: 3.7534
# Epoch 92: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 167ms/step - loss: 22.9682 - mae: 3.7534 - val_loss: 91.0864 - val_mae: 7.2247 - lr: 1.0000e-04
# Epoch 93/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9375 - mae: 3.7547
# Epoch 93: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 170ms/step - loss: 22.9375 - mae: 3.7547 - val_loss: 19.6200 - val_mae: 3.4429 - lr: 1.0000e-04
# Epoch 94/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1727 - mae: 3.7715
# Epoch 94: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 168ms/step - loss: 23.1727 - mae: 3.7715 - val_loss: 2738.2632 - val_mae: 47.0595 - lr: 1.0000e-04
# Epoch 95/100
# 856/856 [==============================] - ETA: 0s - loss: 23.0264 - mae: 3.7520
# Epoch 95: val_loss did not improve from 3.50238
# 856/856 [==============================] - 143s 167ms/step - loss: 23.0264 - mae: 3.7520 - val_loss: 28.2801 - val_mae: 3.9966 - lr: 1.0000e-04
# Epoch 96/100
# 856/856 [==============================] - ETA: 0s - loss: 22.7744 - mae: 3.7387
# Epoch 96: val_loss did not improve from 3.50238
# 856/856 [==============================] - 146s 170ms/step - loss: 22.7744 - mae: 3.7387 - val_loss: 209.6661 - val_mae: 7.8952 - lr: 1.0000e-04
# Epoch 97/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9240 - mae: 3.7462
# Epoch 97: val_loss did not improve from 3.50238
# 856/856 [==============================] - 147s 170ms/step - loss: 22.9240 - mae: 3.7462 - val_loss: 77.4947 - val_mae: 6.4467 - lr: 1.0000e-04
# Epoch 98/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1091 - mae: 3.7611
# Epoch 98: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 167ms/step - loss: 23.1091 - mae: 3.7611 - val_loss: 15.7788 - val_mae: 3.0168 - lr: 1.0000e-04
# Epoch 99/100
# 856/856 [==============================] - ETA: 0s - loss: 22.8839 - mae: 3.7436
# Epoch 99: val_loss did not improve from 3.50238
# 856/856 [==============================] - 144s 167ms/step - loss: 22.8839 - mae: 3.7436 - val_loss: 36.7317 - val_mae: 4.5915 - lr: 1.0000e-04
# Epoch 100/100
# 856/856 [==============================] - ETA: 0s - loss: 23.1025 - mae: 3.7658
# Epoch 100: val_loss improved from 3.50238 to 3.10394, saving model to v3l_b16_lr001.h5
# 856/856 [==============================] - 143s 166ms/step - loss: 23.1025 - mae: 3.7658 - val_loss: 3.1039 - val_mae: 1.2559 - lr: 1.0000e-04

# %%
# 평균 에포크 시간 계산 및 출력
average_epoch_time = np.mean(time_callback.times)
print(f"에포크당 평균 소요 시간: {average_epoch_time:.2f}초")
# Out:
# 에포크당 평균 소요 시간: 146.58초

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'][50:], label='Train Loss')
plt.plot(history.history['val_loss'][50:], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'][50:], label='Train MAE')
plt.plot(history.history['val_mae'][50:], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()

# %%
b_m = tf.keras.models.load_model('v3l_b16_lr001.h5')

# %%
def plot_predicted_keypoints(model, image_path, image_dir, original_width=720, original_height=1280, target_size=224):
    """
    모델을 사용하여 이미지의 키포인트를 예측하고 시각화하는 함수.

    Parameters:
        model (tf.keras.Model): 사전 학습된 모델.
        image_path (str): 예측할 이미지의 경로.
        image_dir (str): 이미지가 저장된 디렉토리 경로.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.
        target_size (int): 모델의 입력 이미지 크기.
    """
    # 이미지 로드 및 전처리
    image_full_path = os.path.join(image_dir, image_path)
    image = cv2.imread(image_full_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_full_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 원본 크기와 종횡비 계산
    orig_h, orig_w = image_rgb.shape[:2]
    scale = min(target_size / orig_w, target_size / orig_h)
    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)

    print(f"Original size: ({orig_w}, {orig_h})")
    print(f"Scale factor: {scale}")
    print(f"Resized size: ({new_w}, {new_h})")

    # 종횡비 유지하며 리사이징
    image_resized = cv2.resize(image_rgb, (new_w, new_h)) / 255.0

    # 패딩 추가
    pad_w = target_size - new_w
    pad_h = target_size - new_h
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top

    print(f"Padding (left, top): ({pad_left}, {pad_top})")
    print(f"Padding (right, bottom): ({pad_right}, {pad_bottom})")

    image_padded = cv2.copyMakeBorder(
        image_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=0
    )

    # 모델 입력 준비
    input_image = np.expand_dims(image_padded, axis=0).astype(np.float32)

    # 예측
    predicted_keypoints = model.predict(input_image)[0]

    # print(f"Predicted keypoints (raw): {predicted_keypoints}")

    # 키포인트 스케일 조정 및 이동 (패딩 고려)
    # 전처리 시 사용된 스케일과 동일하게 되돌리기
    scale_back = 1 / scale

    x_scaled = (predicted_keypoints[::2] - pad_left) * scale_back
    y_scaled = (predicted_keypoints[1::2] - pad_top) * scale_back

    # print(f"Scaled keypoints (x): {x_scaled}")
    # print(f"Scaled keypoints (y): {y_scaled}")

    predicted_keypoints_scaled = np.empty_like(predicted_keypoints)
    predicted_keypoints_scaled[::2] = x_scaled
    predicted_keypoints_scaled[1::2] = y_scaled

    # print(f"Scaled keypoints (combined): {predicted_keypoints_scaled}")

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)

    for i in range(0, len(predicted_keypoints_scaled), 2):
        x = predicted_keypoints_scaled[i]
        y = predicted_keypoints_scaled[i + 1]
        # 키포인트가 이미지 범위 내에 있는지 확인
        if 0 <= x < orig_w and 0 <= y < orig_h:
            plt.scatter(x, y, c='r', s=10)

    plt.title('Predicted Keypoints')
    plt.axis('off')
    plt.show()

# 예측 및 시각화
sample_image_path = val_image_paths[50]
plot_predicted_keypoints(b_m, sample_image_path, val_image_dir)
# Out:
# Original size: (720, 1280)
# Scale factor: 0.175
# Resized size: (125, 224)
# Padding (left, top): (49, 0)
# Padding (right, bottom): (50, 0)
# 1/1 [==============================] - 1s 1s/step
