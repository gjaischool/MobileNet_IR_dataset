# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow_addons as tfa
from tensorflow.keras import mixed_precision
import keras

# %% [markdown]
# # 데이터셋 로더

# %%
# **1. GPU 메모리 성장 설정 (가장 먼저 실행)**
physical_devices = tf.config.list_physical_devices('GPU')
for gpu in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(f"메모리 성장 설정 완료: {gpu}")
    except RuntimeError as e:
        print(f"메모리 성장 설정 실패: {gpu} - {e}")

# **2. 분산 전략 설정**
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# **3. Mixed Precision 비활성화**
policy = mixed_precision.Policy('float32')
mixed_precision.set_global_policy(policy)

# **4. 데이터셋 로더 함수**
def load_data(csv_file, image_dir):
    df = pd.read_csv(csv_file)
    image_paths = df['image_path'].tolist()
    keypoints = df.iloc[:, 1:].values.astype(np.float32)
    return image_paths, keypoints

# **5. 키포인트 스케일링 함수 정의**
def scale_keypoints(keypoints, original_width=720, original_height=1280, target_size=224):
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    x_scale = target_size / original_width
    y_scale = target_size / original_height
    x_scaled = x_coords * x_scale
    y_scaled = y_coords * y_scale
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    return scaled_keypoints

# **6. 데이터 증강 함수 정의 (현재 사용 안 함)**
def augment(image, keypoints):
    # 랜덤 회전
    angle = tf.random.uniform([], -15, 15, dtype=tf.float32)
    angle_rad = angle * np.pi / 180.0
    image = tfa.image.rotate(image, angles=angle_rad, fill_mode='nearest')
    
    # 키포인트 회전
    center_x = 720.0 / 2 * (224 / 720.0)  # 224x224 이미지 기준 (720 -> 224)
    center_y = 1280.0 / 2 * (224 / 1280.0)  # 1280 -> 224
    rotation_matrix = tf.reshape([
        tf.cos(angle_rad), -tf.sin(angle_rad),
        tf.sin(angle_rad), tf.cos(angle_rad)
    ], [2, 2])
    keypoints = tf.reshape(keypoints, [NUM_KEYPOINTS, 2])
    keypoints = tf.matmul(keypoints - tf.constant([center_x, center_y]), rotation_matrix) + tf.constant([center_x, center_y])
    keypoints = tf.reshape(keypoints, [-1])
    
    return image, keypoints

# **7. 이미지 및 키포인트 전처리 함수 (종횡비 유지 및 패딩 추가)**
def preprocess_image(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    """
    이미지와 키포인트를 전처리하는 함수.

    Parameters:
        image_path (tf.Tensor): 이미지 파일 경로.
        keypoints (tf.Tensor): 키포인트 좌표.
        image_dir (tf.Tensor): 이미지가 저장된 디렉토리 경로.
        target_size (int): 모델 입력 이미지의 크기.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.

    Returns:
        image (tf.Tensor): 전처리된 이미지.
        scaled_keypoints (tf.Tensor): 스케일 조정된 키포인트 좌표.
    """
    # 이미지 경로 결합
    image_full_path = tf.strings.join([image_dir, '/', image_path])
    
    # 이미지 로드 및 디코드
    image = tf.io.read_file(image_full_path)
    image = tf.image.decode_jpeg(image, channels=3)
    
    # 이미지가 정상적으로 로드되었는지 확인하고, float32로 변환 및 [0,1] 범위로 스케일링
    image = tf.cond(tf.equal(tf.size(image), 0),
                   lambda: tf.zeros([target_size, target_size, 3], dtype=tf.float32),
                   lambda: tf.image.convert_image_dtype(image, tf.float32))
    
    # 원본 크기 가져오기
    orig_shape = tf.shape(image)[:2]
    orig_height_img = tf.cast(orig_shape[0], tf.float32)
    orig_width_img = tf.cast(orig_shape[1], tf.float32)
    
    # 종횡비 유지하며 리사이징
    scale = tf.minimum(target_size / orig_width_img, target_size / orig_height_img)
    new_width = tf.cast(tf.round(orig_width_img * scale), tf.int32)
    new_height = tf.cast(tf.round(orig_height_img * scale), tf.int32)
    
    image = tf.image.resize(image, [new_height, new_width])
    
    # 패딩 추가하여 타겟 사이즈 맞추기
    pad_width = target_size - new_width
    pad_height = target_size - new_height
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    
    image = tf.pad(image, [[pad_top, pad_bottom], [pad_left, pad_right], [0, 0]], constant_values=0)
    
    # 키포인트 스케일 조정 및 이동
    keypoints = tf.convert_to_tensor(keypoints, dtype=tf.float32)
    x_coords = keypoints[::2]
    y_coords = keypoints[1::2]
    
    # 스케일링
    x_scale = scale
    y_scale = scale
    
    x_scaled = x_coords * x_scale + tf.cast(pad_left, tf.float32)
    y_scaled = y_coords * y_scale + tf.cast(pad_top, tf.float32)
    
    scaled_keypoints = tf.stack([x_scaled, y_scaled], axis=1)
    scaled_keypoints = tf.reshape(scaled_keypoints, [-1])
    
    return image, scaled_keypoints

# **8. 데이터셋 전처리 및 증강 함수**
def preprocess_image_aug(image_path, keypoints, image_dir, target_size=224, original_width=720, original_height=1280):
    image, keypoints = preprocess_image(image_path, keypoints, image_dir, target_size, original_width, original_height)
    image, keypoints = augment(image, keypoints)
    return image, keypoints

# **9. 데이터셋 생성 함수 수정**
def create_dataset(image_paths, keypoints, image_dir, batch_size=64, shuffle=True, augment_data=False, target_size=224, original_width=720, original_height=1280):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, keypoints))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(image_paths))
    
    # image_dir을 TensorFlow 상수로 변환
    image_dir_tf = tf.constant(image_dir)
    
    if augment_data:
        # 데이터 증강 적용
        dataset = dataset.map(lambda x, y: preprocess_image_aug(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        # 데이터 증강 미적용
        dataset = dataset.map(lambda x, y: preprocess_image(x, y, image_dir_tf, target_size, original_width, original_height), num_parallel_calls=tf.data.AUTOTUNE)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset
# Out:
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 메모리 성장 설정 완료: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# Number of devices: 3
# 2024-11-01 06:08:34.263915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.266014: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.267980: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.343072: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.345061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.346970: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.348876: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.350804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:34.352706: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.313816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.350907: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.352852: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.355010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.356998: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.358783: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.360690: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.362624: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.364399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.397097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.399085: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.400906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.402813: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.404757: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.406539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.408446: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.410384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11333 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:08.0, compute capability: 7.5
# 2024-11-01 06:08:35.410928: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.412712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11857 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5
# 2024-11-01 06:08:35.416333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-01 06:08:35.418216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 11857 MB memory:  -> device: 2, name: Tesla T4, pci bus id: 0000:00:0a.0, compute capability: 7.5

# %%
# CSV 파일 경로
train_csv = 'keras_dataset/annotations/train_annotations.csv'
val_csv = 'keras_dataset/annotations/val_annotations.csv'

# 이미지 디렉토리
train_image_dir = 'keras_dataset/images/train'
val_image_dir = 'keras_dataset/images/val'

# 로드된 데이터
train_image_paths, train_keypoints = load_data(train_csv, train_image_dir)
val_image_paths, val_keypoints = load_data(val_csv, val_image_dir)

# 전체 배치 크기 설정
BATCH_SIZE_PER_REPLICA = 16  # 각 GPU당 배치 크기 (메모리 문제를 방지하기 위해 줄임)
GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync  # 전체 배치 크기

# 훈련 및 검증 데이터셋 생성
train_dataset = create_dataset(
    train_image_paths, 
    train_keypoints, 
    train_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=True, 
    augment_data=False,  # 현재 데이터 증강 비활성화
    target_size=224, 
    original_width=720, 
    original_height=1280
)

val_dataset = create_dataset(
    val_image_paths, 
    val_keypoints, 
    val_image_dir, 
    batch_size=GLOBAL_BATCH_SIZE, 
    shuffle=False, 
    augment_data=False, 
    target_size=224, 
    original_width=720, 
    original_height=1280
)

# %% [markdown]
# # 키포인트 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터셋 일부 시각화 (디버깅 용도)
def visualize_sample(image, keypoints, title='Sample'):
    image_np = image.numpy()
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np)
    # 키포인트를 224x224 이미지에 맞게 그리기
    x = keypoints[::2].numpy()
    y = keypoints[1::2].numpy()
    plt.scatter(x, y, c='r', s=10)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# 데이터셋에서 샘플 가져오기
for images, keypoints in train_dataset.take(1):
    for i in range(3):  # 첫 3개 샘플 시각화
        visualize_sample(images[i], keypoints[i], title=f"Sample {i+1}")

# %% [markdown]
# # 모델학습

# %%
len(base_model.layers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(base_model.layers)
#
# NameError: name 'base_model' is not defined

# %%
import keras

# 키포인트 수
NUM_KEYPOINTS = 70

# 전략 범위 내에서 모델 정의 및 컴파일
with strategy.scope():
    # 백본 모델 로드 (pre-trained MobileNetV2)
    base_model = MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
    
    # 백본 모델 고정
    # base_model.trainable = False
    
    # 글로벌 풀링
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    
    # 출력 레이어: 70개의 키포인트, 각 키포인트에 대해 x, y 좌표
    x = Dense(NUM_KEYPOINTS * 2, activation='linear', dtype='float32')(x)  # mixed precision 시 출력 dtype 설정
    
    # 모델 정의
    model = Model(inputs=base_model.input, outputs=x)
    
    # 모델 컴파일
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 140)                  179340    ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2437324 (9.30 MB)
# Trainable params: 2403212 (9.17 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
# 콜백 설정
checkpoint = ModelCheckpoint('b16_lr001.h5', monitor='val_loss', save_best_only=True, verbose=1)
# early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# 모델 훈련
EPOCHS = 100

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2024-10-28 05:22:24.451990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-28 05:22:24.467089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-28 05:22:24.487155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-10-28 05:22:28.029979: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc6d7420710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-28 05:22:28.030026: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-10-28 05:22:28.030033: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-10-28 05:22:28.030039: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla T4, Compute Capability 7.5
# 2024-10-28 05:22:28.039863: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-28 05:22:28.160431: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 856/856 [==============================] - ETA: 0s - loss: 936.6008 - mae: 16.5950
# Epoch 1: val_loss improved from inf to 663.65753, saving model to b16_lr001.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 234s 198ms/step - loss: 936.6008 - mae: 16.5950 - val_loss: 663.6575 - val_mae: 21.9923
# Epoch 2/100
# 856/856 [==============================] - ETA: 0s - loss: 38.2587 - mae: 4.8392
# Epoch 2: val_loss improved from 663.65753 to 269.20139, saving model to b16_lr001.h5
# 856/856 [==============================] - 162s 189ms/step - loss: 38.2587 - mae: 4.8392 - val_loss: 269.2014 - val_mae: 14.0423
# Epoch 3/100
# 856/856 [==============================] - ETA: 0s - loss: 30.5274 - mae: 4.3352
# Epoch 3: val_loss improved from 269.20139 to 133.36177, saving model to b16_lr001.h5
# 856/856 [==============================] - 159s 184ms/step - loss: 30.5274 - mae: 4.3352 - val_loss: 133.3618 - val_mae: 9.2837
# Epoch 4/100
# 856/856 [==============================] - ETA: 0s - loss: 28.0682 - mae: 4.1584
# Epoch 4: val_loss did not improve from 133.36177
# 856/856 [==============================] - 164s 191ms/step - loss: 28.0682 - mae: 4.1584 - val_loss: 7242.5381 - val_mae: 82.4428
# Epoch 5/100
# 856/856 [==============================] - ETA: 0s - loss: 26.8907 - mae: 4.0648
# Epoch 5: val_loss did not improve from 133.36177
# 856/856 [==============================] - 165s 192ms/step - loss: 26.8907 - mae: 4.0648 - val_loss: 1981.1382 - val_mae: 38.8752
# Epoch 6/100
# 856/856 [==============================] - ETA: 0s - loss: 25.7499 - mae: 3.9767
# Epoch 6: val_loss improved from 133.36177 to 101.37454, saving model to b16_lr001.h5
# 856/856 [==============================] - 165s 192ms/step - loss: 25.7499 - mae: 3.9767 - val_loss: 101.3745 - val_mae: 8.7005
# Epoch 7/100
# 856/856 [==============================] - ETA: 0s - loss: 24.2361 - mae: 3.8621
# Epoch 7: val_loss improved from 101.37454 to 91.40085, saving model to b16_lr001.h5
# 856/856 [==============================] - 166s 193ms/step - loss: 24.2361 - mae: 3.8621 - val_loss: 91.4008 - val_mae: 8.1486
# Epoch 8/100
# 856/856 [==============================] - ETA: 0s - loss: 23.7106 - mae: 3.8208
# Epoch 8: val_loss did not improve from 91.40085
# 856/856 [==============================] - 165s 193ms/step - loss: 23.7106 - mae: 3.8208 - val_loss: 1574.4680 - val_mae: 35.4862
# Epoch 9/100
# 856/856 [==============================] - ETA: 0s - loss: 22.9357 - mae: 3.7573
# Epoch 9: val_loss did not improve from 91.40085
# 856/856 [==============================] - 165s 192ms/step - loss: 22.9357 - mae: 3.7573 - val_loss: 112.6242 - val_mae: 8.9221
# Epoch 10/100
# 856/856 [==============================] - ETA: 0s - loss: 22.7188 - mae: 3.7359
# Epoch 10: val_loss did not improve from 91.40085
# 856/856 [==============================] - 166s 194ms/step - loss: 22.7188 - mae: 3.7359 - val_loss: 2617.4446 - val_mae: 48.9579
# Epoch 11/100
# 856/856 [==============================] - ETA: 0s - loss: 22.5014 - mae: 3.7241
# Epoch 11: val_loss improved from 91.40085 to 62.44513, saving model to b16_lr001.h5
# 856/856 [==============================] - 162s 189ms/step - loss: 22.5014 - mae: 3.7241 - val_loss: 62.4451 - val_mae: 6.7751
# Epoch 12/100
# 856/856 [==============================] - ETA: 0s - loss: 22.5280 - mae: 3.7252
# Epoch 12: val_loss did not improve from 62.44513
# 856/856 [==============================] - 164s 191ms/step - loss: 22.5280 - mae: 3.7252 - val_loss: 105.9932 - val_mae: 8.1492
# Epoch 13/100
# 856/856 [==============================] - ETA: 0s - loss: 22.0569 - mae: 3.6834
# Epoch 13: val_loss did not improve from 62.44513
# 856/856 [==============================] - 166s 193ms/step - loss: 22.0569 - mae: 3.6834 - val_loss: 3919.2539 - val_mae: 59.6964
# Epoch 14/100
# 856/856 [==============================] - ETA: 0s - loss: 22.0496 - mae: 3.6857
# Epoch 14: val_loss did not improve from 62.44513
# 856/856 [==============================] - 164s 191ms/step - loss: 22.0496 - mae: 3.6857 - val_loss: 861.5994 - val_mae: 26.6989
# Epoch 15/100
# 856/856 [==============================] - ETA: 0s - loss: 21.8621 - mae: 3.6727
# Epoch 15: val_loss improved from 62.44513 to 57.30274, saving model to b16_lr001.h5
# 856/856 [==============================] - 163s 190ms/step - loss: 21.8621 - mae: 3.6727 - val_loss: 57.3027 - val_mae: 6.3899
# Epoch 16/100
# 856/856 [==============================] - ETA: 0s - loss: 21.6501 - mae: 3.6533
# Epoch 16: val_loss improved from 57.30274 to 49.99883, saving model to b16_lr001.h5
# 856/856 [==============================] - 163s 190ms/step - loss: 21.6501 - mae: 3.6533 - val_loss: 49.9988 - val_mae: 6.0157
# Epoch 17/100
# 856/856 [==============================] - ETA: 0s - loss: 21.4376 - mae: 3.6313
# Epoch 17: val_loss did not improve from 49.99883
# 856/856 [==============================] - 164s 191ms/step - loss: 21.4376 - mae: 3.6313 - val_loss: 77.2371 - val_mae: 7.3502
# Epoch 18/100
# 856/856 [==============================] - ETA: 0s - loss: 21.3371 - mae: 3.6297
# Epoch 18: val_loss improved from 49.99883 to 30.37062, saving model to b16_lr001.h5
# 856/856 [==============================] - 164s 191ms/step - loss: 21.3371 - mae: 3.6297 - val_loss: 30.3706 - val_mae: 4.6344
# Epoch 19/100
# 856/856 [==============================] - ETA: 0s - loss: 21.4891 - mae: 3.6296
# Epoch 19: val_loss improved from 30.37062 to 28.45297, saving model to b16_lr001.h5
# 856/856 [==============================] - 164s 191ms/step - loss: 21.4891 - mae: 3.6296 - val_loss: 28.4530 - val_mae: 4.5915
# Epoch 20/100
# 856/856 [==============================] - ETA: 0s - loss: 21.0613 - mae: 3.6033
# Epoch 20: val_loss did not improve from 28.45297
# 856/856 [==============================] - 165s 192ms/step - loss: 21.0613 - mae: 3.6033 - val_loss: 1976.0320 - val_mae: 43.3296
# Epoch 21/100
# 856/856 [==============================] - ETA: 0s - loss: 20.8967 - mae: 3.5911
# Epoch 21: val_loss did not improve from 28.45297
# 856/856 [==============================] - 164s 191ms/step - loss: 20.8967 - mae: 3.5911 - val_loss: 38.7152 - val_mae: 5.3069
# Epoch 22/100
# 856/856 [==============================] - ETA: 0s - loss: 20.8960 - mae: 3.5855
# Epoch 22: val_loss did not improve from 28.45297
# 856/856 [==============================] - 163s 190ms/step - loss: 20.8960 - mae: 3.5855 - val_loss: 428.4508 - val_mae: 18.2014
# Epoch 23/100
# 856/856 [==============================] - ETA: 0s - loss: 20.8156 - mae: 3.5755
# Epoch 23: val_loss did not improve from 28.45297
# 856/856 [==============================] - 158s 184ms/step - loss: 20.8156 - mae: 3.5755 - val_loss: 4454.6260 - val_mae: 65.4006
# Epoch 24/100
# 856/856 [==============================] - ETA: 0s - loss: 20.5025 - mae: 3.5571
# Epoch 24: val_loss improved from 28.45297 to 11.32049, saving model to b16_lr001.h5
# 856/856 [==============================] - 152s 177ms/step - loss: 20.5025 - mae: 3.5571 - val_loss: 11.3205 - val_mae: 2.7955
# Epoch 25/100
# 856/856 [==============================] - ETA: 0s - loss: 20.7060 - mae: 3.5671
# Epoch 25: val_loss did not improve from 11.32049
# 856/856 [==============================] - 151s 176ms/step - loss: 20.7060 - mae: 3.5671 - val_loss: 20.1883 - val_mae: 3.5969
# Epoch 26/100
# 856/856 [==============================] - ETA: 0s - loss: 20.4635 - mae: 3.5488
# Epoch 26: val_loss did not improve from 11.32049
# 856/856 [==============================] - 155s 181ms/step - loss: 20.4635 - mae: 3.5488 - val_loss: 12.7462 - val_mae: 2.5848
# Epoch 27/100
# 856/856 [==============================] - ETA: 0s - loss: 20.6358 - mae: 3.5633
# Epoch 27: val_loss did not improve from 11.32049
# 856/856 [==============================] - 151s 176ms/step - loss: 20.6358 - mae: 3.5633 - val_loss: 12346.0117 - val_mae: 109.3046
# Epoch 28/100
# 856/856 [==============================] - ETA: 0s - loss: 20.2559 - mae: 3.5361
# Epoch 28: val_loss did not improve from 11.32049
# 856/856 [==============================] - 155s 181ms/step - loss: 20.2559 - mae: 3.5361 - val_loss: 9235.3027 - val_mae: 94.5371
# Epoch 29/100
# 856/856 [==============================] - ETA: 0s - loss: 20.1065 - mae: 3.5170
# Epoch 29: val_loss did not improve from 11.32049
# 856/856 [==============================] - 153s 178ms/step - loss: 20.1065 - mae: 3.5170 - val_loss: 11.9136 - val_mae: 2.8271
# Epoch 30/100
# 855/856 [============================>.] - ETA: 0s - loss: 19.8929 - mae: 3.4980
# Epoch 30: val_loss did not improve from 11.32049
# 856/856 [==============================] - 158s 183ms/step - loss: 19.8925 - mae: 3.4980 - val_loss: 22.6602 - val_mae: 3.8088
# Epoch 31/100
# 856/856 [==============================] - ETA: 0s - loss: 19.9799 - mae: 3.5025
# Epoch 31: val_loss improved from 11.32049 to 7.03414, saving model to b16_lr001.h5
# 856/856 [==============================] - 148s 173ms/step - loss: 19.9799 - mae: 3.5025 - val_loss: 7.0341 - val_mae: 2.1125
# Epoch 32/100
# 856/856 [==============================] - ETA: 0s - loss: 20.1715 - mae: 3.5230
# Epoch 32: val_loss did not improve from 7.03414
# 856/856 [==============================] - 153s 178ms/step - loss: 20.1715 - mae: 3.5230 - val_loss: 1115.4875 - val_mae: 32.4515
# Epoch 33/100
# 856/856 [==============================] - ETA: 0s - loss: 19.7981 - mae: 3.4914
# Epoch 33: val_loss did not improve from 7.03414
# 856/856 [==============================] - 153s 178ms/step - loss: 19.7981 - mae: 3.4914 - val_loss: 5812.2793 - val_mae: 75.1064
# Epoch 34/100
# 856/856 [==============================] - ETA: 0s - loss: 19.8379 - mae: 3.4969
# Epoch 34: val_loss did not improve from 7.03414
# 856/856 [==============================] - 152s 177ms/step - loss: 19.8379 - mae: 3.4969 - val_loss: 7393.2939 - val_mae: 84.7806
# Epoch 35/100
# 856/856 [==============================] - ETA: 0s - loss: 20.0062 - mae: 3.5109
# Epoch 35: val_loss did not improve from 7.03414
# 856/856 [==============================] - 153s 178ms/step - loss: 20.0062 - mae: 3.5109 - val_loss: 23.0132 - val_mae: 4.0053
# Epoch 36/100
# 856/856 [==============================] - ETA: 0s - loss: 19.7631 - mae: 3.4903
# Epoch 36: val_loss did not improve from 7.03414
# 856/856 [==============================] - 152s 177ms/step - loss: 19.7631 - mae: 3.4903 - val_loss: 1192.7937 - val_mae: 33.8964
# Epoch 37/100
# 856/856 [==============================] - ETA: 0s - loss: 19.5269 - mae: 3.4668
# Epoch 37: val_loss did not improve from 7.03414
# 856/856 [==============================] - 152s 177ms/step - loss: 19.5269 - mae: 3.4668 - val_loss: 686.9899 - val_mae: 25.1999
# Epoch 38/100
# 856/856 [==============================] - ETA: 0s - loss: 19.6909 - mae: 3.4860
# Epoch 38: val_loss did not improve from 7.03414
# 856/856 [==============================] - 159s 185ms/step - loss: 19.6909 - mae: 3.4860 - val_loss: 11.2917 - val_mae: 2.8595
# Epoch 39/100
# 856/856 [==============================] - ETA: 0s - loss: 19.6678 - mae: 3.4800
# Epoch 39: val_loss did not improve from 7.03414
# 856/856 [==============================] - 165s 192ms/step - loss: 19.6678 - mae: 3.4800 - val_loss: 1673.5704 - val_mae: 40.1896
# Epoch 40/100
# 856/856 [==============================] - ETA: 0s - loss: 19.6321 - mae: 3.4755
# Epoch 40: val_loss improved from 7.03414 to 4.98453, saving model to b16_lr001.h5
# 856/856 [==============================] - 165s 192ms/step - loss: 19.6321 - mae: 3.4755 - val_loss: 4.9845 - val_mae: 1.6621
# Epoch 41/100
# 856/856 [==============================] - ETA: 0s - loss: 19.4891 - mae: 3.4664
# Epoch 41: val_loss did not improve from 4.98453
# 856/856 [==============================] - 165s 192ms/step - loss: 19.4891 - mae: 3.4664 - val_loss: 7099.7192 - val_mae: 83.0097
# Epoch 42/100
# 856/856 [==============================] - ETA: 0s - loss: 19.5913 - mae: 3.4633
# Epoch 42: val_loss did not improve from 4.98453
# 856/856 [==============================] - 166s 193ms/step - loss: 19.5913 - mae: 3.4633 - val_loss: 109.7966 - val_mae: 9.6232
# Epoch 43/100
# 856/856 [==============================] - ETA: 0s - loss: 19.2141 - mae: 3.4403
# Epoch 43: val_loss did not improve from 4.98453
# 856/856 [==============================] - 163s 190ms/step - loss: 19.2141 - mae: 3.4403 - val_loss: 1664.8445 - val_mae: 39.9437
# Epoch 44/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1373 - mae: 3.4312
# Epoch 44: val_loss did not improve from 4.98453
# 856/856 [==============================] - 164s 191ms/step - loss: 19.1373 - mae: 3.4312 - val_loss: 9.2670 - val_mae: 2.3521
# Epoch 45/100
# 856/856 [==============================] - ETA: 0s - loss: 19.4644 - mae: 3.4556
# Epoch 45: val_loss did not improve from 4.98453
# 856/856 [==============================] - 164s 191ms/step - loss: 19.4644 - mae: 3.4556 - val_loss: 17.9239 - val_mae: 3.5177
# Epoch 46/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1728 - mae: 3.4332
# Epoch 46: val_loss did not improve from 4.98453
# 856/856 [==============================] - 164s 191ms/step - loss: 19.1728 - mae: 3.4332 - val_loss: 2766.3696 - val_mae: 51.8450
# Epoch 47/100
# 856/856 [==============================] - ETA: 0s - loss: 19.3668 - mae: 3.4555
# Epoch 47: val_loss did not improve from 4.98453
# 856/856 [==============================] - 166s 194ms/step - loss: 19.3668 - mae: 3.4555 - val_loss: 713.0049 - val_mae: 26.0227
# Epoch 48/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1351 - mae: 3.4327
# Epoch 48: val_loss did not improve from 4.98453
# 856/856 [==============================] - 161s 188ms/step - loss: 19.1351 - mae: 3.4327 - val_loss: 12.0314 - val_mae: 3.0562
# Epoch 49/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1323 - mae: 3.4313
# Epoch 49: val_loss did not improve from 4.98453
# 856/856 [==============================] - 162s 189ms/step - loss: 19.1323 - mae: 3.4313 - val_loss: 22.2872 - val_mae: 3.9005
# Epoch 50/100
# 856/856 [==============================] - ETA: 0s - loss: 19.2072 - mae: 3.4368
# Epoch 50: val_loss improved from 4.98453 to 3.94132, saving model to b16_lr001.h5
# 856/856 [==============================] - 163s 190ms/step - loss: 19.2072 - mae: 3.4368 - val_loss: 3.9413 - val_mae: 1.5165
# Epoch 51/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1401 - mae: 3.4275
# Epoch 51: val_loss did not improve from 3.94132
# 856/856 [==============================] - 162s 189ms/step - loss: 19.1401 - mae: 3.4275 - val_loss: 109.1440 - val_mae: 9.4918
# Epoch 52/100
# 856/856 [==============================] - ETA: 0s - loss: 19.1547 - mae: 3.4357
# Epoch 52: val_loss improved from 3.94132 to 3.79312, saving model to b16_lr001.h5
# 856/856 [==============================] - 162s 188ms/step - loss: 19.1547 - mae: 3.4357 - val_loss: 3.7931 - val_mae: 1.4610
# Epoch 53/100
# 856/856 [==============================] - ETA: 0s - loss: 18.9974 - mae: 3.4135
# Epoch 53: val_loss did not improve from 3.79312
# 856/856 [==============================] - 163s 189ms/step - loss: 18.9974 - mae: 3.4135 - val_loss: 17.9473 - val_mae: 3.5193
# Epoch 54/100
# 856/856 [==============================] - ETA: 0s - loss: 18.9949 - mae: 3.4162
# Epoch 54: val_loss did not improve from 3.79312
# 856/856 [==============================] - 161s 188ms/step - loss: 18.9949 - mae: 3.4162 - val_loss: 4.9310 - val_mae: 1.7034
# Epoch 55/100
# 856/856 [==============================] - ETA: 0s - loss: 18.8962 - mae: 3.4091
# Epoch 55: val_loss did not improve from 3.79312
# 856/856 [==============================] - 164s 190ms/step - loss: 18.8962 - mae: 3.4091 - val_loss: 9.7538 - val_mae: 2.6837
# Epoch 56/100
# 856/856 [==============================] - ETA: 0s - loss: 18.8689 - mae: 3.4066
# Epoch 56: val_loss did not improve from 3.79312
# 856/856 [==============================] - 163s 190ms/step - loss: 18.8689 - mae: 3.4066 - val_loss: 6.0399 - val_mae: 2.0257
# Epoch 57/100
# 856/856 [==============================] - ETA: 0s - loss: 18.8671 - mae: 3.4063
# Epoch 57: val_loss did not improve from 3.79312
# 856/856 [==============================] - 163s 190ms/step - loss: 18.8671 - mae: 3.4063 - val_loss: 9.9950 - val_mae: 2.6743
# Epoch 58/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6808 - mae: 3.3910
# Epoch 58: val_loss did not improve from 3.79312
# 856/856 [==============================] - 169s 196ms/step - loss: 18.6808 - mae: 3.3910 - val_loss: 15.0459 - val_mae: 3.3337
# Epoch 59/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6306 - mae: 3.3846
# Epoch 59: val_loss did not improve from 3.79312
# 856/856 [==============================] - 168s 196ms/step - loss: 18.6306 - mae: 3.3846 - val_loss: 4.8288 - val_mae: 1.7037
# Epoch 60/100
# 856/856 [==============================] - ETA: 0s - loss: 18.8363 - mae: 3.4049
# Epoch 60: val_loss did not improve from 3.79312
# 856/856 [==============================] - 168s 196ms/step - loss: 18.8363 - mae: 3.4049 - val_loss: 12.9659 - val_mae: 3.0614
# Epoch 61/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6661 - mae: 3.3851
# Epoch 61: val_loss improved from 3.79312 to 3.26729, saving model to b16_lr001.h5
# 856/856 [==============================] - 172s 200ms/step - loss: 18.6661 - mae: 3.3851 - val_loss: 3.2673 - val_mae: 1.3383
# Epoch 62/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6382 - mae: 3.3883
# Epoch 62: val_loss did not improve from 3.26729
# 856/856 [==============================] - 164s 191ms/step - loss: 18.6382 - mae: 3.3883 - val_loss: 3.7186 - val_mae: 1.4789
# Epoch 63/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6951 - mae: 3.3832
# Epoch 63: val_loss did not improve from 3.26729
# 856/856 [==============================] - 175s 204ms/step - loss: 18.6951 - mae: 3.3832 - val_loss: 2951.1133 - val_mae: 53.5234
# Epoch 64/100
# 856/856 [==============================] - ETA: 0s - loss: 18.5766 - mae: 3.3758
# Epoch 64: val_loss improved from 3.26729 to 2.90543, saving model to b16_lr001.h5
# 856/856 [==============================] - 167s 195ms/step - loss: 18.5766 - mae: 3.3758 - val_loss: 2.9054 - val_mae: 1.2293
# Epoch 65/100
# 856/856 [==============================] - ETA: 0s - loss: 18.6032 - mae: 3.3831
# Epoch 65: val_loss did not improve from 2.90543
# 856/856 [==============================] - 169s 197ms/step - loss: 18.6032 - mae: 3.3831 - val_loss: 6.2538 - val_mae: 1.9917
# Epoch 66/100
# 856/856 [==============================] - ETA: 0s - loss: 18.4521 - mae: 3.3669
# Epoch 66: val_loss did not improve from 2.90543
# 856/856 [==============================] - 167s 194ms/step - loss: 18.4521 - mae: 3.3669 - val_loss: 10.8364 - val_mae: 2.8114
# Epoch 67/100
# 856/856 [==============================] - ETA: 0s - loss: 18.4264 - mae: 3.3614
# Epoch 67: val_loss did not improve from 2.90543
# 856/856 [==============================] - 166s 193ms/step - loss: 18.4264 - mae: 3.3614 - val_loss: 3.4199 - val_mae: 1.3946
# Epoch 68/100
# 856/856 [==============================] - ETA: 0s - loss: 18.4740 - mae: 3.3725
# Epoch 68: val_loss did not improve from 2.90543
# 856/856 [==============================] - 167s 195ms/step - loss: 18.4740 - mae: 3.3725 - val_loss: 12.0105 - val_mae: 2.8155
# Epoch 69/100
# 856/856 [==============================] - ETA: 0s - loss: 18.2427 - mae: 3.3505
# Epoch 69: val_loss did not improve from 2.90543
# 856/856 [==============================] - 165s 192ms/step - loss: 18.2427 - mae: 3.3505 - val_loss: 235.0711 - val_mae: 14.2596
# Epoch 70/100
# 856/856 [==============================] - ETA: 0s - loss: 18.2709 - mae: 3.3496
# Epoch 70: val_loss did not improve from 2.90543
# 856/856 [==============================] - 165s 192ms/step - loss: 18.2709 - mae: 3.3496 - val_loss: 3.4452 - val_mae: 1.3983
# Epoch 71/100
# 856/856 [==============================] - ETA: 0s - loss: 18.3496 - mae: 3.3551
# Epoch 71: val_loss did not improve from 2.90543
# 856/856 [==============================] - 166s 194ms/step - loss: 18.3496 - mae: 3.3551 - val_loss: 19.4408 - val_mae: 3.8765
# Epoch 72/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1970 - mae: 3.3428
# Epoch 72: val_loss did not improve from 2.90543
# 856/856 [==============================] - 166s 193ms/step - loss: 18.1970 - mae: 3.3428 - val_loss: 17.0537 - val_mae: 3.2931
# Epoch 73/100
# 856/856 [==============================] - ETA: 0s - loss: 18.2952 - mae: 3.3553
# Epoch 73: val_loss did not improve from 2.90543
# 856/856 [==============================] - 163s 190ms/step - loss: 18.2952 - mae: 3.3553 - val_loss: 82.5741 - val_mae: 7.8137
# Epoch 74/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0807 - mae: 3.3370
# Epoch 74: val_loss did not improve from 2.90543
# 856/856 [==============================] - 165s 192ms/step - loss: 18.0807 - mae: 3.3370 - val_loss: 5842.7061 - val_mae: 75.1525
# Epoch 75/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0136 - mae: 3.3253
# Epoch 75: val_loss did not improve from 2.90543
# 856/856 [==============================] - 171s 199ms/step - loss: 18.0136 - mae: 3.3253 - val_loss: 4.1838 - val_mae: 1.5146
# Epoch 76/100
# 856/856 [==============================] - ETA: 0s - loss: 18.2166 - mae: 3.3471
# Epoch 76: val_loss did not improve from 2.90543
# 856/856 [==============================] - 167s 195ms/step - loss: 18.2166 - mae: 3.3471 - val_loss: 127.2448 - val_mae: 10.0495
# Epoch 77/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0682 - mae: 3.3329
# Epoch 77: val_loss did not improve from 2.90543
# 856/856 [==============================] - 162s 189ms/step - loss: 18.0682 - mae: 3.3329 - val_loss: 8.0618 - val_mae: 2.3664
# Epoch 78/100
# 856/856 [==============================] - ETA: 0s - loss: 18.3048 - mae: 3.3559
# Epoch 78: val_loss did not improve from 2.90543
# 856/856 [==============================] - 164s 191ms/step - loss: 18.3048 - mae: 3.3559 - val_loss: 3.5515 - val_mae: 1.3978
# Epoch 79/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1301 - mae: 3.3379
# Epoch 79: val_loss did not improve from 2.90543
# 856/856 [==============================] - 167s 194ms/step - loss: 18.1301 - mae: 3.3379 - val_loss: 8.2003 - val_mae: 2.2585
# Epoch 80/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0235 - mae: 3.3284
# Epoch 80: val_loss did not improve from 2.90543
# 856/856 [==============================] - 166s 193ms/step - loss: 18.0235 - mae: 3.3284 - val_loss: 29.3644 - val_mae: 4.2879
# Epoch 81/100
# 856/856 [==============================] - ETA: 0s - loss: 17.9554 - mae: 3.3218
# Epoch 81: val_loss did not improve from 2.90543
# 856/856 [==============================] - 164s 191ms/step - loss: 17.9554 - mae: 3.3218 - val_loss: 4.1249 - val_mae: 1.5603
# Epoch 82/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0164 - mae: 3.3277
# Epoch 82: val_loss did not improve from 2.90543
# 856/856 [==============================] - 162s 188ms/step - loss: 18.0164 - mae: 3.3277 - val_loss: 42.9817 - val_mae: 5.8161
# Epoch 83/100
# 856/856 [==============================] - ETA: 0s - loss: 17.9087 - mae: 3.3129
# Epoch 83: val_loss improved from 2.90543 to 2.88290, saving model to b16_lr001.h5
# 856/856 [==============================] - 164s 190ms/step - loss: 17.9087 - mae: 3.3129 - val_loss: 2.8829 - val_mae: 1.2605
# Epoch 84/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7590 - mae: 3.3049
# Epoch 84: val_loss did not improve from 2.88290
# 856/856 [==============================] - 162s 189ms/step - loss: 17.7590 - mae: 3.3049 - val_loss: 14.5612 - val_mae: 3.0481
# Epoch 85/100
# 856/856 [==============================] - ETA: 0s - loss: 17.9891 - mae: 3.3221
# Epoch 85: val_loss did not improve from 2.88290
# 856/856 [==============================] - 159s 185ms/step - loss: 17.9891 - mae: 3.3221 - val_loss: 3.3550 - val_mae: 1.3772
# Epoch 86/100
# 856/856 [==============================] - ETA: 0s - loss: 17.8567 - mae: 3.3089
# Epoch 86: val_loss did not improve from 2.88290
# 856/856 [==============================] - 164s 191ms/step - loss: 17.8567 - mae: 3.3089 - val_loss: 3.1502 - val_mae: 1.3247
# Epoch 87/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7461 - mae: 3.3019
# Epoch 87: val_loss did not improve from 2.88290
# 856/856 [==============================] - 167s 194ms/step - loss: 17.7461 - mae: 3.3019 - val_loss: 129.0759 - val_mae: 10.2597
# Epoch 88/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7389 - mae: 3.3032
# Epoch 88: val_loss did not improve from 2.88290
# 856/856 [==============================] - 162s 188ms/step - loss: 17.7389 - mae: 3.3032 - val_loss: 8.7630 - val_mae: 2.4659
# Epoch 89/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7182 - mae: 3.3005
# Epoch 89: val_loss did not improve from 2.88290
# 856/856 [==============================] - 152s 177ms/step - loss: 17.7182 - mae: 3.3005 - val_loss: 9.1253 - val_mae: 2.5031
# Epoch 90/100
# 856/856 [==============================] - ETA: 0s - loss: 17.6490 - mae: 3.2930
# Epoch 90: val_loss did not improve from 2.88290
# 856/856 [==============================] - 154s 179ms/step - loss: 17.6490 - mae: 3.2930 - val_loss: 7.6284 - val_mae: 2.1345
# Epoch 91/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7450 - mae: 3.2988
# Epoch 91: val_loss did not improve from 2.88290
# 856/856 [==============================] - 156s 181ms/step - loss: 17.7450 - mae: 3.2988 - val_loss: 2.9886 - val_mae: 1.2746
# Epoch 92/100
# 856/856 [==============================] - ETA: 0s - loss: 17.5707 - mae: 3.2841
# Epoch 92: val_loss did not improve from 2.88290
# 856/856 [==============================] - 161s 188ms/step - loss: 17.5707 - mae: 3.2841 - val_loss: 5650.3872 - val_mae: 73.7236
# Epoch 93/100
# 856/856 [==============================] - ETA: 0s - loss: 17.6870 - mae: 3.2952
# Epoch 93: val_loss did not improve from 2.88290
# 856/856 [==============================] - 161s 187ms/step - loss: 17.6870 - mae: 3.2952 - val_loss: 1447.6075 - val_mae: 36.9696
# Epoch 94/100
# 856/856 [==============================] - ETA: 0s - loss: 17.8691 - mae: 3.3139
# Epoch 94: val_loss did not improve from 2.88290
# 856/856 [==============================] - 171s 199ms/step - loss: 17.8691 - mae: 3.3139 - val_loss: 17.8624 - val_mae: 3.4330
# Epoch 95/100
# 856/856 [==============================] - ETA: 0s - loss: 17.5748 - mae: 3.2824
# Epoch 95: val_loss did not improve from 2.88290
# 856/856 [==============================] - 165s 191ms/step - loss: 17.5748 - mae: 3.2824 - val_loss: 9.7900 - val_mae: 2.6542
# Epoch 96/100
# 856/856 [==============================] - ETA: 0s - loss: 17.4872 - mae: 3.2729
# Epoch 96: val_loss did not improve from 2.88290
# 856/856 [==============================] - 156s 181ms/step - loss: 17.4872 - mae: 3.2729 - val_loss: 2.9008 - val_mae: 1.2117
# Epoch 97/100
# 856/856 [==============================] - ETA: 0s - loss: 17.3944 - mae: 3.2661
# Epoch 97: val_loss did not improve from 2.88290
# 856/856 [==============================] - 161s 187ms/step - loss: 17.3944 - mae: 3.2661 - val_loss: 48.8392 - val_mae: 5.9342
# Epoch 98/100
# 856/856 [==============================] - ETA: 0s - loss: 17.5449 - mae: 3.2781
# Epoch 98: val_loss did not improve from 2.88290
# 856/856 [==============================] - 159s 186ms/step - loss: 17.5449 - mae: 3.2781 - val_loss: 4.0592 - val_mae: 1.5631
# Epoch 99/100
# 856/856 [==============================] - ETA: 0s - loss: 17.4613 - mae: 3.2728
# Epoch 99: val_loss did not improve from 2.88290
# 856/856 [==============================] - 163s 190ms/step - loss: 17.4613 - mae: 3.2728 - val_loss: 3.6996 - val_mae: 1.4519
# Epoch 100/100
# 856/856 [==============================] - ETA: 0s - loss: 17.3954 - mae: 3.2700
# Epoch 100: val_loss did not improve from 2.88290
# 856/856 [==============================] - 164s 190ms/step - loss: 17.3954 - mae: 3.2700 - val_loss: 3.9990 - val_mae: 1.5584

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()

# %%
b_m = tf.keras.models.load_model('b16_lr001.h5')

# %%
def plot_predicted_keypoints(model, image_path, image_dir, original_width=720, original_height=1280, target_size=224):
    """
    모델을 사용하여 이미지의 키포인트를 예측하고 시각화하는 함수.

    Parameters:
        model (tf.keras.Model): 사전 학습된 모델.
        image_path (str): 예측할 이미지의 경로.
        image_dir (str): 이미지가 저장된 디렉토리 경로.
        original_width (int): 원본 이미지의 너비.
        original_height (int): 원본 이미지의 높이.
        target_size (int): 모델의 입력 이미지 크기.
    """
    # 이미지 로드 및 전처리
    image_full_path = os.path.join(image_dir, image_path)
    image = cv2.imread(image_full_path)
    if image is None:
        print(f"이미지를 불러올 수 없습니다: {image_full_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 원본 크기와 종횡비 계산
    orig_h, orig_w = image_rgb.shape[:2]
    scale = min(target_size / orig_w, target_size / orig_h)
    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)

    print(f"Original size: ({orig_w}, {orig_h})")
    print(f"Scale factor: {scale}")
    print(f"Resized size: ({new_w}, {new_h})")

    # 종횡비 유지하며 리사이징
    image_resized = cv2.resize(image_rgb, (new_w, new_h)) / 255.0

    # 패딩 추가
    pad_w = target_size - new_w
    pad_h = target_size - new_h
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top

    print(f"Padding (left, top): ({pad_left}, {pad_top})")
    print(f"Padding (right, bottom): ({pad_right}, {pad_bottom})")

    image_padded = cv2.copyMakeBorder(
        image_resized, pad_top, pad_bottom, pad_left, pad_right,
        cv2.BORDER_CONSTANT, value=0
    )

    # 모델 입력 준비
    input_image = np.expand_dims(image_padded, axis=0).astype(np.float32)

    # 예측
    predicted_keypoints = model.predict(input_image)[0]

    # print(f"Predicted keypoints (raw): {predicted_keypoints}")

    # 키포인트 스케일 조정 및 이동 (패딩 고려)
    # 전처리 시 사용된 스케일과 동일하게 되돌리기
    scale_back = 1 / scale

    x_scaled = (predicted_keypoints[::2] - pad_left) * scale_back
    y_scaled = (predicted_keypoints[1::2] - pad_top) * scale_back

    # print(f"Scaled keypoints (x): {x_scaled}")
    # print(f"Scaled keypoints (y): {y_scaled}")

    predicted_keypoints_scaled = np.empty_like(predicted_keypoints)
    predicted_keypoints_scaled[::2] = x_scaled
    predicted_keypoints_scaled[1::2] = y_scaled

    # print(f"Scaled keypoints (combined): {predicted_keypoints_scaled}")

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)

    for i in range(0, len(predicted_keypoints_scaled), 2):
        x = predicted_keypoints_scaled[i]
        y = predicted_keypoints_scaled[i + 1]
        # 키포인트가 이미지 범위 내에 있는지 확인
        if 0 <= x < orig_w and 0 <= y < orig_h:
            plt.scatter(x, y, c='r', s=10)

    plt.title('Predicted Keypoints')
    plt.axis('off')
    plt.show()

# 예측 및 시각화
sample_image_path = val_image_paths[1]
plot_predicted_keypoints(b_m, sample_image_path, val_image_dir)
# Out:
# Original size: (720, 1280)
# Scale factor: 0.175
# Resized size: (125, 224)
# Padding (left, top): (49, 0)
# Padding (right, bottom): (50, 0)
# 1/1 [==============================] - 0s 97ms/step

# %%
b_m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 140)                  179340    ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2437324 (9.30 MB)
# Trainable params: 2403212 (9.17 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
# 1. GPU 메모리 성장 설정
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# 2. 분산 전략 설정
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    # 3. 모델 로드
    model = tf.keras.models.load_model('b16_lr001.h5')
    
    # 4. 모델 컴파일
    # 옵티마이저, 손실 함수, 평가 지표를 정의합니다.
    model.compile(
        optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    
    # 5. 콜백 설정
    checkpoint = ModelCheckpoint('v2_b16_rmsprop.h5', monitor='val_loss', save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose=1)
    
    # 6. 배치 사이즈 설정
    per_replica_batch_size = 16
    GLOBAL_BATCH_SIZE = per_replica_batch_size * strategy.num_replicas_in_sync
    
    # 7. 모델 훈련
    EPOCHS = 100
    
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=[checkpoint, reduce_lr]
    )
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 158 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2024-11-01 06:26:23.633751: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-01 06:26:24.365347: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-01 06:26:24.372783: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-11-01 06:26:28.211009: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa2413092d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-01 06:26:28.211059: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-11-01 06:26:28.211066: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-11-01 06:26:28.211071: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla T4, Compute Capability 7.5
# 2024-11-01 06:26:28.219506: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-01 06:26:28.310556: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 856/856 [==============================] - ETA: 0s - loss: 18.3043 - mae: 3.3536
# Epoch 1: val_loss improved from inf to 26.07938, saving model to v2_b16_rmsprop.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 856/856 [==============================] - 206s 180ms/step - loss: 18.3043 - mae: 3.3536 - val_loss: 26.0794 - val_mae: 4.6246 - lr: 0.0010
# Epoch 2/100
# 855/856 [============================>.] - ETA: 0s - loss: 18.0791 - mae: 3.3370
# Epoch 2: val_loss improved from 26.07938 to 3.31164, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 152s 177ms/step - loss: 18.0799 - mae: 3.3371 - val_loss: 3.3116 - val_mae: 1.3641 - lr: 0.0010
# Epoch 3/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1580 - mae: 3.3427
# Epoch 3: val_loss did not improve from 3.31164
# 856/856 [==============================] - 153s 178ms/step - loss: 18.1580 - mae: 3.3427 - val_loss: 4.4069 - val_mae: 1.6173 - lr: 0.0010
# Epoch 4/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1963 - mae: 3.3415
# Epoch 4: val_loss did not improve from 3.31164
# 856/856 [==============================] - 144s 167ms/step - loss: 18.1963 - mae: 3.3415 - val_loss: 20.3501 - val_mae: 4.1180 - lr: 0.0010
# Epoch 5/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0537 - mae: 3.3268
# Epoch 5: val_loss did not improve from 3.31164
# 856/856 [==============================] - 146s 170ms/step - loss: 18.0537 - mae: 3.3268 - val_loss: 6.8606 - val_mae: 2.1495 - lr: 0.0010
# Epoch 6/100
# 855/856 [============================>.] - ETA: 0s - loss: 18.1862 - mae: 3.3416
# Epoch 6: val_loss did not improve from 3.31164
# 856/856 [==============================] - 141s 164ms/step - loss: 18.1842 - mae: 3.3414 - val_loss: 5.0823 - val_mae: 1.7182 - lr: 0.0010
# Epoch 7/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1095 - mae: 3.3353
# Epoch 7: val_loss improved from 3.31164 to 3.02979, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 149s 173ms/step - loss: 18.1095 - mae: 3.3353 - val_loss: 3.0298 - val_mae: 1.2814 - lr: 0.0010
# Epoch 8/100
# 856/856 [==============================] - ETA: 0s - loss: 18.1296 - mae: 3.3337
# Epoch 8: val_loss did not improve from 3.02979
# 856/856 [==============================] - 145s 169ms/step - loss: 18.1296 - mae: 3.3337 - val_loss: 16.0768 - val_mae: 3.0220 - lr: 0.0010
# Epoch 9/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0529 - mae: 3.3307
# Epoch 9: val_loss did not improve from 3.02979
# 856/856 [==============================] - 158s 184ms/step - loss: 18.0529 - mae: 3.3307 - val_loss: 3962.9324 - val_mae: 61.7855 - lr: 0.0010
# Epoch 10/100
# 855/856 [============================>.] - ETA: 0s - loss: 18.0262 - mae: 3.3288
# Epoch 10: val_loss did not improve from 3.02979
# 856/856 [==============================] - 160s 186ms/step - loss: 18.0245 - mae: 3.3286 - val_loss: 1033.7722 - val_mae: 30.2667 - lr: 0.0010
# Epoch 11/100
# 856/856 [==============================] - ETA: 0s - loss: 17.8180 - mae: 3.3083
# Epoch 11: val_loss did not improve from 3.02979
# 856/856 [==============================] - 152s 176ms/step - loss: 17.8180 - mae: 3.3083 - val_loss: 3.9319 - val_mae: 1.5524 - lr: 0.0010
# Epoch 12/100
# 856/856 [==============================] - ETA: 0s - loss: 18.0203 - mae: 3.3251
# Epoch 12: val_loss did not improve from 3.02979
# 856/856 [==============================] - 152s 177ms/step - loss: 18.0203 - mae: 3.3251 - val_loss: 129.0195 - val_mae: 10.5912 - lr: 0.0010
# Epoch 13/100
# 856/856 [==============================] - ETA: 0s - loss: 17.8370 - mae: 3.3068
# Epoch 13: val_loss improved from 3.02979 to 3.00086, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 143s 167ms/step - loss: 17.8370 - mae: 3.3068 - val_loss: 3.0009 - val_mae: 1.2527 - lr: 0.0010
# Epoch 14/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.8935 - mae: 3.3157
# Epoch 14: val_loss did not improve from 3.00086
# 856/856 [==============================] - 148s 172ms/step - loss: 17.8956 - mae: 3.3159 - val_loss: 8.6167 - val_mae: 2.4813 - lr: 0.0010
# Epoch 15/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.5631 - mae: 3.2807
# Epoch 15: val_loss did not improve from 3.00086
# 856/856 [==============================] - 140s 163ms/step - loss: 17.5636 - mae: 3.2808 - val_loss: 5.3734 - val_mae: 1.8061 - lr: 0.0010
# Epoch 16/100
# 856/856 [==============================] - ETA: 0s - loss: 17.8125 - mae: 3.3116
# Epoch 16: val_loss did not improve from 3.00086
# 856/856 [==============================] - 143s 166ms/step - loss: 17.8125 - mae: 3.3116 - val_loss: 3.9190 - val_mae: 1.5638 - lr: 0.0010
# Epoch 17/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.7773 - mae: 3.3022
# Epoch 17: val_loss did not improve from 3.00086
# 856/856 [==============================] - 143s 166ms/step - loss: 17.7765 - mae: 3.3021 - val_loss: 4.0335 - val_mae: 1.5791 - lr: 0.0010
# Epoch 18/100
# 856/856 [==============================] - ETA: 0s - loss: 17.7861 - mae: 3.3012
# Epoch 18: val_loss did not improve from 3.00086
# 856/856 [==============================] - 148s 172ms/step - loss: 17.7861 - mae: 3.3012 - val_loss: 9.2811 - val_mae: 2.3524 - lr: 0.0010
# Epoch 19/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.6710 - mae: 3.2950
# Epoch 19: val_loss did not improve from 3.00086
# 856/856 [==============================] - 145s 168ms/step - loss: 17.6703 - mae: 3.2949 - val_loss: 29.1223 - val_mae: 4.6326 - lr: 0.0010
# Epoch 20/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.7849 - mae: 3.3033
# Epoch 20: val_loss did not improve from 3.00086
# 856/856 [==============================] - 150s 174ms/step - loss: 17.7962 - mae: 3.3041 - val_loss: 4.6805 - val_mae: 1.7475 - lr: 0.0010
# Epoch 21/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.6301 - mae: 3.2900
# Epoch 21: val_loss did not improve from 3.00086
# 856/856 [==============================] - 151s 176ms/step - loss: 17.6274 - mae: 3.2897 - val_loss: 3.6269 - val_mae: 1.4275 - lr: 0.0010
# Epoch 22/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.6219 - mae: 3.2905
# Epoch 22: val_loss improved from 3.00086 to 2.82963, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 145s 168ms/step - loss: 17.6210 - mae: 3.2904 - val_loss: 2.8296 - val_mae: 1.2381 - lr: 0.0010
# Epoch 23/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.5805 - mae: 3.2841
# Epoch 23: val_loss did not improve from 2.82963
# 856/856 [==============================] - 145s 168ms/step - loss: 17.5815 - mae: 3.2843 - val_loss: 3.2631 - val_mae: 1.3184 - lr: 0.0010
# Epoch 24/100
# 856/856 [==============================] - ETA: 0s - loss: 17.6040 - mae: 3.2902
# Epoch 24: val_loss did not improve from 2.82963
# 856/856 [==============================] - 145s 169ms/step - loss: 17.6040 - mae: 3.2902 - val_loss: 9.2170 - val_mae: 2.4144 - lr: 0.0010
# Epoch 25/100
# 856/856 [==============================] - ETA: 0s - loss: 17.6370 - mae: 3.2922
# Epoch 25: val_loss did not improve from 2.82963
# 856/856 [==============================] - 144s 167ms/step - loss: 17.6370 - mae: 3.2922 - val_loss: 19.8171 - val_mae: 4.0698 - lr: 0.0010
# Epoch 26/100
# 856/856 [==============================] - ETA: 0s - loss: 17.5725 - mae: 3.2810
# Epoch 26: val_loss did not improve from 2.82963
# 856/856 [==============================] - 139s 162ms/step - loss: 17.5725 - mae: 3.2810 - val_loss: 3.6281 - val_mae: 1.4186 - lr: 0.0010
# Epoch 27/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.4212 - mae: 3.2692
# Epoch 27: val_loss did not improve from 2.82963
# 856/856 [==============================] - 144s 167ms/step - loss: 17.4238 - mae: 3.2694 - val_loss: 4.7667 - val_mae: 1.7390 - lr: 0.0010
# Epoch 28/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.6673 - mae: 3.2962
# Epoch 28: val_loss did not improve from 2.82963
# 856/856 [==============================] - 147s 171ms/step - loss: 17.6686 - mae: 3.2964 - val_loss: 3545.3000 - val_mae: 58.2113 - lr: 0.0010
# Epoch 29/100
# 856/856 [==============================] - ETA: 0s - loss: 17.4094 - mae: 3.2659
# Epoch 29: val_loss did not improve from 2.82963
# 856/856 [==============================] - 147s 171ms/step - loss: 17.4094 - mae: 3.2659 - val_loss: 12.5147 - val_mae: 3.0174 - lr: 0.0010
# Epoch 30/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.3188 - mae: 3.2621
# Epoch 30: val_loss did not improve from 2.82963
# 856/856 [==============================] - 144s 168ms/step - loss: 17.3160 - mae: 3.2618 - val_loss: 6.2856 - val_mae: 1.8998 - lr: 0.0010
# Epoch 31/100
# 856/856 [==============================] - ETA: 0s - loss: 17.4099 - mae: 3.2697
# Epoch 31: val_loss did not improve from 2.82963
# 856/856 [==============================] - 144s 168ms/step - loss: 17.4099 - mae: 3.2697 - val_loss: 3.7357 - val_mae: 1.4653 - lr: 0.0010
# Epoch 32/100
# 855/856 [============================>.] - ETA: 0s - loss: 17.3852 - mae: 3.2641
# Epoch 32: val_loss did not improve from 2.82963
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 856/856 [==============================] - 147s 171ms/step - loss: 17.3877 - mae: 3.2643 - val_loss: 4.3556 - val_mae: 1.5798 - lr: 0.0010
# Epoch 33/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.6010 - mae: 3.1886
# Epoch 33: val_loss improved from 2.82963 to 2.49905, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 143s 166ms/step - loss: 16.5989 - mae: 3.1883 - val_loss: 2.4990 - val_mae: 1.1391 - lr: 2.0000e-04
# Epoch 34/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.8314 - mae: 3.2136
# Epoch 34: val_loss did not improve from 2.49905
# 856/856 [==============================] - 148s 173ms/step - loss: 16.8296 - mae: 3.2134 - val_loss: 2.6276 - val_mae: 1.1904 - lr: 2.0000e-04
# Epoch 35/100
# 856/856 [==============================] - ETA: 0s - loss: 16.5530 - mae: 3.1838
# Epoch 35: val_loss did not improve from 2.49905
# 856/856 [==============================] - 147s 171ms/step - loss: 16.5530 - mae: 3.1838 - val_loss: 2.5483 - val_mae: 1.1478 - lr: 2.0000e-04
# Epoch 36/100
# 856/856 [==============================] - ETA: 0s - loss: 16.5787 - mae: 3.1875
# Epoch 36: val_loss improved from 2.49905 to 2.28680, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 138s 161ms/step - loss: 16.5787 - mae: 3.1875 - val_loss: 2.2868 - val_mae: 1.0750 - lr: 2.0000e-04
# Epoch 37/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.6304 - mae: 3.1890
# Epoch 37: val_loss did not improve from 2.28680
# 856/856 [==============================] - 141s 164ms/step - loss: 16.6309 - mae: 3.1891 - val_loss: 2.7496 - val_mae: 1.2016 - lr: 2.0000e-04
# Epoch 38/100
# 856/856 [==============================] - ETA: 0s - loss: 16.6307 - mae: 3.1927
# Epoch 38: val_loss did not improve from 2.28680
# 856/856 [==============================] - 146s 170ms/step - loss: 16.6307 - mae: 3.1927 - val_loss: 2.3764 - val_mae: 1.1143 - lr: 2.0000e-04
# Epoch 39/100
# 856/856 [==============================] - ETA: 0s - loss: 16.3708 - mae: 3.1707
# Epoch 39: val_loss did not improve from 2.28680
# 856/856 [==============================] - 148s 173ms/step - loss: 16.3708 - mae: 3.1707 - val_loss: 2.6031 - val_mae: 1.1667 - lr: 2.0000e-04
# Epoch 40/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.4379 - mae: 3.1733
# Epoch 40: val_loss did not improve from 2.28680
# 856/856 [==============================] - 147s 171ms/step - loss: 16.4381 - mae: 3.1732 - val_loss: 2.4727 - val_mae: 1.1295 - lr: 2.0000e-04
# Epoch 41/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.4717 - mae: 3.1770
# Epoch 41: val_loss improved from 2.28680 to 2.28487, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 147s 171ms/step - loss: 16.4726 - mae: 3.1771 - val_loss: 2.2849 - val_mae: 1.0651 - lr: 2.0000e-04
# Epoch 42/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.6069 - mae: 3.1889
# Epoch 42: val_loss improved from 2.28487 to 2.21429, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 149s 174ms/step - loss: 16.6048 - mae: 3.1887 - val_loss: 2.2143 - val_mae: 1.0535 - lr: 2.0000e-04
# Epoch 43/100
# 856/856 [==============================] - ETA: 0s - loss: 16.4013 - mae: 3.1687
# Epoch 43: val_loss did not improve from 2.21429
# 856/856 [==============================] - 153s 179ms/step - loss: 16.4013 - mae: 3.1687 - val_loss: 2.2385 - val_mae: 1.0675 - lr: 2.0000e-04
# Epoch 44/100
# 856/856 [==============================] - ETA: 0s - loss: 16.4776 - mae: 3.1768
# Epoch 44: val_loss did not improve from 2.21429
# 856/856 [==============================] - 145s 169ms/step - loss: 16.4776 - mae: 3.1768 - val_loss: 2.2301 - val_mae: 1.0596 - lr: 2.0000e-04
# Epoch 45/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.4068 - mae: 3.1713
# Epoch 45: val_loss did not improve from 2.21429
# 856/856 [==============================] - 146s 170ms/step - loss: 16.4070 - mae: 3.1713 - val_loss: 2.2338 - val_mae: 1.0542 - lr: 2.0000e-04
# Epoch 46/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3723 - mae: 3.1677
# Epoch 46: val_loss did not improve from 2.21429
# 856/856 [==============================] - 148s 172ms/step - loss: 16.3715 - mae: 3.1676 - val_loss: 2.9187 - val_mae: 1.2703 - lr: 2.0000e-04
# Epoch 47/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2816 - mae: 3.1539
# Epoch 47: val_loss did not improve from 2.21429
# 856/856 [==============================] - 141s 164ms/step - loss: 16.2823 - mae: 3.1540 - val_loss: 2.5346 - val_mae: 1.1444 - lr: 2.0000e-04
# Epoch 48/100
# 856/856 [==============================] - ETA: 0s - loss: 16.4096 - mae: 3.1671
# Epoch 48: val_loss did not improve from 2.21429
# 856/856 [==============================] - 148s 172ms/step - loss: 16.4096 - mae: 3.1671 - val_loss: 2.3149 - val_mae: 1.0734 - lr: 2.0000e-04
# Epoch 49/100
# 856/856 [==============================] - ETA: 0s - loss: 16.3892 - mae: 3.1692
# Epoch 49: val_loss did not improve from 2.21429
# 856/856 [==============================] - 149s 174ms/step - loss: 16.3892 - mae: 3.1692 - val_loss: 2.4198 - val_mae: 1.1269 - lr: 2.0000e-04
# Epoch 50/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1750 - mae: 3.1426
# Epoch 50: val_loss did not improve from 2.21429
# 856/856 [==============================] - 149s 173ms/step - loss: 16.1750 - mae: 3.1426 - val_loss: 2.2972 - val_mae: 1.0768 - lr: 2.0000e-04
# Epoch 51/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.4091 - mae: 3.1696
# Epoch 51: val_loss did not improve from 2.21429
# 856/856 [==============================] - 146s 170ms/step - loss: 16.4111 - mae: 3.1696 - val_loss: 2.2285 - val_mae: 1.0574 - lr: 2.0000e-04
# Epoch 52/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2922 - mae: 3.1579
# Epoch 52: val_loss improved from 2.21429 to 2.20744, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 149s 174ms/step - loss: 16.2937 - mae: 3.1581 - val_loss: 2.2074 - val_mae: 1.0476 - lr: 2.0000e-04
# Epoch 53/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3736 - mae: 3.1606
# Epoch 53: val_loss did not improve from 2.20744
# 856/856 [==============================] - 145s 169ms/step - loss: 16.3745 - mae: 3.1607 - val_loss: 2.2427 - val_mae: 1.0514 - lr: 2.0000e-04
# Epoch 54/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3892 - mae: 3.1616
# Epoch 54: val_loss did not improve from 2.20744
# 856/856 [==============================] - 148s 173ms/step - loss: 16.3971 - mae: 3.1621 - val_loss: 2.3810 - val_mae: 1.1003 - lr: 2.0000e-04
# Epoch 55/100
# 856/856 [==============================] - ETA: 0s - loss: 16.4182 - mae: 3.1690
# Epoch 55: val_loss did not improve from 2.20744
# 856/856 [==============================] - 146s 170ms/step - loss: 16.4182 - mae: 3.1690 - val_loss: 2.8423 - val_mae: 1.2450 - lr: 2.0000e-04
# Epoch 56/100
# 856/856 [==============================] - ETA: 0s - loss: 16.3396 - mae: 3.1610
# Epoch 56: val_loss did not improve from 2.20744
# 856/856 [==============================] - 150s 174ms/step - loss: 16.3396 - mae: 3.1610 - val_loss: 2.4454 - val_mae: 1.1081 - lr: 2.0000e-04
# Epoch 57/100
# 856/856 [==============================] - ETA: 0s - loss: 16.2510 - mae: 3.1481
# Epoch 57: val_loss did not improve from 2.20744
# 856/856 [==============================] - 150s 174ms/step - loss: 16.2510 - mae: 3.1481 - val_loss: 2.2611 - val_mae: 1.0586 - lr: 2.0000e-04
# Epoch 58/100
# 856/856 [==============================] - ETA: 0s - loss: 16.2533 - mae: 3.1536
# Epoch 58: val_loss did not improve from 2.20744
# 856/856 [==============================] - 146s 171ms/step - loss: 16.2533 - mae: 3.1536 - val_loss: 2.3544 - val_mae: 1.0880 - lr: 2.0000e-04
# Epoch 59/100
# 856/856 [==============================] - ETA: 0s - loss: 16.2100 - mae: 3.1502
# Epoch 59: val_loss did not improve from 2.20744
# 856/856 [==============================] - 147s 172ms/step - loss: 16.2100 - mae: 3.1502 - val_loss: 2.5382 - val_mae: 1.1649 - lr: 2.0000e-04
# Epoch 60/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.4582 - mae: 3.1704
# Epoch 60: val_loss improved from 2.20744 to 2.13779, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 147s 172ms/step - loss: 16.4577 - mae: 3.1704 - val_loss: 2.1378 - val_mae: 1.0219 - lr: 2.0000e-04
# Epoch 61/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1944 - mae: 3.1497
# Epoch 61: val_loss did not improve from 2.13779
# 856/856 [==============================] - 150s 174ms/step - loss: 16.1944 - mae: 3.1497 - val_loss: 2.4779 - val_mae: 1.1272 - lr: 2.0000e-04
# Epoch 62/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3062 - mae: 3.1576
# Epoch 62: val_loss did not improve from 2.13779
# 856/856 [==============================] - 152s 177ms/step - loss: 16.3053 - mae: 3.1575 - val_loss: 2.4551 - val_mae: 1.1254 - lr: 2.0000e-04
# Epoch 63/100
# 856/856 [==============================] - ETA: 0s - loss: 16.2356 - mae: 3.1496
# Epoch 63: val_loss did not improve from 2.13779
# 856/856 [==============================] - 150s 174ms/step - loss: 16.2356 - mae: 3.1496 - val_loss: 2.4770 - val_mae: 1.1409 - lr: 2.0000e-04
# Epoch 64/100
# 856/856 [==============================] - ETA: 0s - loss: 16.2670 - mae: 3.1523
# Epoch 64: val_loss did not improve from 2.13779
# 856/856 [==============================] - 151s 176ms/step - loss: 16.2670 - mae: 3.1523 - val_loss: 2.4073 - val_mae: 1.1276 - lr: 2.0000e-04
# Epoch 65/100
# 856/856 [==============================] - ETA: 0s - loss: 16.3056 - mae: 3.1531
# Epoch 65: val_loss did not improve from 2.13779
# 856/856 [==============================] - 150s 174ms/step - loss: 16.3056 - mae: 3.1531 - val_loss: 3.2044 - val_mae: 1.3674 - lr: 2.0000e-04
# Epoch 66/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1959 - mae: 3.1501
# Epoch 66: val_loss did not improve from 2.13779
# 856/856 [==============================] - 148s 172ms/step - loss: 16.1959 - mae: 3.1501 - val_loss: 2.3075 - val_mae: 1.0794 - lr: 2.0000e-04
# Epoch 67/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1361 - mae: 3.1443
# Epoch 67: val_loss did not improve from 2.13779
# 856/856 [==============================] - 150s 175ms/step - loss: 16.1361 - mae: 3.1443 - val_loss: 2.1935 - val_mae: 1.0446 - lr: 2.0000e-04
# Epoch 68/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2519 - mae: 3.1524
# Epoch 68: val_loss did not improve from 2.13779
# 856/856 [==============================] - 145s 169ms/step - loss: 16.2528 - mae: 3.1525 - val_loss: 2.3977 - val_mae: 1.1109 - lr: 2.0000e-04
# Epoch 69/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2080 - mae: 3.1531
# Epoch 69: val_loss did not improve from 2.13779
# 856/856 [==============================] - 149s 173ms/step - loss: 16.2066 - mae: 3.1529 - val_loss: 2.2470 - val_mae: 1.0612 - lr: 2.0000e-04
# Epoch 70/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3104 - mae: 3.1545
# Epoch 70: val_loss did not improve from 2.13779
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 856/856 [==============================] - 150s 174ms/step - loss: 16.3124 - mae: 3.1547 - val_loss: 2.2163 - val_mae: 1.0500 - lr: 2.0000e-04
# Epoch 71/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1124 - mae: 3.1429
# Epoch 71: val_loss did not improve from 2.13779
# 856/856 [==============================] - 150s 175ms/step - loss: 16.1124 - mae: 3.1429 - val_loss: 2.2176 - val_mae: 1.0533 - lr: 4.0000e-05
# Epoch 72/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2384 - mae: 3.1512
# Epoch 72: val_loss improved from 2.13779 to 2.13493, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 150s 174ms/step - loss: 16.2406 - mae: 3.1515 - val_loss: 2.1349 - val_mae: 1.0253 - lr: 4.0000e-05
# Epoch 73/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1116 - mae: 3.1412
# Epoch 73: val_loss did not improve from 2.13493
# 856/856 [==============================] - 143s 166ms/step - loss: 16.1140 - mae: 3.1415 - val_loss: 2.2703 - val_mae: 1.0700 - lr: 4.0000e-05
# Epoch 74/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.3778 - mae: 3.1637
# Epoch 74: val_loss did not improve from 2.13493
# 856/856 [==============================] - 146s 169ms/step - loss: 16.3766 - mae: 3.1636 - val_loss: 2.1535 - val_mae: 1.0290 - lr: 4.0000e-05
# Epoch 75/100
# 856/856 [==============================] - ETA: 0s - loss: 16.0767 - mae: 3.1307
# Epoch 75: val_loss improved from 2.13493 to 2.12921, saving model to v2_b16_rmsprop.h5
# 856/856 [==============================] - 147s 171ms/step - loss: 16.0767 - mae: 3.1307 - val_loss: 2.1292 - val_mae: 1.0208 - lr: 4.0000e-05
# Epoch 76/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1771 - mae: 3.1494
# Epoch 76: val_loss did not improve from 2.12921
# 856/856 [==============================] - 144s 168ms/step - loss: 16.1771 - mae: 3.1494 - val_loss: 2.1411 - val_mae: 1.0244 - lr: 4.0000e-05
# Epoch 77/100
# 856/856 [==============================] - ETA: 0s - loss: 16.0686 - mae: 3.1357
# Epoch 77: val_loss did not improve from 2.12921
# 856/856 [==============================] - 142s 166ms/step - loss: 16.0686 - mae: 3.1357 - val_loss: 2.3341 - val_mae: 1.0952 - lr: 4.0000e-05
# Epoch 78/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.2130 - mae: 3.1462
# Epoch 78: val_loss did not improve from 2.12921
# 856/856 [==============================] - 145s 169ms/step - loss: 16.2142 - mae: 3.1463 - val_loss: 2.1364 - val_mae: 1.0238 - lr: 4.0000e-05
# Epoch 79/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1838 - mae: 3.1460
# Epoch 79: val_loss did not improve from 2.12921
# 856/856 [==============================] - 142s 165ms/step - loss: 16.1853 - mae: 3.1461 - val_loss: 2.1337 - val_mae: 1.0229 - lr: 4.0000e-05
# Epoch 80/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1169 - mae: 3.1405
# Epoch 80: val_loss did not improve from 2.12921
# 856/856 [==============================] - 142s 165ms/step - loss: 16.1169 - mae: 3.1405 - val_loss: 2.2924 - val_mae: 1.0762 - lr: 4.0000e-05
# Epoch 81/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0624 - mae: 3.1367
# Epoch 81: val_loss did not improve from 2.12921
# 856/856 [==============================] - 144s 168ms/step - loss: 16.0617 - mae: 3.1366 - val_loss: 2.2306 - val_mae: 1.0507 - lr: 4.0000e-05
# Epoch 82/100
# 856/856 [==============================] - ETA: 0s - loss: 15.9841 - mae: 3.1315
# Epoch 82: val_loss did not improve from 2.12921
# 856/856 [==============================] - 140s 163ms/step - loss: 15.9841 - mae: 3.1315 - val_loss: 2.2034 - val_mae: 1.0455 - lr: 4.0000e-05
# Epoch 83/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1536 - mae: 3.1414
# Epoch 83: val_loss did not improve from 2.12921
# 856/856 [==============================] - 143s 167ms/step - loss: 16.1529 - mae: 3.1414 - val_loss: 2.2999 - val_mae: 1.0812 - lr: 4.0000e-05
# Epoch 84/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1136 - mae: 3.1428
# Epoch 84: val_loss did not improve from 2.12921
# 856/856 [==============================] - 148s 172ms/step - loss: 16.1120 - mae: 3.1426 - val_loss: 2.1457 - val_mae: 1.0256 - lr: 4.0000e-05
# Epoch 85/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1541 - mae: 3.1412
# Epoch 85: val_loss did not improve from 2.12921
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 856/856 [==============================] - 142s 165ms/step - loss: 16.1544 - mae: 3.1413 - val_loss: 2.2869 - val_mae: 1.0750 - lr: 4.0000e-05
# Epoch 86/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1119 - mae: 3.1412
# Epoch 86: val_loss did not improve from 2.12921
# 856/856 [==============================] - 143s 167ms/step - loss: 16.1119 - mae: 3.1412 - val_loss: 2.1739 - val_mae: 1.0357 - lr: 8.0000e-06
# Epoch 87/100
# 855/856 [============================>.] - ETA: 0s - loss: 15.9607 - mae: 3.1280
# Epoch 87: val_loss did not improve from 2.12921
# 856/856 [==============================] - 142s 166ms/step - loss: 15.9590 - mae: 3.1279 - val_loss: 2.1925 - val_mae: 1.0436 - lr: 8.0000e-06
# Epoch 88/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0578 - mae: 3.1336
# Epoch 88: val_loss did not improve from 2.12921
# 856/856 [==============================] - 146s 170ms/step - loss: 16.0601 - mae: 3.1338 - val_loss: 2.2119 - val_mae: 1.0505 - lr: 8.0000e-06
# Epoch 89/100
# 855/856 [============================>.] - ETA: 0s - loss: 15.9677 - mae: 3.1261
# Epoch 89: val_loss did not improve from 2.12921
# 856/856 [==============================] - 149s 173ms/step - loss: 15.9683 - mae: 3.1263 - val_loss: 2.1881 - val_mae: 1.0411 - lr: 8.0000e-06
# Epoch 90/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1105 - mae: 3.1403
# Epoch 90: val_loss did not improve from 2.12921
# 856/856 [==============================] - 149s 173ms/step - loss: 16.1105 - mae: 3.1403 - val_loss: 2.1907 - val_mae: 1.0418 - lr: 8.0000e-06
# Epoch 91/100
# 856/856 [==============================] - ETA: 0s - loss: 16.0361 - mae: 3.1332
# Epoch 91: val_loss did not improve from 2.12921
# 856/856 [==============================] - 150s 175ms/step - loss: 16.0361 - mae: 3.1332 - val_loss: 2.1965 - val_mae: 1.0443 - lr: 8.0000e-06
# Epoch 92/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1247 - mae: 3.1378
# Epoch 92: val_loss did not improve from 2.12921
# 856/856 [==============================] - 150s 175ms/step - loss: 16.1247 - mae: 3.1378 - val_loss: 2.2081 - val_mae: 1.0491 - lr: 8.0000e-06
# Epoch 93/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0484 - mae: 3.1273
# Epoch 93: val_loss did not improve from 2.12921
# 856/856 [==============================] - 148s 173ms/step - loss: 16.0456 - mae: 3.1270 - val_loss: 2.2573 - val_mae: 1.0661 - lr: 8.0000e-06
# Epoch 94/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0441 - mae: 3.1312
# Epoch 94: val_loss did not improve from 2.12921
# 856/856 [==============================] - 145s 169ms/step - loss: 16.0434 - mae: 3.1311 - val_loss: 2.2154 - val_mae: 1.0515 - lr: 8.0000e-06
# Epoch 95/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.1245 - mae: 3.1382
# Epoch 95: val_loss did not improve from 2.12921
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 856/856 [==============================] - 149s 174ms/step - loss: 16.1243 - mae: 3.1381 - val_loss: 2.1868 - val_mae: 1.0406 - lr: 8.0000e-06
# Epoch 96/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0529 - mae: 3.1371
# Epoch 96: val_loss did not improve from 2.12921
# 856/856 [==============================] - 149s 173ms/step - loss: 16.0546 - mae: 3.1372 - val_loss: 2.1916 - val_mae: 1.0424 - lr: 1.6000e-06
# Epoch 97/100
# 855/856 [============================>.] - ETA: 0s - loss: 16.0989 - mae: 3.1377
# Epoch 97: val_loss did not improve from 2.12921
# 856/856 [==============================] - 150s 175ms/step - loss: 16.1013 - mae: 3.1379 - val_loss: 2.2169 - val_mae: 1.0512 - lr: 1.6000e-06
# Epoch 98/100
# 855/856 [============================>.] - ETA: 0s - loss: 15.9811 - mae: 3.1249
# Epoch 98: val_loss did not improve from 2.12921
# 856/856 [==============================] - 151s 176ms/step - loss: 15.9807 - mae: 3.1248 - val_loss: 2.1962 - val_mae: 1.0438 - lr: 1.6000e-06
# Epoch 99/100
# 856/856 [==============================] - ETA: 0s - loss: 16.1003 - mae: 3.1405
# Epoch 99: val_loss did not improve from 2.12921
# 856/856 [==============================] - 147s 172ms/step - loss: 16.1003 - mae: 3.1405 - val_loss: 2.1803 - val_mae: 1.0377 - lr: 1.6000e-06
# Epoch 100/100
# 856/856 [==============================] - ETA: 0s - loss: 16.0750 - mae: 3.1392
# Epoch 100: val_loss did not improve from 2.12921
# 856/856 [==============================] - 149s 173ms/step - loss: 16.0750 - mae: 3.1392 - val_loss: 2.1751 - val_mae: 1.0359 - lr: 1.6000e-06

# %%
import matplotlib.pyplot as plt

# 훈련 손실 및 MAE 시각화
plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'][50:], label='Train Loss')
plt.plot(history.history['val_loss'][50:], label='Val Loss')
plt.legend()
plt.title('Loss')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'][50:], label='Train MAE')
plt.plot(history.history['val_mae'][50:], label='Val MAE')
plt.legend()
plt.title('MAE')

plt.show()
